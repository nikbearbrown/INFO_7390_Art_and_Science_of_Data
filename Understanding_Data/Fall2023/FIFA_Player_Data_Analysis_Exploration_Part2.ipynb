# %% [markdown]
# <center> <h1> Assignment 1: Understanding data : Part 2</h1> </center>
# <center> <h3> INFO 7390: Advance Data Science </h3> </center>
# <center> <h3> Vinay Jogani, NEU ID: 002839145 </h3> </center>

# %% [markdown]
# The sinking of the RMS Titanic is a notorious maritime disaster that occurred on April 15, 1912, during its inaugural voyage. Striking an iceberg led to the ship's demise, resulting in the tragic loss of 1502 lives out of the 2224 passengers and crew on board. This catastrophic event sent shockwaves across the globe and prompted the establishment of improved safety regulations for sea travel.
#
# A significant factor contributing to the high casualty count was the inadequate provision of lifeboats, leaving many passengers and crew without sufficient means of escape. The aftermath of the Titanic disaster highlighted the need for enhanced safety measures in the maritime industry.
#
# Exploring the data related to the Titanic tragedy allows us to delve into the demographics of the passengers, their chances of survival, and the factors that influenced their outcomes. By analyzing the information, we can gain insights into the differential survival rates among various groups, such as women, children, and individuals from different socio-economic classes. This exploration will involve visualizing the data to uncover patterns and trends, shedding light on the complex dynamics at play during this historic event.

# %% [markdown]
# ### Data

# %% [markdown]
# - Titanic data (titanic_data.csv)

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# <center>
# <table class="table table-bordered">
# <tr>
# <th style="width:5%">Variable</th><th style="width:5%">Definition</th><th style="width:5%">Key</th>
# </tr>
# <tr>
# <td>survival</td>
# <td>Survival</td>
# <td>0 = No, 1 = Yes</td>
# </tr>
# <tr>
# <td>pclass</td>
# <td>Ticket class</td>
# <td>1 = 1st, 2 = 2nd, 3 = 3rd</td>
# </tr>
# <tr>
# <td>sex</td>
# <td>sex</td>
# <td></td>
# </tr>
# <tr>
# <td>Age</td>
# <td>Age in years</td>
# <td></td>
# </tr>
# <tr>
# <td>sibsp</td>
# <td># of siblings / spouses aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>parch</td>
# <td># of parents / children aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>ticket</td>
# <td>Ticket number</td>
# <td></td>
# </tr>
# <tr>
# <td>fare</td>
# <td>Passenger fare</td>
# <td></td>
# </tr>
# <tr>
# <td>cabin</td>
# <td>Cabin number</td>
# <td></td>
# </tr>
# <tr>
# <td>embarked</td>
# <td>Port of Embarkation</td>
# <td>C = Cherbourg, Q = Queenstown, S = Southampton</td>
# </tr>
# </table>
# </center>

# %% [markdown]
# # Wrangling & EDA

# %% [markdown]
# ## 1. Loading Packages

# %%
# Importing "Pandas" , "Numpy" , "Matplotlib" and "Seaborn" libraries.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()  # to set theme of plot
# %matplotlib inline 
# %(magic command) to IDE that use interactive python. Jupites implements interactive python.

# %% [markdown]
# ## 2. Loading Data & Basic Analysis

# %%
# Importing and reading "Titanic Dataset"

data = pd.read_csv('titanic_unclean_data.csv')
dftitanic = data.copy()

# %% [markdown]
# ### Basic Structure

# %%
# Checking the number of values in "Titanic Dataset" using "Shape()" function.

dftitanic.shape
# Out:
# (891, 12)

# %%
# Examining the Top 10 Rows/Values of "Titanic Dataset" using "head()" function. 

dftitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
# Examining the data types if columns values of "Titanic Dataset" using "dtypes" function.

dftitanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Examining the Dataset by applying Statistical formula using "describe()" function.

dftitanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dftitanic.describe(include=["O"])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
dftitanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ### Completeness

# %%
# Examining the Dataset and counting number of Null values in "Titanic Dataset" using "isnull().sum()" function 

dftitanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# FareCat          0
# dtype: int64

# %% [markdown]
# ## 3. Exploration

# %% [markdown]
# ### 3.1 Exploration of Complete & Important Variables
#
# Our response variable in the training set is complete, as well as Sex and Pclass, which seem two of the most important predictors.

# %% [markdown]
# **Survival**

# %%
sns.countplot(x='Survived', hue='Survived', data=dftitanic);

# %% [markdown]
# **Gender & Survival**

# %%
sns.countplot(x='Sex', data=dftitanic);

# %%
sns.countplot(x='Sex', hue='Survived', data=dftitanic);

# %% [markdown]
# ### Passenger Survival Class

# %%
sns.countplot(x='Pclass', data=dftitanic);

# %%
sns.countplot(x='Pclass', hue='Survived', data=dftitanic);

# %% [markdown]
# **Passenger Class, Gender & Survival**

# %%
sns.catplot(x='Sex', col='Pclass', data=dftitanic, kind='count');
# Out:
# /Users/vinayjogani/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='Sex', col='Pclass', hue='Survived', data=dftitanic, kind='count')
# Out:
# /Users/vinayjogani/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### 3.2 What's in the name?

# %%
dftitanic['Name'].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %% [markdown]
# **Extracting & Analyzing Titles**

# %% [markdown]
# This is called feature engineering where you derive additional columns as per your domain knowledge like creating 'Title in the following example.

# %%
import re  # regular expression re
a='Braund, Mr.Owen Harris'
re.search(' ([A-Z][a-z]+)\.', a).group(1)
# Out:
# 'Mr'

# %%
dftitanic['Title'] = dftitanic['Name'].apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
dftitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked FareCat   Title
# 0      0         A/5 21171   7.2500   NaN        S    0-10      Mr
# 1      0          PC 17599  71.2833   C85        C  70-100     Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S    0-10    Miss
# 3      0            113803  53.1000  C123        S   40-70     Mrs
# 4      0            373450   8.0500   NaN        S    0-10      Mr
# 5      0            330877   8.4583   NaN        Q    0-10      Mr
# 6      0             17463  51.8625   E46        S   40-70      Mr
# 7      1            349909  21.0750   NaN        S   10-25  Master
# 8      2            347742  11.1333   NaN        S   10-25     Mrs
# 9      0            237736  30.0708   NaN        C   25-40     Mrs

# %%
dftitanic['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %% [markdown]
# The term *Mademoiselle* is a French familiar title, abbreviated **Mlle**, traditionally given to an unmarried woman. The equivalent in English is "Miss". However, the courtesy title "Madame" is accorded women where their marital status is unknown.

# %%
dftitanic['Title'] = dftitanic['Title'].replace('Mlle', 'Miss')

# %% [markdown]
# In France, one traditionally calls a young, unmarried woman Mademoiselle – Mlle for short – and an older, married woman _Madame_, whose abbreviation is **Mme**.

# %%
dftitanic['Title'] = dftitanic['Title'].replace('Mme', 'Mrs')

# %%
(~dftitanic['Title'].isin(['Mr', 'Mrs', 'Miss', 'Master']))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Title, Length: 891, dtype: bool

# %%
dftitanic.loc[0:77, 'Title']
# Out:
# 0       Mr
# 1      Mrs
# 2     Miss
# 3      Mrs
# 4       Mr
#       ...
# 73      Mr
# 74      Mr
# 75      Mr
# 76      Mr
# 77      Mr
# Name: Title, Length: 78, dtype: object

# %%
dftitanic.loc[(~dftitanic['Title'].isin(['Mr', 'Mrs', 'Miss', 'Master'])), 'Title'] = 'Rare Title'

# %%
dftitanic['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Rare Title'], dtype=object)

# %%
sns.countplot(data=dftitanic,x='Title', hue='Survived');

# %% [markdown]
# ### 3.3 Travelling Alone vs. Travelling in groups

# %% [markdown]
# **3.3.1 Family Size**

# %%
dftitanic['Fsize'] = dftitanic['SibSp'] + dftitanic['Parch']+1
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked       Title  Fsize
# 0        0         A/5 21171   7.2500   NaN        S          Mr      2
# 1        0          PC 17599  71.2833   C85        C         Mrs      2
# 2        0  STON/O2. 3101282   7.9250   NaN        S        Miss      1
# 3        0            113803  53.1000  C123        S         Mrs      2
# 4        0            373450   8.0500   NaN        S          Mr      1
# ..     ...               ...      ...   ...      ...         ...    ...
# 886      0            211536  13.0000   NaN        S  Rare Title      1
# 887      0            112053  30.0000   B42        S        Miss      1
# 888      2        W./C. 6607  23.4500   NaN        S        Miss      4
# 889      0            111369  30.0000  C148        C          Mr      1
# 890      0            370376   7.7500   NaN        Q          Mr      1
#
# [891 rows x 14 columns]

# %% [markdown]
# Show the countplot on column **'Fsize'** and check how many people are survived and died.

# %%
# Plotting the Family Size

sns.countplot(data=dftitanic,x='Fsize', hue='Survived');

# %%
dftitanic.groupby('Fsize')['Survived'].value_counts(normalize=True).reset_index(name='perc') 
# normalize =true calculates percentage
# Out:
#     Fsize  Survived      perc
# 0       1         0  0.696462
# 1       1         1  0.303538
# 2       2         1  0.552795
# 3       2         0  0.447205
# 4       3         1  0.578431
# 5       3         0  0.421569
# 6       4         1  0.724138
# 7       4         0  0.275862
# 8       5         0  0.800000
# 9       5         1  0.200000
# 10      6         0  0.863636
# 11      6         1  0.136364
# 12      7         0  0.666667
# 13      7         1  0.333333
# 14      8         0  1.000000
# 15     11         0  1.000000

# %%
temp = dftitanic.groupby('Fsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')
plt.figure(figsize=(15,6));
sns.barplot(data=temp,x='Fsize', y='Perc', hue='Survived', dodge=True);

# %% [markdown]
# **3.3.2 How many people booked together?**
#
# _Apart from families, there could be groups of friends travelling together._

# %%
dftitanic['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
dftitanic['Ticket'].value_counts().head()
# Out:
# CA. 2343    7
# 347082      7
# 1601        7
# 3101295     6
# CA 2144     6
# Name: Ticket, dtype: int64

# %% [markdown]
# **reset_index()** is a method to reset index of a Data Frame. **reset_index()** method sets a list of integer ranging from 0 to length of data as index.

# %%
dftitanic['Ticket'].value_counts().reset_index().head()
# Out:
#       index  Ticket
# 0  CA. 2343       7
# 1    347082       7
# 2      1601       7
# 3   3101295       6
# 4   CA 2144       6

# %%
temp = dftitanic['Ticket'].value_counts().reset_index(name='Tsize') # introduces index
temp
# Out:
#          index  Tsize
# 0     CA. 2343      7
# 1       347082      7
# 2         1601      7
# 3      3101295      6
# 4      CA 2144      6
# ..         ...    ...
# 676     250648      1
# 677     370377      1
# 678     237671      1
# 679  A/5. 3337      1
# 680     330919      1
#
# [681 rows x 2 columns]

# %%
dftitanic = dftitanic.merge(temp, left_on='Ticket', right_on='index',how='inner').drop('index', axis=1) 
# merged two tables , both have a common column of Ticket. 
dftitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4          138         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#    Parch            Ticket     Fare Cabin Embarked Title  Fsize  Tsize
# 0      0         A/5 21171   7.2500   NaN        S    Mr      2      1
# 1      0          PC 17599  71.2833   C85        C   Mrs      2      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss      1      1
# 3      0            113803  53.1000  C123        S   Mrs      2      2
# 4      0            113803  53.1000  C123        S    Mr      2      2

# %% [markdown]
# Show the countplot on column **'Tsize'** and check how many people are survived and died.

# %%
sns.countplot(data=dftitanic,x='Tsize', hue='Survived');

# %%
temp = dftitanic.groupby('Tsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')

# %%
sns.barplot(x='Tsize', y='Perc', hue='Survived', data=temp, dodge=True);

# %% [markdown]
# **3.3.3 Consolidating family & friends**

# %%
dftitanic[['Tsize', 'Fsize']].max(axis=1) # picking maximum of both in tsize and fsize
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      2
#       ..
# 886    1
# 887    1
# 888    1
# 889    1
# 890    1
# Length: 891, dtype: int64

# %%
dftitanic['Group'] = dftitanic[['Tsize', 'Fsize']].max(axis=1) # creating a new colum group

plt.figure(figsize=(15,6));
sns.countplot(x='Group', hue='Survived', data=dftitanic);

# %%
dftitanic['GrpSize'] = ''
dftitanic.loc[dftitanic['Group']==1, 'GrpSize'] = dftitanic.loc[dftitanic['Group']==1, 'GrpSize'].replace('', 'solo')
dftitanic.loc[dftitanic['Group']==2, 'GrpSize'] = dftitanic.loc[dftitanic['Group']==2, 'GrpSize'].replace('', 'couple')
dftitanic.loc[(dftitanic['Group']<=4) & (dftitanic['Group']>=3), 'GrpSize'] = dftitanic.loc[(dftitanic['Group']<=4) & (dftitanic['Group']>=3), 'GrpSize'].replace('', 'group')
dftitanic.loc[dftitanic['Group']>4, 'GrpSize'] = dftitanic.loc[dftitanic['Group']>4, 'GrpSize'].replace('', 'large group')
dftitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4          138         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#    Parch            Ticket     Fare Cabin Embarked Title  Fsize  Tsize  Group  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr      2      1      2
# 1      0          PC 17599  71.2833   C85        C   Mrs      2      1      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss      1      1      1
# 3      0            113803  53.1000  C123        S   Mrs      2      2      2
# 4      0            113803  53.1000  C123        S    Mr      2      2      2
#
#   GrpSize
# 0  couple
# 1  couple
# 2    solo
# 3  couple
# 4  couple

# %%
plt.figure(figsize=(15,6));
sns.countplot(x='GrpSize', order=['solo', 'couple', 'group', 'large group'], hue='Survived', data=dftitanic);

# %% [markdown]
# ### 3.4 Effect of Fare

# %% [markdown]
# **Task 16:**
# Check the null values of fare

# %%
dftitanic["Fare"].isnull().sum()
# Out:
# 0

# %%
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
plt.subplots(figsize=(15,6))
sns.distplot(dftitanic['Fare'],kde=True);
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_51168/143108262.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dftitanic['Fare'],kde=True);

# %%
plt.subplots(figsize=(15,6))
sns.distplot(dftitanic['Fare'],kde=False);
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_51168/2351139552.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dftitanic['Fare'],kde=False);

# %%
dftitanic[dftitanic['Fare'] < 0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
dftitanic[dftitanic['Fare'] == 0] # there are null values in fare, so we will replace null values.
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# we replace null values with median value of their respective class.
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 1), 'Fare'] = dftitanic[dftitanic['Pclass'] == 1]['Fare'].median()
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 2), 'Fare'] = dftitanic[dftitanic['Pclass'] == 2]['Fare'].median()
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 3), 'Fare'] = dftitanic[dftitanic['Pclass'] == 3]['Fare'].median()

# %%
dftitanic[dftitanic['Fare']==0] # no more null values in fare now.
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# Assigning categories to fare

# %%
dftitanic['FareCat'] = ''
dftitanic.loc[dftitanic['Fare']<=10, 'FareCat'] = '0-10'
dftitanic.loc[(dftitanic['Fare']>10) & (dftitanic['Fare']<=25), 'FareCat'] = '10-25'
dftitanic.loc[(dftitanic['Fare']>25) & (dftitanic['Fare']<=40), 'FareCat'] = '25-40'
dftitanic.loc[(dftitanic['Fare']>40) & (dftitanic['Fare']<=70), 'FareCat'] = '40-70'
dftitanic.loc[(dftitanic['Fare']>70) & (dftitanic['Fare']<=100), 'FareCat'] = '70-100'
dftitanic.loc[dftitanic['Fare']>100, 'FareCat'] = '100+'
dftitanic[['Fare', 'FareCat']].head(10)
# Out:
#       Fare FareCat
# 0   7.2500    0-10
# 1  71.2833  70-100
# 2   7.9250    0-10
# 3  53.1000   40-70
# 4   8.0500    0-10
# 5   8.4583    0-10
# 6  51.8625   40-70
# 7  21.0750   10-25
# 8  11.1333   10-25
# 9  30.0708   25-40

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='FareCat', order=['0-10', '10-25', '25-40', '40-70', '70-100', '100+'], hue='Survived', data=dftitanic);

# %%
#write the code to find the median
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 1), 'Fare'] = dftitanic[dftitanic['Pclass'] == 1]['Fare'].median()
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 2), 'Fare'] = dftitanic[dftitanic['Pclass'] == 2]['Fare'].median()
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 3), 'Fare'] = dftitanic[dftitanic['Pclass'] == 3]['Fare'].median()

# %% [markdown]
# ### 3.5 Effect of Embarked variable
#
# _C = Cherbourg(France), Q = Queenstown(Ireland), S = Southampton(England)_

# %% [markdown]
# ***Engineered Features***

# %%
dftitanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked FareCat Title
# 0      0  A/5 21171   7.2500   NaN        S    0-10    Mr
# 1      0   PC 17599  71.2833   C85        C  70-100   Mrs

# %% [markdown]
# ## 4. Missing Values

# %% [markdown]
# ### 4.1 Age

# %%
sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'].dropna(), shade=True,label="Not survived");
sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'].dropna(), shade=True,label="Survived");
plt.legend()
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_51168/3577536914.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'].dropna(), shade=True,label="Not survived");
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_51168/3577536914.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'].dropna(), shade=True,label="Survived");

# %%
temp = dftitanic[dftitanic['Age'].isnull() == False]

# %%
sns.set_context('poster')
sns.catplot(kind='box', x='Age', col='Title', row='Pclass', data=temp);
# Out:
# /Users/vinayjogani/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
for t in dftitanic['Title'].unique():
    for p in dftitanic['Pclass'].unique():
        dftitanic.loc[(dftitanic['Title'] == t) & (dftitanic['Pclass'] == p) & (dftitanic['Age'].isnull()), 'Age'] = dftitanic.loc[(dftitanic['Title'] == t) & (dftitanic['Pclass'] == p), 'Age'].median()

# %%
plt.subplots(figsize=(10,6))
sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'], shade=True,label='Not Survived');
sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'], shade=True,label='Survived');
plt.legend()
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_51168/829782506.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'], shade=True,label='Not Survived');
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_51168/829782506.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'], shade=True,label='Survived');

# %% [markdown]
# Creating Age categories

# %%
dftitanic['AgeCat']=''
dftitanic.loc[ dftitanic['Age'] <= 16, 'AgeCat'] = '0-16'
dftitanic.loc[(dftitanic['Age'] > 16) & (dftitanic['Age'] <= 32), 'AgeCat'] = '16-32'
dftitanic.loc[(dftitanic['Age'] > 32) & (dftitanic['Age'] <= 48), 'AgeCat'] = '32-48'
dftitanic.loc[(dftitanic['Age'] > 48) & (dftitanic['Age'] <= 64), 'AgeCat'] = '48-64'
dftitanic.loc[ dftitanic['Age'] > 64, 'AgeCat']= '64+'

# %%
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  18.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked FareCat       Title  \
# 0        0         A/5 21171   7.2500   NaN        S    0-10          Mr
# 1        0          PC 17599  71.2833   C85        C  70-100         Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0-10        Miss
# 3        0            113803  53.1000  C123        S   40-70         Mrs
# 4        0            373450   8.0500   NaN        S    0-10          Mr
# ..     ...               ...      ...   ...      ...     ...         ...
# 886      0            211536  13.0000   NaN        S   10-25  Rare Title
# 887      0            112053  30.0000   B42        S   25-40        Miss
# 888      2        W./C. 6607  23.4500   NaN        S   10-25        Miss
# 889      0            111369  30.0000  C148        C   25-40          Mr
# 890      0            370376   7.7500   NaN        Q    0-10          Mr
#
#     AgeCat
# 0    16-32
# 1    32-48
# 2    16-32
# 3    32-48
# 4    32-48
# ..     ...
# 886  16-32
# 887  16-32
# 888  16-32
# 889  16-32
# 890  16-32
#
# [891 rows x 15 columns]

# %% [markdown]
# ### 4.2 Embarkment and null values

# %%
dftitanic.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked FareCat Title  \
# count                       891   891     891      204      889     891   891
# unique                      891     2     681      147        3       6     5
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S    0-10    Mr
# freq                          1   577       7        4      644     325   517
#
#        AgeCat
# count     891
# unique      5
# top     16-32
# freq      490

# %%
dftitanic['Embarked'].isnull().sum()
# Out:
# 2

# %%
dftitanic.loc[(dftitanic['Embarked'].isnull()),'Embarked']='S'

# %% [markdown]
# ### 4.3 Dropping Cabin

# %% [markdown]
# Defining the cabin type

# %%
dftitanic['CabinType'] = dftitanic['Cabin'].str[0]
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  18.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked FareCat       Title  \
# 0        0         A/5 21171   7.2500   NaN        S    0-10          Mr
# 1        0          PC 17599  71.2833   C85        C  70-100         Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S    0-10        Miss
# 3        0            113803  53.1000  C123        S   40-70         Mrs
# 4        0            373450   8.0500   NaN        S    0-10          Mr
# ..     ...               ...      ...   ...      ...     ...         ...
# 886      0            211536  13.0000   NaN        S   10-25  Rare Title
# 887      0            112053  30.0000   B42        S   25-40        Miss
# 888      2        W./C. 6607  23.4500   NaN        S   10-25        Miss
# 889      0            111369  30.0000  C148        C   25-40          Mr
# 890      0            370376   7.7500   NaN        Q    0-10          Mr
#
#     AgeCat CabinType
# 0    16-32       NaN
# 1    32-48         C
# 2    16-32       NaN
# 3    32-48         C
# 4    32-48       NaN
# ..     ...       ...
# 886  16-32       NaN
# 887  16-32         B
# 888  16-32       NaN
# 889  16-32         C
# 890  16-32       NaN
#
# [891 rows x 16 columns]

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='CabinType', hue='Survived', data=dftitanic);

# %% [markdown]
# Dropping Cabin

# %%
dftitanic.groupby(['CabinType', 'Pclass'])['Pclass'].count()
# Out:
# CabinType  Pclass
# A          1         15
# B          1         47
# C          1         59
# D          1         29
#            2          4
# E          1         25
#            2          4
#            3          3
# F          2          8
#            3          5
# G          3          4
# T          1          1
# Name: Pclass, dtype: int64

# %%
dftitanic.drop('Cabin',axis=1,inplace=True)

# %%
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4            138         0       1
# ..           ...       ...     ...
# 886          885         0       3
# 887          887         0       2
# 888          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                          Futrelle, Mr. Jacques Heath    male  37.0      1
# ..                                                 ...     ...   ...    ...
# 886                             Sutehall, Mr. Henry Jr    male  25.0      0
# 887                              Montvila, Rev. Juozas    male  27.0      0
# 888                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked       Title  Fsize  Tsize  \
# 0        0         A/5 21171   7.2500        S          Mr      2      1
# 1        0          PC 17599  71.2833        C         Mrs      2      1
# 2        0  STON/O2. 3101282   7.9250        S        Miss      1      1
# 3        0            113803  53.1000        S         Mrs      2      2
# 4        0            113803  53.1000        S          Mr      2      2
# ..     ...               ...      ...      ...         ...    ...    ...
# 886      0   SOTON/OQ 392076   7.0500        S          Mr      1      1
# 887      0            211536  13.0000        S  Rare Title      1      1
# 888      0            112053  30.0000        S        Miss      1      1
# 889      0            111369  30.0000        C          Mr      1      1
# 890      0            370376   7.7500        Q          Mr      1      1
#
#      Group GrpSize FareCat AgeCat CabinType
# 0        2  couple    0-10  16-32       NaN
# 1        2  couple  70-100  32-48         C
# 2        1    solo    0-10  16-32       NaN
# 3        2  couple   40-70  32-48         C
# 4        2  couple   40-70  32-48         C
# ..     ...     ...     ...    ...       ...
# 886      1    solo    0-10  16-32       NaN
# 887      1    solo   10-25  16-32       NaN
# 888      1    solo   25-40  16-32         B
# 889      1    solo   25-40  16-32         C
# 890      1    solo    0-10  16-32       NaN
#
# [891 rows x 19 columns]

# %% [markdown]
# ## 5. Feature Selection

# %%
sns.set_context('poster')

# %%
sns.set_context('poster')
plt.figure(figsize=(20,5))
cor = dftitanic.drop('PassengerId',axis=1).corr()
sns.heatmap(cor, annot=True, fmt='.1g');

# %% [markdown]
# The heatmap above illustrates the correlation between different columns. Heatmaps are useful for visualizing correlations. Upon analyzing the heatmap, we can determine which attributes or columns are correlated and consider removing them to enhance the dataset's structure.
#
# Observations from the heatmap:
#
# - 'Group' has a correlation of 0.9 with both 'Fsize' and 'Tsize'. Consequently, we can eliminate 'Group' and 'Tsize' since 'GrpSize' contains related information.
# - 'Fsize' maintains a correlation of 0.9 with 'SibSp' and 0.8 with 'Parch'. Therefore, 'Fsize' is redundant, and we can remove it in favor of utilizing 'SibSp' and 'Parch.'
# - 'Name' can be safely dropped since 'Title' has already been extracted.
# - Similarly, 'Age' and 'Fare' can be removed, as 'AgeCat' and 'FareCat' offer relevant information.
#
# In summary, the columns to be dropped are: 'Name,' 'Age,' 'Fare,' 'Ticket,' 'Fsize,' 'Tsize,' and 'Group.

# %%
drop_features = ['Name','Age','Fare','Ticket','Fsize','Tsize','Group']

# %% [markdown]
# Selecting final features

# %%
dftitanic.drop(drop_features,axis=1,inplace=True)
dftitanic
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch Embarked       Title  \
# 0              1         0       3    male      1      0        S          Mr
# 1              2         1       1  female      1      0        C         Mrs
# 2              3         1       3  female      0      0        S        Miss
# 3              4         1       1  female      1      0        S         Mrs
# 4            138         0       1    male      1      0        S          Mr
# ..           ...       ...     ...     ...    ...    ...      ...         ...
# 886          885         0       3    male      0      0        S          Mr
# 887          887         0       2    male      0      0        S  Rare Title
# 888          888         1       1  female      0      0        S        Miss
# 889          890         1       1    male      0      0        C          Mr
# 890          891         0       3    male      0      0        Q          Mr
#
#     GrpSize FareCat AgeCat CabinType
# 0    couple    0-10  16-32       NaN
# 1    couple  70-100  32-48         C
# 2      solo    0-10  16-32       NaN
# 3    couple   40-70  32-48         C
# 4    couple   40-70  32-48         C
# ..      ...     ...    ...       ...
# 886    solo    0-10  16-32       NaN
# 887    solo   10-25  16-32       NaN
# 888    solo   25-40  16-32         B
# 889    solo   25-40  16-32         C
# 890    solo    0-10  16-32       NaN
#
# [891 rows x 12 columns]

# %% [markdown]
# Exporting final dataset in csv file
