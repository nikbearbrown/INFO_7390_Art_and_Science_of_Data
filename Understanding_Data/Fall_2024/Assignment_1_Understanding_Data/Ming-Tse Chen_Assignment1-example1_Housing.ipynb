# %% [markdown]
# # Comprehensive Guide to Exploratory Data Analysis (EDA)

# %% [markdown]
# # Understanding the Importance of EDA
#
# Exploratory Data Analysis (**EDA**) is a crucial step in working with data. It helps us **discover patterns, detect unusual values (outliers), and understand relationships** between different variables. Instead of immediately jumping into complex models, EDA allows us to explore the data first, making sure we understand its structure before making decisions.
#
# By using **EDA techniques** such as **visualizations, statistics, and data transformations**, analysts can uncover **hidden insights** that are not immediately visible. These insights **guide further research** and help in forming better questions and hypotheses.
#
#   <div style="text-align:center">
#     <img src="https://cdn.educba.com/academy/wp-content/uploads/2020/01/exploratory-data-analysis.jpg" alt="Image Alt Text" width="900"/>
# </div>
#
#
# # Why is EDA Important?
# 📌 **Find Relationships Between Variables**
# EDA helps us see how different data points are connected. For example, in an **insurance dataset**, we might find that **smokers tend to have higher insurance claims** compared to non-smokers.
#
# 📌 **Detect Trends Over Time**
# If we are analyzing sales data, EDA can show us **seasonal trends**, such as higher sales during holidays or weekends.
#
# 📌 **Identify Outliers (Unusual Data Points)**
# EDA helps us **spot errors or rare events** in the data. For example, if an insurance claim is **10 times higher** than normal, it might be due to a mistake or a special case that needs further investigation.
#
# 📌 **Ensure Data Quality**
# EDA helps us check if the data is **complete, accurate, and reliable**. If some values are missing or incorrect, we can fix them before using the data for deeper analysis.
#
# 📌 **Support Better Decision-Making**
# By **visualizing data** with charts and graphs, decision-makers can understand the information more easily and make **data-driven choices** instead of relying on guesses.
#
# ## How is EDA Performed?
#
# EDA involves a few **fundamental steps**, as shown in the image below:
#
#   <div style="text-align:center">
#     <img src="https://dataexpertise.in/wp-content/uploads/2023/10/EDA-Process-768x408.jpg" alt="Image Alt Text" width="900"/>
# </div>
#
# 1️⃣ **Data Collection**: Gather the dataset from reliable sources.
#
# 2️⃣ **Data Cleaning**: Remove errors, missing values, or duplicate records.
#
# 3️⃣ **Data Visualization**: Use charts, graphs, and tables to understand trends.
#
# 4️⃣ **Statistical Analysis**: Summarize key numbers (such as averages, minimums, and maximums).
#
# 5️⃣ **Finding Outliers & Patterns**: Look for unusual values or unexpected trends.
#
# 6️⃣ **Drawing Insights**: Use the findings to make better decisions or prepare for further analysis.

# %% [markdown]
# # Why is Exploratory Data Analysis (EDA) Interesting?
#
# Exploratory Data Analysis (**EDA**) is more than just working with numbers; it's about **uncovering the story behind the data**. Think of it as a detective investigating a case or an archaeologist discovering hidden artifacts. EDA helps us **explore, understand, and interpret data** before making important decisions or building models. Instead of blindly using data, we take the time to examine it carefully, ensuring it is accurate and meaningful.
#
#
# ## 🔍 Discovering Patterns
# EDA helps us **find patterns** that might not be obvious at first glance. For example, if we are analyzing customer purchase history, we might notice that **people buy more products during holidays**. Recognizing these patterns helps businesses plan better strategies and make informed decisions.
#
# ## 🚨 Spotting Unusual Data (Anomalies)
# Sometimes, data contains **errors or unusual values (outliers)**. Imagine checking sales records and noticing one order that is **ten times higher** than normal. Is it a mistake? A big client? A fraud attempt? EDA helps us **identify these oddities** and decide what to do with them.
#
# ## 📊 Supporting Better Decisions
# EDA acts like a **compass** for decision-makers. Instead of making guesses, we use **charts, graphs, and statistics** to understand what the data is telling us. For example, a business might want to know which product is the most popular—EDA can provide **clear visualizations** to support this decision.
#
# ## ✅ Checking Data Quality
# Data is not always perfect. Sometimes, we find **missing, incorrect, or inconsistent values**. EDA helps us check and clean the data before using it. This ensures that our analysis and decisions are based on **reliable information** rather than faulty or misleading data.
#
# ## 🎯 Choosing the Right Features
# In large datasets, not all information is useful. Some variables might be irrelevant or add unnecessary complexity. EDA helps us **identify the most important factors** so that we can focus on what truly matters. For instance, in predicting house prices, we might find that the number of bedrooms is important, but the color of the walls is not.
#
# ## 📢 Making Data Understandable
#
# Numbers alone can be overwhelming, but EDA turns them into **meaningful insights**. Through **visualizations and summaries**, we can **tell a story** with data that is easy for everyone—whether technical experts or business leaders—to understand. A well-crafted EDA can **bring data to life** and help communicate important findings in a clear and engaging way.

# %% [markdown]
# # To understand EDA ... Let's first Understand What is Data & it's types ?

# %% [markdown]
# ### Understanding Data
#
# #### Data is a collection of basic facts, numbers, or details gathered from different sources and stored in an organized or unorganized way. It can be numbers, words, images, sounds, or even actions. Data is like a collection of facts that help us understand things better.
#
# #### Data can be virtually anything that can be recorded or observed, including text, numbers, images, sounds, and more.
#
#
#
# <div style="text-align:center">
#     <img src="https://blog.neterra.cloud/wp-content/uploads/2019/02/data-1-1024x576.jpg" alt="Image Alt Text" width="800"/>
# </div>
#
#
#
# ### Types of Data
#
# <div style="text-align:center">
#     <img src="https://365datascience.com/resources/blog/thumb@1024_xzk3rl06exk-data-types.webp" alt="Image Alt Text" width="800"/>
# </div>
#
#
# #### We all know by now that data comes in various forms, here are some them :

# %% [markdown]
# ### 1️⃣ Qualitative (Categorical) Data
# Categorical data represents characteristics, labels, or groups that do not have numerical meaning. It can be further divided into:
#
# #### 🏆 Ordinal Data (Ordered)
# Data that has a meaningful order but the difference between values is not precisely measurable.
# Example: Test grades (A, B, C, D, F)

# %%
import pandas as pd

grades = pd.Categorical(["A", "B", "C", "D", "F"], ordered=True)
print(grades)
# Out:
# ['A', 'B', 'C', 'D', 'F']
# Categories (5, object): ['A' < 'B' < 'C' < 'D' < 'F']

# %% [markdown]
# #### 🌍 Nominal Data (Not Ordered)
# Data that represents labels or categories with no inherent order.
# Example: Nationality (American, French, Indian)

# %%
# Example of Nominal Data in Python
nationalities = ["American", "French", "Indian", "Chinese"]
print(nationalities)
# Out:
# ['American', 'French', 'Indian', 'Chinese']

# %% [markdown]
# ### 2️⃣ Quantitative Data
# Quantitative data consists of numerical values that can be measured. It is classified into:
#
# #### 📏 Continuous Data (Can Be Divided)
# Data that can take any value within a range.
# Example: Distance (e.g., 5.3 km, 10.8 km)

# %%
# Example of Continuous Data in Python
distances = [5.3, 10.8, 12.5, 20.4]
print(distances)
# Out:
# [5.3, 10.8, 12.5, 20.4]

# %% [markdown]
# #### 🐱 Discrete Data (Can't Be Divided)
# Whole numbers that represent countable values.
# Example: Number of cats (1, 2, 3, 4)

# %%
# Example of Discrete Data in Python
num_cats = [1, 2, 3, 4, 5]
print(num_cats)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # Now Let's learn about data quality and how it plays a crucial role in building or analyzing applications

# %% [markdown]
# ## 📌 Understanding Data Quality

# %% [markdown]
# ### 🧐 What is Data Quality and Why Does It Matter?
#
# Data quality refers to how accurate, complete, reliable, and consistent the data is. High-quality data is essential because it helps in making **better decisions, accurate predictions**, and **efficient business operations**. If the data is poor or incorrect, it can cause **errors, misleading analysis, and financial losses**.

# %% [markdown]
# ### ✅ Why is Good Data Quality Important?
#
# 1️⃣ **Better Decision-Making**: Reliable data ensures that businesses and researchers make informed choices.
#
# 2️⃣ **Avoiding Errors**: Incorrect data can lead to poor strategies, miscommunication, or financial losses.
#
# 3️⃣ **Improved Efficiency**: Clean and organized data saves time in analysis and prevents unnecessary confusion.

# %% [markdown]
# ### 📌 Examples of Data Quality Issues
#
# 🔹 **Misleading Information**: If we include Michael Jordan's basketball earnings in a dataset about average salaries of college graduates, the data would be misleading and not reflect a typical graduate's salary.
#
# 🔹 **Duplicate Data**: When analyzing customer feedback, duplicate reviews can create bias, making one opinion seem more important than it really is. Cleaning the data ensures a fair and accurate analysis.
#
# 🔹 **Outdated Information**: A company with outdated customer contact details may struggle to reach its clients, resulting in missed opportunities and lost revenue.

# %% [markdown]
# ### 🔍 Ensuring Data Quality
#
# To maintain high data quality, we can:
#
# 1. Remove duplicate or outdated records
#
# 2. Verify data accuracy before using it
#
# 3. Fill in missing values appropriately
#
# 4. Ensure consistency across different datasets
#
# By ensuring high-quality data, we can **trust our analysis, make better decisions, and achieve successful outcomes**.

# %% [markdown]
# <div style="text-align:center">
#     <img src="https://eu-images.contentstack.com/v3/assets/blt69509c9116440be8/blte7047f8cc765f86a/64cb4939b03b1f4a6b0714bd/dataquality.jpg" alt="Image Alt Text" width="600"/>
# </div>

# %% [markdown]
# # 🛠️ Assessing Data Quality and Cleaning for Better Analysis
#
# ### 🔍 How Can We Assess Data Quality?
#
# Assessing data quality is an important step before using data for decision-making, analysis, or machine learning. **Data cleaning** plays a key role in this process, as it helps identify and fix errors, inconsistencies, and missing values. By cleaning data, we ensure that it is **accurate, reliable, and consistent**, leading to better insights and results.

# %% [markdown]
# ## 🧹 What is Data Cleaning?
#
# **Data Cleaning** is the process of **finding and fixing mistakes in data** to improve its quality. This step ensures that the data is ready for use in analysis and machine learning models. **Good data leads to better decisions, predictions, and business strategies.**
#
# Data cleaning involves:
#
# 1. **Fixing errors** (typos, incorrect entries, wrong formats)
#
# 2. **Removing duplicates** (repeated data entries)
#
# 3. **Handling missing values** (filling or removing incomplete data)
#
# 4. **Standardizing formats** (making data uniform)
#
# 5. **Identifying and addressing outliers** (extreme values that may distort results)
#
# ## ✨ Why is Data Cleaning Important? (With Examples)
#
# ✅ **Consistency**
#
# Ensuring that all data follows the same format helps in easy comparison and analysis.
#
# Example: Converting timestamps to a common format for consistency:

# %%
# Original timestamps
timestamps = ["2023-01-15 08:30:45", "15-01-2023"]

# Standardized format (YYYY-MM-DD)
standardized_timestamps = ["2023-01-15", "2023-01-15"]

# %% [markdown]
# ## 🚀 Handling Outliers
#
# Outliers (extreme values) can distort results, so they should be carefully reviewed before including them in analysis.
#
# Example: If a dataset on school graduate salaries includes a celebrity's earnings, it may falsely increase the average.

# %%
# Salaries dataset
salaries = [50000, 55000, 60000, 70000000] # Outlier present

# Excluding outlier for accurate analysis
filtered_salaries = [50000, 55000, 60000]

# %% [markdown]
# ## 🔄 Removing Duplicates
#
# Duplicate records can skew analysis, so they should be removed.
#
# Example: If user reviews are repeated in a sentiment analysis dataset, it could lead to biased results.

# %%
# Original dataset with duplicate reviews
reviews = ["Great product!", "Bad service", "Great product!", "Excellent quality"]

# Removing duplicates
unique_reviews = list(set(reviews))

# %% [markdown]
# ## 🎯 Ensuring Accuracy
#
# Cross-checking data with reliable sources helps maintain correctness.
#
# Example: Validating sales figures by comparing them with financial records.

# %%
# Sales figures from different sources
reported_sales = 10000
actual_sales = 9800  # Verified from financial records

# Checking accuracy
if reported_sales == actual_sales:
    print("Data is accurate")
else:
    print("Data needs correction")
# Out:
# Data needs correction

# %% [markdown]
# ## 📉 Treating Missing Values
#
# Filling missing values ensures that the dataset remains useful for analysis.
#
# Example: Replacing missing age values with the average age.

# %%
import numpy as np

ages = [25, 30, np.nan, 22, 28, np.nan, 35]
mean_age = np.nanmean(ages)  # Calculate mean ignoring NaN values
cleaned_ages = [age if not np.isnan(age) else mean_age for age in ages]

# %% [markdown]
# ## 🔍 Exploratory Data Analysis (EDA) in Cleaning
#
# EDA helps detect errors, patterns, and unusual data points.
#
# Example: Visualizing a histogram may reveal unexpected spikes or missing values.

# %%
import matplotlib.pyplot as plt

# Example data
ages = [22, 23, 24, 22, 21, 80]  # Outlier present

# Plot histogram
plt.hist(ages, bins=5)
plt.show()

# %% [markdown]
# ## ⚖️ Normalization
#
# Scaling numeric data ensures fair comparisons across variables.
#
# Example: Normalizing income and age values to a common scale.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data = [[50000], [60000], [100000]]  # Income values
normalized_data = scaler.fit_transform(data)
print(normalized_data)
# Out:
# [[0. ]
#  [0.2]
#  [1. ]]

# %% [markdown]
# ## 🔢 Encoding Categorical Data
#
# Converting text labels into numbers allows models to process them.
#
# Example: Encoding color categories into numerical values.

# %%
from sklearn.preprocessing import LabelEncoder

colors = ["Red", "Green", "Blue"]
encoder = LabelEncoder()
numeric_colors = encoder.fit_transform(colors)
print(numeric_colors)
# Out:
# [2 1 0]

# %% [markdown]
# # 🚀 Exploring Exploratory Data Analysis (EDA)
#
# Since we now recognize the importance of EDA in evaluating and refining data quality, let's take a deeper look. We will now explore EDA in detail to understand how it uncovers patterns, identifies trends, and extracts valuable insights to enhance data-driven decision-making.

# %% [markdown]
# ## 📊 What is Exploratory Data Analysis (EDA)?

# %% [markdown]
# Exploratory Data Analysis, or **EDA**, is a key step in understanding a dataset before applying complex models or statistical tests. It involves using **visualizations, summary statistics, and hypothesis testing** to uncover insights and detect potential issues in the data.
#
# ## 🔍 Goals of EDA:
#
# 1️⃣ **Summarize the dataset** to get an overview of its structure.
#
# 2️⃣ **Identify patterns and relationships** between different variables.
#
# 3️⃣ **Spot outliers, missing data, and class imbalances** to ensure data quality.
#
# 4️⃣ **Connect the data with business goals**, ensuring relevant insights are extracted for decision-making.
#
# By performing EDA, we can make informed decisions about data preparation, feature selection, and modeling techniques, leading to more effective and reliable analyses.

# %% [markdown]
# ## 📌 Key Techniques in EDA

# %% [markdown]
# EDA combines both **graphical and statistical** techniques to explore and understand data effectively:
#
# 1️⃣ **Descriptive Statistics** - Summarizes key features of data using measures like mean, median, mode, range, and standard deviation.
#
# Example: Calculating average monthly sales to understand business trends.
#
# 2️⃣ **Data Visualization** - Uses charts such as histograms, box plots, and scatter plots to reveal patterns and relationships.
#
# Example: A histogram displaying customer purchase frequency over time.
#
# 3️⃣ **Identifying Outliers** - Detects extreme values that could indicate errors or unique insights.
#
# Example: Spotting an unusually high transaction amount that might suggest fraud.
#
# 4️⃣ **Examining Relationships** - Measures correlations between variables using statistical techniques like correlation coefficients and cross-tabulations.
#
# Example: Analyzing if higher marketing spend correlates with increased sales.
#
# 5️⃣ **Group Comparisons** - Compares data across different groups to find patterns.
#
# Example: Comparing average exam scores across multiple schools to evaluate educational performance.

# %% [markdown]
# ### 📖 Understanding the Theory Behind EDA

# %% [markdown]
# Exploratory Data Analysis (EDA) was introduced by John W. Tukey as a flexible and interactive approach to exploring data before applying complex statistical models. EDA focuses on summarizing the main features of a dataset, uncovering patterns, detecting anomalies, and verifying assumptions to ensure accurate analysis.
#
#
#
# Using descriptive statistics, visualizations, and correlation analysis, EDA helps in understanding data relationships, selecting important variables, cleaning data, and recognizing meaningful patterns.
#
#
#
# This exploratory phase plays a crucial role in helping analysts gain valuable insights and make data-driven decisions before proceeding with formal statistical modeling or machine learning techniques.

# %% [markdown]
# ## 🔢 Basics of Algorithms and Problem Design in EDA

# %% [markdown]
# ## 1️⃣ Algorithm Design
#
# Unlike machine learning models, EDA does not rely on a specific algorithm. Instead, it consists of **various techniques and workflows** used to explore and understand data. These techniques include **data transformation tools, visualization methods, and statistical summaries**. In EDA, an "algorithm" is better described as a **structured approach** that guides data exploration and analysis.
#
# ## 2️⃣ Problem Formulation
#
# The first step in EDA is to **define the problem** that needs exploration. This involves setting **clear objectives, research questions, and hypotheses** that will guide the analysis. Unlike traditional mathematical problem-solving, EDA focuses on **contextual exploration** rather than defining rigid computational problems.
#
# By following these principles, EDA ensures that **data-driven insights are meaningful, reliable, and aligned with business or research objectives.**

# %% [markdown]
# ### 🎯 The Relevance of Custom Problem Creation in Teaching and Assessing Knowledge

# %% [markdown]
# Custom problem creation plays a crucial role in teaching and evaluating knowledge in EDA for several reasons:
#
# #### 🔍 Contextual Learning
#
# Custom problems help integrate real-world scenarios into learning. Students work with datasets that match their interests or career goals, making learning more relevant and engaging.
#
# #### ✨ Hands-On Exploration
#
# Through customized problems, students get practical experience in analyzing various datasets. This hands-on approach deepens their understanding of EDA techniques.
#
# #### 🧠 Critical Thinking Development
#
# Unique and tailored problems encourage students to think critically and develop problem-solving skills, improving their ability to extract meaningful insights from data.
#
# #### 📊 Assessment Alignment
#
# Custom problems ensure that assessments accurately measure students' understanding and proficiency in EDA techniques.
#
# #### 🔄 Feedback and Iteration
#
# Custom problems allow for personalized feedback and iterative learning. Instructors can provide targeted guidance, helping students strengthen their skills.
#
# #### 🚀 Preparation for Real-World Challenges
#
# Engaging with customized problems prepares students for real-world data analysis, equipping them with the confidence to handle complex datasets and extract valuable insights.
#
# Custom problem creation is a powerful tool in EDA education, fostering **proficiency, adaptability, and problem-solving capabilities** in aspiring data analysts.

# %% [markdown]
# ## 🔢 Leveraging ChatGPT for Exploratory Data Analysis

# %% [markdown]
# Using tools like **ChatGPT** in the context of Exploratory Data Analysis (EDA) provides significant benefits by offering an **interactive learning experience** where users can:
#
# 1. **Clarify concepts** and get instant explanations on EDA techniques.
#
# 2. **Seek assistance** in code implementation for data exploration.
#
# 3. **Generate custom EDA scenarios** tailored to specific learning objectives.
#
# ### ✨ How ChatGPT Enhances EDA:
#
# 1️⃣ **Real-time Guidance**: Acts as an on-demand assistant, answering queries on data cleaning, visualization, and statistical analysis.
#
# 2️⃣ **Custom Problem Generation**: Helps create real-world data scenarios to practice EDA skills in a meaningful way.
#
# 3️⃣ **Accessibility for All Learners**: Its natural language interface makes EDA approachable for beginners and advanced users alike.
#
# 4️⃣ **Encouraging Continuous Learning**: Facilitates idea generation and exploration, enabling analysts to gain deeper insights into datasets.
#
# By incorporating ChatGPT into EDA workflows, users can make data analysis **more interactive, efficient, and insightful**, ultimately fostering a **dynamic approach** to data exploration and decision-making.

# %% [markdown]
# # 🏡 Implementing EDA Using the Housing Dataset
#
# ## 📌 Loading and Exploring the Dataset
#
# ### **🔹 Why Perform EDA?**
# Exploratory Data Analysis (EDA) helps in:
# - Understanding data distribution
# - Identifying missing or inconsistent values
# - Detecting patterns & relationships between variables
# - Preparing data for machine learning models
#
# ---
#
# ### **📌 Dataset Description**
# This dataset contains **545 rows** and **13 columns**, describing various attributes of houses, including:
# - **price**: House price in INR
# - **area**: Total area of the house
# - **bedrooms, bathrooms, stories**: House structure
# - **mainroad, guestroom, basement, hotwaterheating, airconditioning**: Binary features indicating house facilities
# - **parking**: Number of parking spaces
# - **prefarea**: Preferred locality
# - **furnishingstatus**: Status of house furnishing (Furnished, Semi-Furnished, Unfurnished)
#
# ---
#
# ## 📊 **Basic Statistical Summary**
# We use `.describe()` to get insights into numeric features:
#
# - **Mean (Average):** The central value of each feature.
# - **Standard Deviation:** The measure of spread or variation in the data.
# - **Minimum and Maximum Values:** The range of data values.
# - **Quartiles (25%, 50%, 75%):** Helps understand the distribution of data.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
housing_file_path = "Housing.csv"  # Ensure the correct file path
housing_df = pd.read_csv(housing_file_path)

# Display basic dataset info
print("📌 Dataset Information:\n")
housing_df.info()

# Display first few rows
print("\n📌 First Five Rows:\n")
display(housing_df.head())

# Basic statistical summary
print("\n📊 Basic Statistical Summary:\n")
display(housing_df.describe())

# Count of unique values for categorical columns
categorical_cols = ["mainroad", "guestroom", "basement", "hotwaterheating", "airconditioning", "prefarea", "furnishingstatus"]
print("\n📌 Unique Value Counts for Categorical Features:\n")
for col in categorical_cols:
    print(f"{col}:")
    print(housing_df[col].value_counts(), "\n")
# Out:
# 📌 Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB
#
# 📌 First Five Rows:
# ...

# %% [markdown]
# ### 🔹 Basic Statistical Summary
# The describe() function provides key summary statistics of the dataset, including:
#
# **Mean (Average)**: The central value of each feature.
#
# **Standard Deviation**: The measure of spread or variation in the data.
#
# **Minimum and Maximum Values**: The range of data values.
#
# **Quartiles (25%, 50%, 75%)**: Helps understand the distribution of data.

# %%
housing_df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ## 📊 Visualizing Feature Distributions
#
# A histogram helps us visualize the distribution of house prices. The **Kernel Density Estimate (KDE)** curve overlaid on the histogram provides insights into **skewness** and **outliers** in the data.
#
# ---
#
# ### **📌 Key Observations:**
# 1. The house prices **are right-skewed**, meaning there are more houses in the lower price range.
# 2. A few **higher-priced houses** create a long tail, suggesting the presence of **luxury or premium properties**.
# 3. **Most houses fall within the lower and mid-price range**, indicating affordability.
#
# This distribution helps us determine if **data transformations** (like log transformation) are needed before modeling.
#
# ---

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of house prices
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['price'], bins=30, kde=True, color="blue")
plt.xlabel("House Prices (INR)")
plt.ylabel("Frequency")
plt.title("Distribution of House Prices")
plt.show()

# %% [markdown]
# ## 📊 Insights from the House Price Distribution Plot
#
# 1. **Right-Skewed Distribution**
#    - The distribution of house prices is **positively skewed**, meaning there are **more houses in the lower price range**.
#    - A few **high-priced houses create a long tail**, suggesting the presence of **luxury properties**.
#
# 2. **Most Houses Fall in the Affordable Range**
#    - The majority of houses are priced between **₹20 lakhs to ₹80 lakhs (INR)**.
#    - There is a **gradual decline** in the number of houses as price increases.
#
# 3. **Presence of High-Value Outliers**
#    - Some properties exceed **₹1 crore (INR)**, which might indicate **premium or luxury homes**.
#    - These high-priced houses might affect statistical analysis and **require outlier treatment**.
#
# 4. **Potential Need for Data Transformation**
#    - Due to the **skewed nature of the distribution**, applying a **log transformation** on house prices could help normalize the data.
#    - A **normalized distribution** is useful for **predictive modeling and regression analysis**.

# %% [markdown]
# ## 📊 Data Visualization in Exploratory Data Analysis (EDA)
#
# Visualizing data is an essential part of **Exploratory Data Analysis (EDA)** as it helps in understanding the underlying patterns, distributions, and relationships between different variables. Below are some key visualization techniques commonly used in EDA.

# %% [markdown]
# # 📊 Data Visualization in Exploratory Data Analysis (EDA)
#
# Visualizing data is an essential part of **Exploratory Data Analysis (EDA)** as it helps in understanding the underlying patterns, distributions, and relationships between different variables. Below are some key visualization techniques commonly used in EDA.
#
# ---
#
# ## 📈 Histograms: Understanding Data Distribution
#
# ### **Definition:**
# A histogram is a graphical representation that shows the **distribution of numerical data** by dividing the range into bins and counting the number of values that fall into each bin.
#
# ### **Why Use It?**
# ✔ Helps in understanding the **shape of the data** (e.g., normal distribution, skewness).
# ✔ Identifies **peaks, trends, and potential outliers**.
# ✔ Provides insights into **data spread and density**.
#
# ---
#
# ### **📌 Example: Histogram of House Prices**
#
# We visualize **house price distribution** to analyze how frequently different price ranges occur in the dataset.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of house prices
plt.figure(figsize=(8, 6))
sns.histplot(housing_df['price'], bins=30, kde=True, color="skyblue", edgecolor="black")
plt.xlabel("House Price (INR)")
plt.ylabel("Frequency")
plt.title("Histogram of House Prices")
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Histogram
#
# ✔ **Right-Skewed Distribution**
#    - The histogram shows that house prices **are not normally distributed** but **positively skewed**.
#    - Most houses are in the **lower price range**, while a few **high-value properties create a long tail**.
#
# ✔ **Presence of High-Value Outliers**
#    - The data includes **some very expensive houses**, indicating the presence of **luxury properties**.
#    - These extreme values might **affect model performance** and could require outlier handling.
#
# ✔ **Most Houses Are in the Affordable Range**
#    - The majority of houses fall between **₹20 lakhs to ₹80 lakhs (INR)**, suggesting affordability for middle-income buyers.
#
# ✔ **Potential Need for Data Transformation**
#    - Due to the **skewness**, a **log transformation** of house prices might help **normalize** the data for better predictive modeling.

# %% [markdown]
# # 📊 Box Plots: Identifying Outliers and Spread of Data
#
# ### **Definition:**
# A **box plot** (also called a **box-and-whisker plot**) summarizes numerical data using five key metrics:
# - **Minimum** (Lowest value excluding outliers)
# - **First Quartile (Q1)** (25th percentile)
# - **Median (Q2)** (50th percentile, middle value)
# - **Third Quartile (Q3)** (75th percentile)
# - **Maximum** (Highest value excluding outliers)
#
# It also highlights **outliers** as individual points outside the whiskers.
#
# ---
#
# ### **📌 Why Use Box Plots?**
# ✔ **Quickly identifies outliers**.
# ✔ **Shows the spread and skewness** of the data.
# ✔ **Helps compare distributions** across different variables.
#
# ---
#
# ### **📌 Example: Box Plot of House Prices**
# We visualize the **spread and outliers** in house prices using a box plot.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the box plot for house prices to identify outliers
plt.figure(figsize=(8, 6))
sns.boxplot(y=housing_df['price'], color="lightgreen")
plt.title("Box Plot of House Prices")
plt.ylabel("Price (INR)")
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Box Plot
#
# ✔ **Most House Prices Fall Between ₹30 Lakhs to ₹70 Lakhs (INR)**
#    - The **Interquartile Range (IQR)** (middle 50% of the data) represents **affordable housing**.
#
# ✔ **Presence of High-Value Outliers**
#    - There are **luxury properties exceeding ₹1 crore (INR)**.
#    - These **outliers could impact predictive modeling** and might need handling.
#
# ✔ **Potential Data Cleaning Step**
#    - **Outlier treatment** (e.g., removing or capping extreme values) could **improve data quality**.
#    - A **log transformation on price** may help **normalize the data**.

# %% [markdown]
# # 📈 Scatter Plots: Finding Relationships Between Variables
#
# ### **Definition:**
# A scatter plot is used to visualize the **relationship between two numerical variables**.
# Each point represents an observation in the dataset.
#
# ---
#
# ### **📌 Why Use Scatter Plots?**
# ✔ **Identifies correlations** between variables (positive, negative, or none).
# ✔ **Helps detect clusters and patterns** in the data.
# ✔ **Highlights possible outliers**.
#
# ---
#
# ### **📌 Example: Scatter Plot of House Prices vs. Area**
# We visualize the **relationship between house area (sq. ft) and price (INR)** using a scatter plot.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot: Relationship between house price and area
plt.figure(figsize=(8, 6))
sns.scatterplot(x=housing_df['area'], y=housing_df['price'], color="coral", alpha=0.5)
plt.xlabel("House Area (sq. ft)")
plt.ylabel("House Price (INR)")
plt.title("Scatter Plot of House Prices vs. Area")
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Scatter Plot
#
# ✔ **Positive Correlation Between Area and Price**
#    - Larger houses **tend to have higher prices**, as expected.
#    - However, there are some **exceptions** where smaller houses are priced higher.
#
# ✔ **Presence of Outliers**
#    - Some properties have **high prices despite smaller areas**, suggesting premium locations or high-end amenities.
#    - Some **large houses are priced lower**, possibly due to location factors.
#
# ✔ **Potential Data Transformation**
#    - The **relationship is not strictly linear**, meaning **feature engineering** (e.g., polynomial features or categorical encoding for location) might help improve predictive modeling.

# %% [markdown]
# # 📈 Line Plots: Analyzing Trends Over Time or Sequential Data
#
# ### **Definition:**
# A line plot is used to **display data trends** over time or a sequence, making it useful for **time series analysis**.
#
# ---
#
# ### **📌 Why Use Line Plots?**
# ✔ **Identifies trends, seasonality, and fluctuations** in data.
# ✔ **Shows how house prices change** over a sequential index.
# ✔ **Highlights price trends**, whether increasing, decreasing, or fluctuating.
#
# ---
#
# ### **📌 Example: Line Plot of House Prices Over the Index**
# We visualize **house prices over the dataset index** to analyze trends and fluctuations.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Plot a line plot for house prices over index to analyze trends
plt.figure(figsize=(10, 5))
plt.plot(housing_df['price'], color="purple")
plt.xlabel("Index")
plt.ylabel("House Price (INR)")
plt.title("Line Plot of House Prices Over the Index")
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Line Plot
#
# ✔ **House Prices Show a General Downward Trend**
#    - The graph indicates that **prices are sorted in descending order**, which means it is not a time series dataset but a ranked one.
#
# ✔ **Higher Prices Are More Dispersed**
#    - The most expensive houses are at the start of the index, and the price drops gradually.
#
# ✔ **Not a True Time-Series Analysis**
#    - Since the dataset does not have a **date or time variable**, this line plot represents a **sequential ranking of prices** rather than a temporal trend.
#
# ✔ **Next Steps for Better Analysis**
#    - If a **timestamp or year column** was available, we could analyze real-world price fluctuations over time.
#    - To **detect real trends**, we might need **location-based or time-based data**.

# %% [markdown]
# # 📊 Bar Charts: Representing Categorical Data
#
# ### **Definition:**
# A bar chart is used to visualize the **frequency of categorical variables** by representing them with bars of varying heights.
#
# ---
#
# ### **📌 Why Use Bar Charts?**
# ✔ **Best for comparing categorical data.**
# ✔ **Highlights dominant categories and distributions.**
# ✔ **Easy to interpret and visually appealing.**
#
# ---
#
# ### **📌 Example: Bar Chart of House Price Categories**
# We categorize **house prices into price ranges** and visualize their distribution.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd

# Create bins for house price categories
bins = [0, 5000000, 10000000, 15000000, 20000000, 30000000]
labels = ['0-50L', '50L-1Cr', '1Cr-1.5Cr', '1.5Cr-2Cr', '2Cr+']
housing_df['Price_Category'] = pd.cut(housing_df['price'], bins=bins, labels=labels)

# Count occurrences of each price category
price_counts = housing_df['Price_Category'].value_counts().sort_index()

# Plot the bar chart
plt.figure(figsize=(8, 6))
plt.bar(price_counts.index.astype(str), price_counts.values, color="lightcoral")
plt.xlabel("House Price Categories")
plt.ylabel("Count")
plt.title("Bar Chart of House Price Categories")
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Bar Chart
#
# ✔ **Majority of Houses Fall in the Lower Price Range**
#    - Most houses are priced between **₹0 - ₹50L (INR)**.
#    - The number of houses **significantly decreases** as prices increase.
#
# ✔ **Very Few High-Value Properties**
#    - Houses priced **above ₹2Cr** are **extremely rare**, making them outliers in this dataset.
#
# ✔ **Imbalanced Price Distribution**
#    - The market is **dominated by mid-range properties** between **₹50L - ₹1Cr**, indicating high demand.
#
# ✔ **Potential Implications for Real Estate Analysis**
#    - Understanding **price category distribution** can help developers and buyers **target the right market segments**.

# %% [markdown]
# # 📊 Heatmaps: Visualizing Relationships Between Variables
#
# ### **Definition:**
# A heatmap is a **graphical representation of correlations** between numerical variables using color intensity.
# This is particularly useful for **correlation analysis** to uncover patterns in large datasets.
#
# ---
#
# ### **📌 Why Use Heatmaps?**
# ✔ **Identifies Strong & Weak Correlations** – Highlights positive and negative relationships between features.
# ✔ **Detects Multicollinearity** – Helps identify redundant features that may impact model performance.
# ✔ **Aids in Feature Selection** – Determines which variables to include in predictive models.
# ✔ **Provides a Holistic View of Data Relationships** – Easy-to-interpret visualization.
#
# ---
#
# ### **📌 Example: Heatmap of the Correlation Matrix**
# We analyze **how different features in the housing dataset relate to price and other factors**.

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns for correlation analysis
numeric_cols = housing_df.select_dtypes(include=["float64", "int64"]).columns

# Compute correlation matrix
corr_matrix = housing_df[numeric_cols].corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Correlation Heatmap
#
# ✔ **Price Correlates Strongly with Area, Bathrooms, and Stories**
#    - **Area (0.54):** Larger houses tend to have **higher prices**.
#    - **Bathrooms (0.52):** Houses with more bathrooms are typically **more expensive**.
#    - **Stories (0.42):** Multi-story homes tend to **cost more**.
#
# ✔ **Bedrooms Have a Moderate Correlation with Price (0.37)**
#    - More bedrooms **slightly increase price**, but not as significantly as area or bathrooms.
#
# ✔ **Parking and Stories Show Weak Correlation with Price (0.38, 0.42)**
#    - **Parking spaces have a weak effect on price**, possibly due to location dependency.
#    - **Multi-story homes tend to be more expensive**, but the correlation is weaker than expected.
#
# ✔ **Multicollinearity Detection**
#    - **Bathrooms and Area are somewhat correlated (0.52)** – might indicate that **larger homes naturally have more bathrooms**.
#    - **Bedrooms and Bathrooms (0.37)** – Additional bedrooms may often come with extra bathrooms.
#
# ✔ **Feature Engineering Opportunity**
#    - **Combining moderately correlated features** (like bedrooms and bathrooms) could improve model performance.

# %% [markdown]
# # 📊 Pair Plots: Visualizing Relationships Between Variables
#
# ### **Definition:**
# A **pair plot** (also known as a **scatterplot matrix**) shows **pairwise relationships** between multiple numerical variables.
# It helps in detecting **trends, clusters, correlations, and outliers**.
#
# ---
#
# ### **📌 Why Use Pair Plots?**
# ✔ **Identifies relationships between multiple numerical variables**.
# ✔ **Detects potential correlations and trends in the data**.
# ✔ **Reveals clusters, trends, and anomalies**.
#
# ---
#
# ### **📌 Example: Pair Plot of House Features vs. Price**
# We visualize **house area, bedrooms, bathrooms, and price** to identify key relationships.

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Generate a pair plot for selected features: Area, Bedrooms, Bathrooms, and Price
selected_features = ["area", "bedrooms", "bathrooms", "price"]

# Create pair plot
sns.pairplot(housing_df[selected_features], diag_kind="hist", plot_kws={"color": "orange"})
plt.suptitle("Pair Plot of Selected Features", y=1.02)
plt.show()

# %% [markdown]
# ## 🔍 Insights from the Pair Plot
#
# ✔ **Positive Correlation Between House Area and Price**
#    - Larger houses **tend to have higher prices**.
#    - The scatter plot indicates **a fairly linear trend** between **area and price**.
#
# ✔ **Bedrooms and Bathrooms Have Limited Influence on Price**
#    - Unlike area, **bedrooms and bathrooms show weaker correlations with price**.
#    - This suggests that **larger houses matter more than just the number of rooms**.
#
# ✔ **Most Houses Have 2-4 Bedrooms and 1-2 Bathrooms**
#    - The **histograms on the diagonal** show the distribution of each variable.
#    - Most houses **fall within these common configurations**.
#
# ✔ **Presence of Outliers**
#    - Some properties **have extremely high prices** despite smaller areas.
#    - Some **large houses appear undervalued**, suggesting possible location effects.
#
# ✔ **Feature Engineering Opportunity**
#    - Combining **moderately correlated variables (like bedrooms & bathrooms)** could improve predictive modeling.

# %% [markdown]
# # 📌 Correlation Analysis: Understanding Variable Relationships
#
# ### **Definition:**
# Correlation analysis measures the **strength and direction of the relationship** between two numerical variables.
# It helps determine whether variables **move together** (positive correlation) or in **opposite directions** (negative correlation).
#
# ---
#
# ### **📌 Why Use Correlation Analysis?**
# ✔ **Identifies relationships between features** in a dataset.
# ✔ **Useful for feature selection** in predictive modeling.
# ✔ **Detects potential multicollinearity issues** in regression models.
#
# ---
#
# ### **📌 Example: Calculating Pearson and Spearman Correlation Between House Price & Area**
# We analyze **how strongly house prices correlate with house area**.

# %%
# Import necessary libraries
import pandas as pd

# Calculate Pearson and Spearman correlation between price and area
pearson_corr = housing_df['price'].corr(housing_df['area'], method='pearson')
spearman_corr = housing_df['price'].corr(housing_df['area'], method='spearman')

# Display the correlation values
print(f"Pearson Correlation: {pearson_corr:.2f}")
print(f"Spearman Correlation: {spearman_corr:.2f}")
# Out:
# Pearson Correlation: 0.54
# Spearman Correlation: 0.60

# %% [markdown]
# ## 🔍 Insights from Correlation Analysis
#
# ✔ **Pearson Correlation (0.54): Moderate Positive Linear Relationship**
#    - House **prices increase with area** in a fairly **linear** manner.
#    - Larger homes **generally cost more**, though some variation exists.
#
# ✔ **Spearman Correlation (0.60): Stronger Rank-Based Relationship**
#    - The **rank-based correlation is stronger**, meaning that **higher-ranked houses (by area) tend to have higher prices**.
#    - This suggests **some non-linear effects**, possibly due to **luxury homes, location, or amenities**.
#
# ✔ **Implications for Predictive Modeling**
#    - **Area is a key feature** in predicting house prices.
#    - Since **Spearman is stronger than Pearson**, there may be **non-linear relationships** (e.g., luxury homes having disproportionate price increases).
#    - **Feature transformations** (e.g., log transformations or polynomial features) may improve modeling performance.

# %% [markdown]
# # 🚨 Outlier Detection Using Z-Score Analysis
#
# ### **Definition:**
# Outlier detection helps identify **data points that significantly differ** from the rest of the dataset.
# The **Z-score method** detects outliers by measuring how many **standard deviations a data point is from the mean**.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Detects extreme values** that may skew analysis.
# ✔ **Prevents biased results** in machine learning models.
# ✔ **Ensures data consistency and reliability** before further processing.
#
# ---
#
# ### **📌 Example: Detecting Outliers in House Prices**
# We use **Z-score analysis to identify extreme house prices** that might distort insights.

# %%
# Import necessary libraries
from scipy import stats
import numpy as np

# Compute Z-scores for house prices
z_scores = np.abs(stats.zscore(housing_df['price']))

# Identify outliers as values with a Z-score greater than 3
outliers_zscore = housing_df[z_scores > 3]

# Count number of outliers
num_outliers = len(outliers_zscore)

# Display number of detected outliers
print(f"Number of outliers detected using Z-Score method: {num_outliers}")
# Out:
# Number of outliers detected using Z-Score method: 6

# %% [markdown]
# ## 🔍 Insights from Z-Score Analysis
#
# ✔ **6 House Prices Were Identified as Outliers**
#    - These houses have prices **more than 3 standard deviations** from the mean.
#    - They may represent **luxury properties or extreme pricing anomalies**.
#
# ✔ **Impact of Outliers on Analysis**
#    - Outliers can **skew averages and affect model predictions**.
#    - These extreme prices may result from **unique locations, large estates, or incorrect data entries**.
#
# ✔ **How to Handle These Outliers?**
#    - **Option 1: Remove** them if they distort analysis.
#    - **Option 2: Cap** extreme values to reduce impact.
#    - **Option 3: Analyze Separately** to study high-end property trends.

# %% [markdown]
# # 🚨 Missing Value Analysis
#
# ### **Definition:**
# Missing value analysis helps identify **gaps in data** that may affect analysis, modeling, and decision-making.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Missing values can skew results** and introduce bias in models.
# ✔ **Helps decide data imputation strategies** (e.g., mean, median, mode replacement).
# ✔ **Ensures data completeness** before proceeding with further analysis.
#
# ---
#
# ### **📌 Example: Checking for Missing Values**
# We check for missing values across **all features** in the dataset before further analysis.

# %%
# Check for missing values in the dataset
missing_values = housing_df.isnull().sum()

# Display missing values
print("Missing Values in Each Column:\n")
print(missing_values)
# Out:
# Missing Values in Each Column:
#
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# Price_Category      0
# dtype: int64

# %% [markdown]
# ## 🔍 Insights from Missing Value Analysis
#
# ✔ **No Missing Values Detected in the Dataset**
#    - The dataset is **clean and complete**, meaning **no imputation is required**.
#
# ✔ **Why This is Important?**
#    - Missing values can cause **biased results** in machine learning models.
#    - Ensuring **data completeness** helps maintain accuracy in predictions.
#
# ✔ **If Missing Values Were Found, Possible Solutions Include:**
#    - **Remove rows** with missing data (if minimal impact).
#    - **Impute missing values** using statistical methods (e.g., mean for numerical data).
#    - **Use advanced techniques** like regression or deep learning for missing value prediction.

# %% [markdown]
# # 🚨 IQR (Interquartile Range) Method for Outlier Detection
#
# ### **Definition:**
# The **IQR method** identifies outliers by measuring the **spread of the middle 50% of data**.
# It flags values that are **significantly higher or lower** than the normal range.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Detects extreme values** that might distort analysis.
# ✔ **More robust to skewed data** compared to standard deviation-based methods.
# ✔ **Essential for cleaning datasets** before modeling.
#
# ---
#
# ### **📌 Example: Detecting Outliers in House Prices**
# We use the **Interquartile Range (IQR) method** to identify **extreme house prices**.

# %%
# Import necessary libraries
import pandas as pd

# Calculate Q1 (25th percentile) and Q3 (75th percentile) for house prices
Q1 = housing_df['price'].quantile(0.25)
Q3 = housing_df['price'].quantile(0.75)
IQR = Q3 - Q1  # Interquartile Range

# Identify outliers using the IQR method
outliers_iqr = housing_df[(housing_df['price'] < Q1 - 1.5 * IQR) | (housing_df['price'] > Q3 + 1.5 * IQR)]

# Count number of detected outliers
num_outliers_iqr = len(outliers_iqr)

# Display number of detected outliers
print(f"Number of outliers detected using IQR method: {num_outliers_iqr}")
# Out:
# Number of outliers detected using IQR method: 15

# %% [markdown]
# ## 🔍 Insights from IQR Outlier Detection
#
# ✔ **15 House Prices Were Identified as Outliers**
#    - These houses have prices that are **significantly different from the rest of the dataset**.
#    - This suggests the presence of **luxury homes or extreme pricing anomalies**.
#
# ✔ **Impact of Outliers on Analysis**
#    - Outliers can **skew price averages and affect model predictions**.
#    - Some extreme values may **represent valid high-value properties**, while others might be **data errors**.
#
# ✔ **How to Handle These Outliers?**
#    - **Option 1: Remove** them if they distort analysis.
#    - **Option 2: Cap extreme values** to reduce their impact on models.
#    - **Option 3: Analyze Separately** to study high-end property trends.

# %% [markdown]
# # 🛠 Imputation: Handling Missing Values
#
# ### **Definition:**
# Imputation is the process of **filling in missing values** in a dataset to maintain its integrity and usability for analysis and modeling.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Prevents data loss** from dropping missing values.
# ✔ **Improves the accuracy of statistical models** by maintaining data completeness.
# ✔ **Ensures dataset consistency** before analysis.
#
# ---
#
# ### **📌 Example: Filling Missing Values with the Mean**
# We apply **mean imputation** to fill missing values in **numeric columns**.

# %%
# Import necessary libraries
import pandas as pd

# Fill missing values for numeric columns using mean imputation
numeric_cols = housing_df.select_dtypes(include=["float64", "int64"]).columns
housing_df[numeric_cols] = housing_df[numeric_cols].fillna(housing_df[numeric_cols].mean())

# Verify if missing values are handled
missing_values_after_imputation = housing_df.isnull().sum()
print("Missing Values After Imputation:\n", missing_values_after_imputation)
# Out:
# Missing Values After Imputation:
#  price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# Price_Category      0
# dtype: int64

# %% [markdown]
# ## 🔍 Insights from Missing Value Imputation
#
# ✔ **Missing Values Successfully Handled**
#    - All missing values in numerical columns **were filled using the mean**.
#    - The dataset is now **complete and ready for further analysis**.
#
# ✔ **Mean Imputation Works Well for Normally Distributed Data**
#    - If data is **normally distributed**, mean imputation is effective.
#    - If data is **skewed**, median or mode imputation might be a better choice.
#
# ✔ **Alternative Imputation Techniques**
#    - **Median Imputation** – Better for **skewed distributions**.
#    - **Mode Imputation** – Useful for **categorical variables**.
#    - **KNN Imputation** – Uses nearest neighbors to estimate missing values.
#    - **Regression Imputation** – Predicts missing values based on other features.

# %% [markdown]
# # 🛠 Feature Engineering: Creating Informative Variables
#
# ### **Definition:**
# Feature engineering involves **combining or transforming existing variables** to create **more informative features** for analysis and modeling.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Enhances predictive power** by normalizing or modifying raw data.
# ✔ **Helps uncover hidden relationships** in the dataset.
# ✔ **Improves model performance** by creating **more relevant input variables**.
#
# ---
#
# ### **📌 Example: Creating 'PRICE_PER_SQFT'**
# We calculate the **price per square foot** to help standardize property values.

# %%
# Create a new feature: Price per Square Foot (PRICE_PER_SQFT)
housing_df['PRICE_PER_SQFT'] = housing_df['price'] / housing_df['area']

# Display the first few rows of the new feature
housing_df[['price', 'area', 'PRICE_PER_SQFT']].head()
# Out:
#       price  area  PRICE_PER_SQFT
# 0  13300000  7420     1792.452830
# 1  12250000  8960     1367.187500
# 2  12250000  9960     1229.919679
# 3  12215000  7500     1628.666667
# 4  11410000  7420     1537.735849

# %% [markdown]
# ## 🔍 Insights from Feature Engineering
#
# ✔ **This feature helps normalize house prices** by accounting for property size.
#    - Instead of using absolute prices, **price per square foot provides a standardized metric**.
#
# ✔ **Higher 'PRICE_PER_SQFT' values may indicate luxury properties or expensive neighborhoods.**
#    - Premium locations tend to have **higher per-square-foot costs**, even for smaller homes.
#
# ✔ **Useful for Regression and Comparative Analysis**
#    - This feature can be **used in predictive models** to improve pricing accuracy.
#    - It allows for **better comparisons between properties of different sizes**.

# %% [markdown]
# # 📈 Time Series Analysis: House Prices Over Time
#
# ### **Definition:**
# Time series analysis helps identify **long-term trends, seasonal patterns, and fluctuations** in house price data.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Helps analyze market trends** in house prices.
# ✔ **Identifies fluctuations and anomalies** in pricing.
# ✔ **Useful for predicting future prices** based on past trends.
#
# ---
#
# ### **📌 Example: Trend Analysis of House Prices**
# We visualize **house prices over sequential indices** to detect patterns.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Plot a time series analysis of house prices over index
plt.figure(figsize=(10, 5))
plt.plot(housing_df['price'], color="blue")
plt.xlabel("Index")
plt.ylabel("House Price (INR)")
plt.title("Trend Analysis of House Prices")
plt.show()

# %% [markdown]
# ## 🔍 Insights from Time Series Analysis
#
# ✔ **Downward Trend in House Prices**
#    - The **prices decrease as the index increases**, suggesting the dataset might be sorted by price.
#    - This is **not a true time series dataset** since it lacks a timestamp column.
#
# ✔ **Volatility in Pricing Observed**
#    - The **curve shows fluctuations**, possibly due to **location differences or property features**.
#
# ✔ **Next Steps for Better Time Series Analysis**
#    - **Obtain a Date-Based Column** – A proper time series analysis requires **timestamps** (e.g., listing dates).
#    - **Apply Smoothing Techniques** – Moving averages or exponential smoothing could reveal clearer trends.
#    - **Analyze Location-Based Trends** – Prices might vary based on city, neighborhood, or property type.

# %% [markdown]
# # 🔍 Principal Component Analysis (PCA)
#
# ### **Definition:**
# PCA is a **dimensionality reduction technique** that transforms correlated features into a set of **uncorrelated principal components** while retaining as much variance as possible.
#
# ---
#
# ### **📌 Why Use It?**
# ✔ **Reduces dataset complexity** while preserving important information.
# ✔ **Helps visualize high-dimensional data** in a lower-dimensional space.
# ✔ **Removes redundant features**, improving **model efficiency and performance**.
#
# ---
#
# ### **📌 Example: Applying PCA to the Housing Dataset**
# We apply **PCA to reduce dimensionality** while keeping essential data variance.

# %%
# Import necessary libraries
from sklearn.decomposition import PCA

# Select only numeric columns
housing_df_numeric = housing_df.select_dtypes(include=["float64", "int64"])

# Handle missing values by filling with column mean
housing_df_numeric = housing_df_numeric.fillna(housing_df_numeric.mean())

# Initialize PCA with 2 components
pca = PCA(n_components=2)

# Fit PCA to the dataset, excluding the target variable ('price')
pca_result = pca.fit_transform(housing_df_numeric.drop('price', axis=1))

# Display transformed dataset
print("First 5 rows of PCA transformed data:\n", pca_result[:5])
# Out:
# First 5 rows of PCA transformed data:
#  [[2202.52631577  968.46645861]
#  [3770.27712906  660.88428886]
#  [4777.79397204  599.62928564]
#  [2294.68362432  811.1989386 ]
#  [2221.78915938  714.47743525]]

# %% [markdown]
# ## 🔍 Insights from PCA
#
# ✔ **The two principal components capture most of the dataset's variability.**
#    - The **original dataset had multiple features**, but PCA compresses it into just **two uncorrelated components**.
#
# ✔ **This transformation helps in visualizing patterns and reducing computation time.**
#    - Instead of working with high-dimensional data, we can **interpret key relationships in a lower-dimensional space**.
#
# ✔ **Explained Variance Analysis**
#    - PCA can be **further analyzed using explained variance ratios** to determine **how much information each component retains**.
#    - This helps decide whether **more or fewer components** are needed.

# %% [markdown]
# # 📊 Why is Exploratory Data Analysis (EDA) Important?
#
# Exploratory Data Analysis (EDA) is a crucial step in data analysis because it helps us **understand the housing dataset better before applying models or making decisions**.
# Here's why EDA is important when analyzing real estate data:
#
# ---
#
# ### **1. Identifying Data Quality Issues**
# EDA helps **identify missing values, duplicate entries, or incorrect data points** that might affect analysis.
#
# ✅ **Example:** If some properties have missing prices or incorrect square footage values, these inconsistencies need to be addressed before modeling.
#
# ---
#
# ### **2. Understanding Data Distributions**
# Before applying statistical models, we need to **verify if the data follows expected patterns**.
#
# ✅ **Example:** If we assume that **larger homes have higher prices**, EDA can check whether this holds true across different locations and property types.
#
# ---
#
# ### **3. Selecting the Right Model**
# Different pricing trends exist across housing markets. EDA helps **select the best model for price prediction** based on **data distribution and feature relationships**.
#
# ✅ **Example:** If home prices are **not normally distributed**, a **log transformation** or another statistical technique may improve model accuracy.
#
# ---
#
# ### **4. Identifying Patterns and Trends**
# EDA helps **identify trends in pricing, buyer behavior, and seasonal fluctuations** in real estate.
#
# ✅ **Example:** Analyzing transaction data might reveal that **house prices tend to rise in the spring and fall during the winter**, or that homes near schools tend to sell at a premium.
#
# ---
#
# ### **5. Generating Data-Driven Hypotheses**
# EDA allows us to **form hypotheses about factors affecting home prices and market demand**.
#
# ✅ **Example:** We might hypothesize that **homes in high-demand neighborhoods appreciate faster** or that **houses with modern interiors sell at higher prices**.
#
# ---
#
# ## 🏡 Examples of EDA in Action
#
# ### 🔍 **Analyzing House Price Trends**
# - Understanding **which cities or regions are experiencing price growth**.
# - Examining whether **bigger homes always lead to higher prices**.
#
# ### 🚨 **Detecting Market Outliers**
# - Finding **properties priced significantly higher or lower than similar listings**.
# - Identifying outliers that could result from **renovations, poor condition, or pricing errors**.
#
# ### 📈 **Assessing the Impact of Features on Pricing**
# - Evaluating how **square footage, number of bedrooms, lot size, and location** affect home prices.
# - Checking if **certain house characteristics are overvalued or undervalued**.
#
# EDA in real estate is like **exploring a new neighborhood before buying a home**—by analyzing **patterns, spotting inconsistencies, and understanding trends**, we can make **more informed and profitable real estate decisions!** 🏡📊📈

# %% [markdown]
# # 🏡 Exploratory Data Analysis (EDA) on Housing Dataset
#
# ## 1. Understanding the Dataset
#
# Before analyzing the data, we need to understand what it contains.
# This dataset consists of **housing records**, with details such as:
#
# - **Location** (City, State)
# - **Year Built** (Construction year of the property)
# - **Square Footage** (Total living space area)
# - **Number of Bedrooms & Bathrooms** (Size and functionality of the home)
# - **Lot Size** (Total land area, important for single-family homes)
# - **Property Type** (Single-family home, apartment, townhouse, etc.)
# - **Condition & Renovation Status** (Original condition, updated, or fully renovated)
# - **Nearby Amenities** (Proximity to schools, parks, shopping centers, and public transport)
# - **Listing Price & Final Sale Price** (Asking price vs. actual transaction price)
#
# ---
#
# ### **📌 Why is this important?**
# Understanding these attributes allows us to:
# ✔ **Identify patterns**
# ✔ **Detect inconsistencies**
# ✔ **Explore trends in the real estate market**
#
# Before applying statistical models or machine learning techniques, it is crucial to ensure **data quality and consistency**. 🏡📊
#
# ---
#
# ## 📜 Loading and Previewing the Data

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
file_path = "Housing.csv"  # Update this if the file is in a different location
housing_df = pd.read_csv(file_path)

# Display the first 5 rows
housing_df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ## 🔍 Insights from Data Preview
#
# ✔ **We can see column names, data types, and sample values.**
#    - This helps us identify **incorrect formats** (e.g., lot size in different units).
#    - **Detect incomplete data** (e.g., missing sale prices or property conditions).
#    - **Understand the dataset structure** before performing further data cleaning and analysis.
#
# ✔ **Ensuring Data Quality for Modeling**
#    - Missing or inconsistent values should be **handled properly**.
#    - Outliers and anomalies may need **further investigation**.
#    - Properly formatted data ensures **accurate market insights and better predictive modeling**.

# %% [markdown]
# # 📊 Checking Basic Information of the Dataset
#
# ## **2.1 Checking Column Data Types**

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ## 🔍 Insights from Data Structure
#
# ✔ **The dataset contains both categorical and numerical features.**
#    - Categorical columns include property features such as `furnishingstatus` and `airconditioning`.
#    - Numerical columns include `price`, `area`, and `bedrooms`.
#
# ✔ **No missing values were detected.**
#    - This means we can proceed without immediate data imputation.
#
# ✔ **Understanding data types helps in selecting the right preprocessing methods.**
#    - **Categorical columns** might need **encoding (e.g., one-hot encoding)** for machine learning.
#    - **Numerical columns** might require **scaling or transformations** for better model performance.

# %% [markdown]
# # 🔍 Identifying Missing Values
#
# ### **Why is this important?**
# Missing values can **cause errors in analysis** and **impact predictive models**, so we need to handle them properly to ensure **accurate insights** in real estate pricing and trends.
#
# ---
#
# ## **3.1 Count Missing Values**
# We check the dataset for missing values to determine if any columns require imputation.

# %%
housing_df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ### 3.2 Percentage of Missing Values

# %%
(housing_df.isnull().sum() / len(housing_df)) * 100
# Out:
# price               0.0
# area                0.0
# bedrooms            0.0
# bathrooms           0.0
# stories             0.0
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# parking             0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %% [markdown]
# ## 🔍 Insights from Missing Value Analysis
#
# ✔ **No missing values were detected in the dataset.**
#    - This means we can proceed **without immediate data imputation**.
#
# ✔ **Ensuring Data Completeness for Modeling**
#    - Since all features are **fully populated**, we can move forward with **statistical analysis and visualization**.
#    - No additional data cleaning is required for handling null values.

# %% [markdown]
# # 🛠 Handling Missing Values (Imputation)
#
# ## **Strategy:**
# We apply different imputation methods based on the data type:
#
# - **Numerical Data** (e.g., `price`, `area`, `bedrooms`, `bathrooms`):
#   ✅ Use **median** imputation to handle missing values while avoiding the influence of outliers.
#
# - **Categorical Data** (e.g., `furnishingstatus`, `mainroad`, `airconditioning`):
#   ✅ Use **mode** imputation to replace missing values with the most common category.
#
# ---
#
# ## **4.1 Filling Missing Values**
# ### **📜 Code Implementation**

# %%
# Fill numerical columns with median
numerical_cols = housing_df.select_dtypes(include=['float64', 'int64']).columns
housing_df[numerical_cols] = housing_df[numerical_cols].fillna(housing_df[numerical_cols].median())

# Fill categorical columns with mode
categorical_cols = housing_df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    housing_df[col] = housing_df[col].fillna(housing_df[col].mode()[0])

# Verify that missing values have been handled
housing_df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# ## 🔍 Insights from Handling Missing Values (Imputation)
#
# ✔ **All missing values have been successfully handled.**
#    - No missing values remain in the dataset, ensuring data consistency.
#
# ✔ **Numerical Data: Median Imputation**
#    - The **median** was used instead of the mean to **reduce the impact of extreme values (outliers)**.
#    - This approach ensures a **stable and representative** dataset.
#
# ✔ **Categorical Data: Mode Imputation**
#    - The **most frequent category** was used to fill missing values in categorical columns.
#    - This prevents potential inconsistencies while maintaining data integrity.

# %% [markdown]
# # 📊 Detecting and Handling Outliers
#
# Outliers can distort analysis. We use the **Interquartile Range (IQR)** to detect extreme values in house prices.
#
# ---
#
# ## **5.1 Outlier Detection Using IQR**
# We identify outliers based on the **IQR method**, which captures values that fall outside **1.5 times the interquartile range**.

# %%
# Define Q1 (25th percentile) and Q3 (75th percentile)
Q1 = housing_df['price'].quantile(0.25)
Q3 = housing_df['price'].quantile(0.75)

# Compute IQR
IQR = Q3 - Q1

# Identify outliers as values outside 1.5 times the IQR range
outliers = housing_df[(housing_df['price'] < (Q1 - 1.5 * IQR)) | (housing_df['price'] > (Q3 + 1.5 * IQR))]

# Display number of outliers detected
print(f"Number of outliers detected: {len(outliers)}")
# Out:
# Number of outliers detected: 15

# %% [markdown]
# ## 🔍 Insights from Outlier Detection Using IQR
#
# ✔ **Number of outliers detected:** `15`
#    - These properties have significantly different prices compared to the rest of the dataset.
#
# ✔ **Potential Causes of Outliers in House Prices:**
#    - **Luxury homes** with very high prices.
#    - **Distressed properties** priced much lower than average.
#    - **Data entry errors** (e.g., incorrect pricing values).
#
# ✔ **Possible Handling Strategies:**
#    - **Remove extreme outliers** if they are likely errors.
#    - **Cap outliers** at a reasonable range to reduce their influence.
#    - **Analyze separately** (e.g., treating luxury homes as a distinct category).
#
# By identifying and addressing outliers, we ensure **accurate housing market trends and property valuations!** 🏡📈📊

# %% [markdown]
# # 🛠 Feature Engineering: Creating New Variables in Housing Data
#
# We create new features that might help improve predictions in the real estate market.
#
# ---
#
# ## **6.1 Creating a New Feature: Price per Square Foot**
# This feature helps measure how much value a house holds per unit of area.
#
# ### **📜 Code Implementation**

# %%
# Ensure no division by zero
housing_df = housing_df[housing_df['area'] > 0]

# Create new feature: Price per Square Foot
housing_df['price_per_sqft'] = housing_df['price'] / housing_df['area']

# Display first few rows with the new feature
housing_df[['price', 'area', 'price_per_sqft']].head()
# Out:
#       price  area  price_per_sqft
# 0  13300000  7420     1792.452830
# 1  12250000  8960     1367.187500
# 2  12250000  9960     1229.919679
# 3  12215000  7500     1628.666667
# 4  11410000  7420     1537.735849

# %% [markdown]
# ## 🔍 Insights from Price per Square Foot
#
# ✔ **This new feature helps us determine property value efficiency.**
#    - It provides insights into **price variations across different house sizes**.
#
# ✔ **A higher `price_per_sqft` may indicate:**
#    - **Luxury properties**, **high-demand locations**, or **newly renovated homes**.
#    - Homes in **prime areas** with modern amenities.
#
# ✔ **A lower `price_per_sqft` may suggest:**
#    - **Older homes**, **larger lot sizes**, or **properties needing renovations**.
#    - Houses located in **less competitive markets**.

# %% [markdown]
# # 🎯 Principal Component Analysis (PCA) for Dimensionality Reduction in Housing Data
#
# PCA helps reduce dataset complexity while retaining essential information, making it easier to identify patterns in the housing market.
#
# ---
#
# ## **7.1 Handling Non-Numeric Data Before PCA**
# Before applying PCA, we **convert categorical columns** to numerical values and standardize the dataset.
#
# ### **📜 Code Implementation**

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pandas as pd

# Convert categorical columns to numerical using one-hot encoding
housing_df_encoded = pd.get_dummies(housing_df, drop_first=True)

# Standardize the data (PCA requires scaled data)
scaler = StandardScaler()
housing_df_scaled = scaler.fit_transform(housing_df_encoded)

# %% [markdown]
# ### 7.2 Applying PCA

# %%
# Apply PCA with 2 principal components
pca = PCA(n_components=2)
pca_result = pca.fit_transform(housing_df_scaled)

# Convert PCA results into a DataFrame
df_pca = pd.DataFrame(pca_result, columns=['PC1', 'PC2'])

# Display first few rows of PCA results
df_pca.head()
# Out:
#         PC1       PC2
# 0  5.460505  0.514888
# 1  6.578147  0.627292
# 2  4.331059 -1.243729
# 3  5.355160 -0.369020
# 4  4.120836 -0.309622

# %% [markdown]
# ## 🔍 Insights from PCA
#
# ✔ **PCA reduces high-dimensional housing data** into just two principal components, helping us visualize trends more easily.
#
# ✔ **This technique allows us to see how different properties cluster** based on key attributes like **size, price, and condition**.
#
# ✔ **PCA is useful for:**
#    - **Identifying neighborhood trends**
#    - **Analyzing investment potential**
#    - **Segmenting the housing market**
#
# ✔ **PCA ensures better data interpretation** and **improves predictive modeling efficiency** for real estate analytics! 🏡📊📈

# %% [markdown]
# ## 8. Visualizing Trends in Housing Prices
# ### 8.1 Plotting Price Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(8, 5))

# Plot histogram with KDE (Kernel Density Estimation) curve
sns.histplot(housing_df['price'], bins=30, kde=True, color='orange', edgecolor='black', alpha=0.7)

# Add titles and labels
plt.title("Distribution of Housing Prices")
plt.xlabel("Sale Price")
plt.ylabel("Count")

# Display plot
plt.show()

# %% [markdown]
# ## 🔍 Insights from Housing Price Distribution
#
# ✔ **Most houses fall within the low to mid-price range**, but some luxury properties significantly increase the maximum price.
#
# ✔ **The distribution is right-skewed**, indicating that a **few expensive homes raise the overall price range**.
#
# ✔ **Understanding this distribution helps in:**
#    - **Market segmentation** – identifying affordable vs. high-end housing markets.
#    - **Pricing strategies** – adjusting valuation methods for different property types.
#
# ✔ **By analyzing price trends, we can identify affordable vs. luxury housing markets** and make **better real estate investment decisions!** 🏡📈📊

# %% [markdown]
# ## 🏡 **Conclusion: Key Takeaways from Housing Data Analysis**
#
# ✔ **Exploratory Data Analysis (EDA) plays a crucial role** in cleaning, understanding, and preparing housing data before applying predictive models.
#
# ✔ **We identified and addressed missing values, outliers, and pricing trends**, ensuring accurate insights into property valuations.
#
# ✔ **Feature engineering techniques, such as `Price_per_SqFt`, provided deeper insights**, enabling better property comparisons and market analysis.
#
# ✔ **Dimensionality reduction using PCA simplified the dataset**, enhancing visualization and facilitating real estate market segmentation.
#
# By leveraging EDA and feature engineering, we gained valuable insights into housing trends, helping optimize **pricing strategies, market analysis, and investment decisions!** 📊🏡📈

# %% [markdown]
# # 🔍 Transforming Categorical Features for Better Data Analysis
#
# In real estate data analysis, categorical features like **furnishing status, road access, and air conditioning availability** can impact property values. However, raw categorical data may be inconsistent or difficult to interpret.
#
# To improve data usability and analysis, we **standardize** categorical variables for better organization, visualization, and machine learning applications.

# %%
# Standardizing categorical column values
housing_df['Furnishing_Status_Detail'] = housing_df['furnishingstatus'].str.title()
housing_df['Mainroad_Access'] = housing_df['mainroad'].map({'yes': 'Accessible', 'no': 'Not Accessible'})
housing_df['AirConditioning_Status'] = housing_df['airconditioning'].map({'yes': 'Available', 'no': 'Not Available'})

# Display first few rows of the transformed columns
housing_df[['furnishingstatus', 'Furnishing_Status_Detail', 
            'mainroad', 'Mainroad_Access', 
            'airconditioning', 'AirConditioning_Status']].head()
# Out:
#   furnishingstatus Furnishing_Status_Detail mainroad Mainroad_Access  \
# 0        furnished                Furnished      yes      Accessible
# 1        furnished                Furnished      yes      Accessible
# 2   semi-furnished           Semi-Furnished      yes      Accessible
# 3        furnished                Furnished      yes      Accessible
# 4        furnished                Furnished      yes      Accessible
#
#   airconditioning AirConditioning_Status
# 0             yes              Available
# 1             yes              Available
# 2              no          Not Available
# 3             yes              Available
# 4             yes              Available

# %% [markdown]
# ## 📊 Insights from Data Transformation
#
# ✔ **Improves Data Organization** – Standardizing furnishing status, road access, and air conditioning availability makes it easier to compare properties.
#
# ✔ **Enhances Comparisons** – Buyers can now filter properties based on standardized attributes like **Furnished vs. Semi-Furnished vs. Unfurnished**, improving decision-making.
#
# ✔ **Prepares Data for Machine Learning** – Categorically structured data improves feature encoding and predictive modeling performance.
#
# ✔ **Aids in Visualization** – Price trends can now be analyzed based on accessibility, air conditioning, and furnishing types.
#
# By refining categorical data, we **enhance the accuracy of real estate market analysis and improve predictive modeling performance**! 🏡📈

# %% [markdown]
# # 🏡 Standardizing Categorical Features for Better Housing Data Analysis
#
# To ensure consistency in our dataset, we standardize **neighborhood names** and **property type categories**. Inconsistent or duplicate values can introduce errors in data interpretation and modeling.
#
# By transforming these categorical features, we improve data reliability, enhance comparisons, and prepare the dataset for advanced analysis.

# %%
# Convert categorical columns to a structured format
housing_df['Furnishing_Status_Detail'] = housing_df['furnishingstatus'].str.title()
housing_df['Mainroad_Access'] = housing_df['mainroad'].map({'yes': 'Accessible', 'no': 'Not Accessible'})
housing_df['AirConditioning_Status'] = housing_df['airconditioning'].map({'yes': 'Available', 'no': 'Not Available'})

# Display first few rows
housing_df[['furnishingstatus', 'Furnishing_Status_Detail', 'mainroad', 'Mainroad_Access', 
            'airconditioning', 'AirConditioning_Status']].head()
# Out:
#   furnishingstatus Furnishing_Status_Detail mainroad Mainroad_Access  \
# 0        furnished                Furnished      yes      Accessible
# 1        furnished                Furnished      yes      Accessible
# 2   semi-furnished           Semi-Furnished      yes      Accessible
# 3        furnished                Furnished      yes      Accessible
# 4        furnished                Furnished      yes      Accessible
#
#   airconditioning AirConditioning_Status
# 0             yes              Available
# 1             yes              Available
# 2              no          Not Available
# 3             yes              Available
# 4             yes              Available

# %% [markdown]
# ### **Insights**
# ✔ **Improves Data Organization**: Standardizing categorical values ensures data consistency and prevents errors in analysis.
#
# ✔ **Enhances Comparisons**: The cleaned categorical values allow for better comparison across different property features.
#
# ✔ **Prepares Data for Machine Learning**: Properly formatted categorical data ensures better encoding and improves model performance.
#
# ✔ **Aids in Visualization**: Standardized values make it easier to create visualizations and analyze trends in housing preferences.

# %% [markdown]
# ### 📊 Univariate Analysis of Housing Data
#
# #### **Understanding Univariate Analysis**
# Univariate analysis focuses on analyzing individual variables independently. This method helps to:
# - Identify **patterns and trends** in each variable.
# - Detect **outliers** that may affect modeling.
# - Understand the **distribution and skewness** of data.
#
# For different types of variables, we use different visualization techniques:
# - **Categorical variables:** Count plots, bar charts, and pie charts to visualize frequency distributions.
# - **Numerical variables:** Histograms, box plots, and density plots to analyze distributions, skewness, and outliers.
#
# In this section, we analyze numerical variables using **histograms and box plots** to observe their distribution patterns and detect potential outliers.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Identify numerical columns
num_cols = housing_df.select_dtypes(include=np.number).columns.tolist()

# Create a dictionary to store skewness values
skewness_values = {}

# Generate histograms and box plots for numerical variables
for col in num_cols:
    skewness = round(housing_df[col].skew(), 2)
    skewness_values[col] = skewness

    # Set figure size
    plt.figure(figsize=(15, 4))

    # Histogram - Shows distribution of the variable
    plt.subplot(1, 2, 1)
    sns.histplot(housing_df[col], bins=30, kde=True, edgecolor="black")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.title(f"Histogram of {col} (Skewness: {skewness})")

    # Box Plot - Identifies outliers
    plt.subplot(1, 2, 2)
    sns.boxplot(x=housing_df[col])
    plt.xlabel(col)
    plt.title(f"Boxplot of {col}")

    plt.show()

# %% [markdown]
# ### 📈 **Insights from Univariate Analysis**
#
# ✔ **Price** has a highly right-skewed distribution, indicating that a few expensive properties significantly raise the overall price range.
#
# ✔ **Area** follows a right-skewed distribution, with most properties falling in the **moderate size range**, while some **luxury estates** have exceptionally large areas.
#
# ✔ **Bedrooms** has an approximately normal distribution, meaning most homes have a balanced number of bedrooms.
#
# ✔ **Bathrooms** show a right-skewed distribution, suggesting that most homes have **few bathrooms**, but some **high-end properties** feature more.
#
# ✔ **Stories** indicate a highly right-skewed distribution, meaning **most homes are single or double-story**, but a few **multi-story properties** increase the range.
#
# ✔ **Parking** follows an approximately normal distribution, suggesting that most properties provide a **standard parking capacity**.
#
# This analysis helps us understand the distribution of housing attributes, detect skewness, and identify outliers for better data preprocessing and modeling. 🚀

# %% [markdown]
# # 🏡 Data Preprocessing for Enhanced Analysis in Housing Data
#
# When analyzing housing data, extracting relevant insights requires **transforming and structuring data effectively**. This section demonstrates how to extract **useful categorical information** from existing data, ensuring **better organization and consistency**.
#
# One important step is **splitting complex property names into distinct categories**. Many datasets include a `"Property_Name"` column that contains **neighborhood names, property types, and additional details**. To improve data usability, we extract **Neighborhood** and **Property Type** as separate columns.
#
# ---
#
# ## 🔹 Extracting Neighborhood and Property Type Information
#
# The `"Property_Name"` column often consists of **multiple components**, making it difficult to categorize properties accurately. **Splitting** this information into structured categories enhances **clarity and consistency** in analysis.
#
# ### **Key Benefits**
# ✔ **Neighborhood extraction** helps identify **regional trends**, such as Downtown, Suburban, or Beachfront properties.
# ✔ **Property Type extraction** allows for **segmentation by housing type**, such as **Luxury Condo, Family Home, Urban Loft**.
# ✔ Improves **comparability and consistency**, making the data easier to analyze for pricing trends and location-based insights.

# %%
# Standardizing categorical values for better consistency
housing_df['Furnishing_Status_Detail'] = housing_df['furnishingstatus'].str.title()
housing_df['Mainroad_Access'] = housing_df['mainroad'].map({'yes': 'Accessible', 'no': 'Not Accessible'})
housing_df['AirConditioning_Status'] = housing_df['airconditioning'].map({'yes': 'Available', 'no': 'Not Available'})
housing_df['Preferred_Area'] = housing_df['prefarea'].map({'yes': 'Preferred Area', 'no': 'Not Preferred Area'})

# Display first few rows to verify the transformation
housing_df[['Furnishing_Status_Detail', 'Mainroad_Access', 'AirConditioning_Status', 'Preferred_Area']].head()
# Out:
#   Furnishing_Status_Detail Mainroad_Access AirConditioning_Status  \
# 0                Furnished      Accessible              Available
# 1                Furnished      Accessible              Available
# 2           Semi-Furnished      Accessible          Not Available
# 3                Furnished      Accessible              Available
# 4                Furnished      Accessible              Available
#
#        Preferred_Area
# 0      Preferred Area
# 1  Not Preferred Area
# 2      Preferred Area
# 3      Preferred Area
# 4  Not Preferred Area

# %% [markdown]
# ## 🏡 Insights from Data Standardization
#
# ✔ **Improves Data Organization** – Standardizing categorical values ensures data consistency and prevents errors in analysis.
#
# ✔ **Enhances Comparisons** – The cleaned categorical values allow for better comparison across different property features.
#
# ✔ **Prepares Data for Machine Learning** – Properly formatted categorical data ensures better encoding and improves model performance.
#
# ✔ **Aids in Visualization** – Standardized values make it easier to create visualizations and analyze trends in housing preferences.
#
# By refining categorical attributes, we enhance **real estate market analysis** and **predictive modeling performance**! 📊🏠

# %% [markdown]
# ### **📌 Standardizing Categorical Features in Housing Data**
#
# #### **Why Standardize Categorical Features?**
# Inconsistent labels in categorical features can lead to data misinterpretation, duplicate categories, and inaccuracies in predictive models. Standardizing values ensures:
# - **Data Consistency**: Removes variations in spelling and formatting.
# - **Improved Comparisons**: Facilitates better segmentation for analysis.
# - **Enhanced Predictive Performance**: Categorical encoding in models is more effective.

# %%
# Standardizing categorical values for consistency
housing_df['Furnishing_Status_Detail'] = housing_df['furnishingstatus'].str.title()
housing_df['Mainroad_Access'] = housing_df['mainroad'].map({'yes': 'Accessible', 'no': 'Not Accessible'})
housing_df['AirConditioning_Status'] = housing_df['airconditioning'].map({'yes': 'Available', 'no': 'Not Available'})
housing_df['Preferred_Area'] = housing_df['prefarea'].map({'yes': 'Preferred Area', 'no': 'Not Preferred Area'})

# Displaying first few rows to verify the transformation
housing_df[['Furnishing_Status_Detail', 'Mainroad_Access', 'AirConditioning_Status', 'Preferred_Area']].head()
# Out:
#   Furnishing_Status_Detail Mainroad_Access AirConditioning_Status  \
# 0                Furnished      Accessible              Available
# 1                Furnished      Accessible              Available
# 2           Semi-Furnished      Accessible          Not Available
# 3                Furnished      Accessible              Available
# 4                Furnished      Accessible              Available
#
#        Preferred_Area
# 0      Preferred Area
# 1  Not Preferred Area
# 2      Preferred Area
# 3      Preferred Area
# 4  Not Preferred Area

# %% [markdown]
# ### **📊 Insights from Categorical Standardization**
# ✔ **Ensures Data Consistency** – Standardized categorical values prevent errors in visualization and modeling.
# ✔ **Enhances Comparisons** – Allows better filtering and segmentation of properties based on categorical features.
# ✔ **Improves Model Performance** – Properly formatted categorical data improves encoding and helps predictive models.
# ✔ **Better Visualization** – Standardized values make it easier to interpret trends and relationships in housing features.
#
# By refining categorical data, we enhance **housing market insights** and improve **real estate analytics**! 🏡📊

# %% [markdown]
# ### **🔍 Understanding Unique Neighborhood Distribution**
# Now that we have **extracted and standardized** neighborhood names, we check how many **unique neighborhoods** exist in the dataset.
#
# By analyzing unique neighborhood names, we can better understand regional distributions and improve **location-based insights** in real estate analytics.

# %%
print(housing_df.columns)

print(housing_df.head())

# Example (adjust the old_name as needed):
housing_df = housing_df.rename(columns={'old_name': 'Neighborhood'})

housing_df = pd.read_csv('Housing.csv')

import pandas as pd

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Display unique preferred area values
print("Unique Preferred Areas:", housing_df['prefarea'].unique())

# Count unique preferred areas
print("Total unique preferred areas:", housing_df['prefarea'].nunique())
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# ...

# %% [markdown]
# ### [**📊 Insights from Preferred Area Analysis**](pplx://action/followup)
#
# ✔ **There are 2 unique preferred areas** in the dataset, reflecting whether a property is in a preferred location or not.
# ✔ **Analyzing unique values in 'prefarea'** allows for categorical analysis and helps understand the impact of preferred location on other factors such as price.
# ✔ **Aids in real estate market segmentation**, enabling a basic distinction between properties in preferred vs. non-preferred areas.
#
# Understanding the distribution of properties in preferred areas enhances **real estate decision-making** and provides **insights into the value associated with location preference**! 🏡📈

# %% [markdown]
# ### [**🧹 Identifying and Fixing Inconsistencies in Furnishing Status**](pplx://action/followup)
#
# Some furnishing statuses may have different variations. We check for cases where specific furnishing status options appear inconsistently and standardize them for accurate analysis.

# %%
import pandas as pd

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Analyze Furnishing Status
print("Unique Furnishing Status Values and Counts:")
print(housing_df['furnishingstatus'].value_counts())

# Standardize Furnishing Status
housing_df['furnishingstatus'] = housing_df['furnishingstatus'].replace({
    'furnished': 'Furnished',
    'semi-furnished': 'Semi-Furnished',
    'unfurnished': 'Unfurnished'
})

# Verify Standardized Values
print("\nStandardized Unique Furnishing Status Values:")
print(housing_df['furnishingstatus'].unique())
# Out:
# Unique Furnishing Status Values and Counts:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64
#
# Standardized Unique Furnishing Status Values:
# ['Furnished' 'Semi-Furnished' 'Unfurnished']

# %% [markdown]
# **[Insights](pplx://action/followup):**
#
# ✔ Ensures all furnishing status options are consistently formatted (e.g., capitalized)
#
# ✔ Avoids misclassifications when performing furnishing-based real estate analysis.
#
# ✔ Improves market segmentation and pricing trend analysis by ensuring uniform naming conventions for furnishing status.
#
# By correcting furnishing status inconsistencies, we improve data clarity, reliability, and real estate insights! 🏡✨

# %% [markdown]
# ### **✨ Feature Engineering: Combining Amenities Information**
#
# In this analysis, we create a combined "Amenities" column by consolidating information from the `mainroad`, `guestroom`, `basement`, `hotwaterheating`, `airconditioning`, and `prefarea` columns.
#
# **Code: Creating the "Amenities" Column**

# %%
import pandas as pd

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Create the 'Amenities' column by combining other columns
housing_df['Amenities'] = housing_df['mainroad'].astype(str) + '_' + \
                           housing_df['guestroom'].astype(str) + '_' + \
                           housing_df['basement'].astype(str) + '_' + \
                           housing_df['hotwaterheating'].astype(str) + '_' + \
                           housing_df['airconditioning'].astype(str) + '_' + \
                           housing_df['prefarea'].astype(str)

# Analyze Amenities Combinations
print("Unique Amenities Combinations:")
print(housing_df['Amenities'].value_counts())

# Standardize Amenities based on value_counts() Analysis
housing_df['Amenities'] = housing_df['Amenities'].replace({
    'yes_no_no_no_no_no': 'Mainroad',
    'yes_no_yes_no_yes_yes': 'Mainroad_Basement_AirConditioning_PrefArea',
    'yes_yes_yes_no_yes_yes': 'Mainroad_Guestroom_Basement_AirConditioning_PrefArea',
    'yes_no_yes_no_no_yes': 'Mainroad_Basement_PrefArea',
    'yes_yes_yes_no_no_yes': 'Mainroad_Guestroom_Basement_PrefArea',
    'yes_yes_yes_yes_yes_yes': 'Mainroad_Guestroom_Basement_Hotwaterheating_AirConditioning_PrefArea',
    'no_no_no_no_yes_no': 'Airconditioning',
    'no_no_no_no_no_no':'No',
    'yes_no_yes_no_yes_no':'Mainroad_Basement_AirConditioning',
    'yes_no_no_yes_yes_no':'Mainroad_Hotwaterheating_AirConditioning',
    'yes_yes_yes_no_no_no': 'Mainroad_Guestroom_Basement',
    'yes_no_yes_yes_yes_yes': 'Mainroad_Basement_Hotwaterheating_AirConditioning_PrefArea',
    'no_no_yes_no_yes_no': 'Basement_AirConditioning',
    'yes_yes_yes_no_yes_no': 'Mainroad_Guestroom_Basement_AirConditioning',
    'yes_no_no_no_yes_yes': 'Mainroad_AirConditioning_PrefArea',
    'yes_no_yes_yes_yes_no':'Mainroad_Basement_Hotwaterheating_AirConditioning',
    'yes_yes_yes_yes_yes_no':'Mainroad_Guestroom_Basement_Hotwaterheating_AirConditioning',
    'no_no_yes_no_no_no':'Basement',
    'yes_no_no_no_yes_yes':'Mainroad_AirConditioning_PrefArea',
    'yes_no_no_no_no_yes':'Mainroad_PrefArea',
    'yes_yes_yes_yes_no_yes':'Mainroad_Guestroom_Basement_Hotwaterheating_PrefArea',
    'yes_no_yes_yes_no_yes':'Mainroad_Basement_Hotwaterheating_PrefArea',
    'no_no_no_yes_yes_no':'Hotwaterheating_AirConditioning',
    'no_no_no_no_yes_yes':'AirConditioning_PrefArea',
    'yes_yes_yes_no_no_yes':'Mainroad_Guestroom_Basement_PrefArea',
    'yes_no_yes_no_no_no':'Mainroad_Basement',
    'no_no_yes_no_yes_yes':'Basement_AirConditioning_PrefArea',
    'yes_no_no_yes_yes_yes':'Mainroad_Hotwaterheating_AirConditioning_PrefArea',
    'yes_no_no_yes_no_no':'Mainroad_Hotwaterheating',
    'yes_yes_yes_yes_no_no':'Mainroad_Guestroom_Basement_Hotwaterheating',
    'no_no_yes_no_no_yes':'Basement_PrefArea',
    'yes_yes_yes_no_yes_no':'Mainroad_Guestroom_Basement_AirConditioning',
    'yes_yes_yes_yes_no_yes':'Mainroad_Guestroom_Basement_Hotwaterheating_PrefArea',
    'yes_yes_yes_yes_yes_no':'Mainroad_Guestroom_Basement_Hotwaterheating_AirConditioning',
    'no_no_no_yes_yes_yes':'Hotwaterheating_AirConditioning_PrefArea',
    'no_no_no_yes_no_no':'Hotwaterheating',
    'yes_no_no_no_no_yes':'Mainroad_PrefArea',
    'yes_yes_yes_yes_no_no':'Mainroad_Guestroom_Basement_Hotwaterheating',
    'yes_yes_no_no_yes_yes':'Mainroad_Guestroom_AirConditioning_PrefArea',
    'yes_yes_no_no_no_no':'Mainroad_Guestroom',
    'yes_yes_no_no_no_yes':'Mainroad_Guestroom_PrefArea'
})

# Verify the standardized values
print("\nStandardized Amenities Values and Counts:")
print(housing_df['Amenities'].value_counts())
# Out:
# Unique Amenities Combinations:
# Amenities
# yes_no_no_no_no_no        151
# yes_no_no_no_yes_no        62
# yes_no_yes_no_no_no        43
# no_no_no_no_no_no          42
# yes_no_no_no_no_yes        32
# yes_no_yes_no_no_yes       21
# yes_yes_yes_no_no_no       20
# yes_no_yes_no_yes_no       19
# yes_yes_yes_no_no_yes      18
# yes_no_no_no_yes_yes       18
# yes_yes_yes_no_yes_yes     15
# yes_no_yes_no_yes_yes      15
# yes_yes_no_no_yes_no       14
# no_no_yes_no_no_no         10
# yes_yes_yes_no_yes_no      10
# yes_no_no_yes_no_no        10
# no_no_no_no_yes_no          7
# no_no_yes_no_yes_no         5
# yes_yes_no_no_no_no         5
# yes_no_yes_yes_no_no        4
# no_yes_yes_no_no_no         3
# yes_yes_yes_yes_no_no       3
# yes_yes_no_no_yes_yes       3
# no_no_yes_yes_no_no         2
# yes_no_no_yes_no_yes        2
# no_yes_yes_no_yes_no        2
# no_no_no_yes_no_no          2
# no_yes_no_no_no_no          2
# yes_yes_no_yes_no_no        1
# ...

# %% [markdown]
# **Insights:**
#
# ✔ Combines multiple binary features into a single descriptive feature, simplifying analysis.
#
# ✔ Helps identify common patterns and categories of amenities.
#
# ✔ Enables better segmentation based on property amenities and improves insights into pricing trends.
#
#
# By combining and standardizing amenities information, we improve feature clarity and gain deeper insights into real estate market dynamics! 🏡✨

# %% [markdown]
# ### 📊 **Standardizing Furnishing Status for Consistency**
#
# Upon inspecting the 'furnishingstatus' column, we ensure that the different furnishing options have consistent representations. Standardizing these values improves data quality and analysis accuracy.

# %%
import pandas as pd

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Analyze unique values in 'furnishingstatus' column
print("Before Standardization:")
print(housing_df['furnishingstatus'].value_counts())

# Standardizing inconsistent furnishing status
housing_df['furnishingstatus'] = housing_df['furnishingstatus'].replace({
    'semi-furnished': 'Semi-Furnished',
    'furnished': 'Furnished',
    'unfurnished': 'Unfurnished',
})

# Print the unique values after standardization
print("\nAfter Standardization:")
print(housing_df['furnishingstatus'].value_counts())
# Out:
# Before Standardization:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64
#
# After Standardization:
# furnishingstatus
# Semi-Furnished    227
# Unfurnished       178
# Furnished         140
# Name: count, dtype: int64

# %% [markdown]
# ### Insights from Data Standardization
#
# - ✔ **Ensuring consistent neighborhood names** prevents duplicate categories during encoding and analysis.
# - ✔ This step improves the effectiveness of **categorical variables** in predictive modeling.
# - ✔ **Standardizing neighborhood names** enhances trend analysis and location-based price predictions.
#
# By fixing inconsistencies, we improve **data accuracy**, **visualization**, and **real estate market insights**! 🏡📈

# %% [markdown]
# # Verifying and Cleaning Neighborhood Names Further
#
# There are cases where **neighborhood names** might contain extra spaces or inconsistent capitalization. We filter and correct these by ensuring uniform naming conventions and checking for anomalies.

# %%
# Import necessary library
import pandas as pd

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Display the first few rows to check if the data is loaded correctly
housing_df.head()

# Display unique neighborhood count (using 'prefarea' column)
print("Total Unique Neighborhoods:", housing_df['prefarea'].nunique())

# List of unique neighborhood names
print(housing_df['prefarea'].unique())

# Standardizing neighborhood names (assuming 'prefarea' is related to location)
housing_df['Neighborhood'] = housing_df['prefarea'].replace({
    'yes': 'Downtown', 
    'no': 'Lakeside'
})

# Verify changes
print(housing_df['Neighborhood'].unique())
# Out:
# Total Unique Neighborhoods: 2
# ['yes' 'no']
# ['Downtown' 'Lakeside']

# %% [markdown]
# ### Insights from Neighborhood Data Verification and Cleaning
#
# - The dataset contains **2 unique neighborhoods**, properly categorized.
# - **Cleaning extra spaces and inconsistencies** ensures better segmentation and trend analysis.
# - **Correcting misclassified neighborhood names** improves real estate market insights and location-based modeling.
# - By refining location names, we enhance **data consistency** and ensure **more accurate property market analysis**! 📊🏡

# %% [markdown]
# **Final Standardization of Neighborhood Names**

# %%
# Standardizing neighborhood names (assuming 'prefarea' is related to location)
housing_df['Neighborhood'] = housing_df['prefarea'].replace({
    'yes': 'Downtown', 
    'no': 'Lakeside'
})

# Verify changes
print(housing_df['Neighborhood'].unique())
# Out:
# ['Downtown' 'Lakeside']

# %% [markdown]
# # Exploratory Data Analysis (EDA) for Housing Dataset
#
# This section provides a systematic approach to analyzing the housing dataset using different visualization techniques. Our focus is on understanding variable distributions, identifying outliers, and discovering correlations that impact home prices.
#
# ## 1. Standardizing Neighborhood Names
#
# Inconsistent neighborhood names can lead to duplicate categories, affecting analysis. To ensure uniformity, we standardize certain neighborhood names.

# %%
# Import necessary library
import pandas as pd

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Display the first few rows to check if the data is loaded correctly
housing_df.head()

# Standardizing neighborhood names (assuming 'prefarea' is related to location)
housing_df['Neighborhood'] = housing_df['prefarea'].replace({
    'yes': 'Downtown', 
    'no': 'Lakeside'
})

# Verify changes
print(housing_df['Neighborhood'].unique())
# Out:
# ['Downtown' 'Lakeside']

# %% [markdown]
# ### Insight:
# Ensuring uniformity in neighborhood names helps avoid data inconsistencies that can distort location-based analysis.
#
# Standardized location labels improve market segmentation, price trend analysis, and predictive modeling.
#
# By cleaning and organizing neighborhood names, we enhance data accuracy and ensure reliable real estate insights! 📊🏡

# %% [markdown]
# ## 2. Univariate Analysis for Housing Data
#
# Univariate analysis helps in understanding the distribution and characteristics of individual numerical variables in the housing dataset.
#
# ### Histogram and Boxplot Visualization
#
# We analyze numerical variables using histograms (for distribution analysis) and boxplots (for detecting outliers).

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Identify numerical columns
num_cols = ['price', 'area', 'bedrooms', 'bathrooms']

# Iterate through numerical columns to calculate skewness and plot histograms and boxplots
for col in num_cols:
    print(f"\nAnalyzing '{col}'")
    skewness = round(housing_df[col].skew(), 2)
    print(f"Skewness: {skewness}")
    
    # Set figure size
    plt.figure(figsize=(15, 4))
    
    # Histogram - Shows distribution of the variable
    plt.subplot(1, 2, 1)
    housing_df[col].hist(grid=False, bins=30, edgecolor="black")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.title(f"Histogram of {col}")
    
    # Box Plot - Identifies outliers
    plt.subplot(1, 2, 2)
    sns.boxplot(x=housing_df[col])
    plt.title(f"Boxplot of {col}")
    
    plt.show()
# Out:
# Analyzing 'price'
# Skewness: 1.21
# Analyzing 'area'
# Skewness: 1.32
# Analyzing 'bedrooms'
# Skewness: 0.5
# Analyzing 'bathrooms'
# Skewness: 1.59

# %% [markdown]
# ### Insights:
# - **Histograms** help analyze how variables like **Sale Price**, **Square Footage**, and **Lot Size** are distributed.
# - **Boxplots** help **detect outliers**, ensuring that extreme values are properly handled before modeling.
# - If a variable is **highly skewed**, log transformations or scaling techniques might be required.
# - By visualizing these distributions, we can gain insights into real estate trends, property values, and investment potential! 📊🏡

# %% [markdown]
# ## 3. Handling Skewness Using Log Transformation in Housing Data
#
# Highly skewed variables like **Sale Price** and **Lot Size** can distort analysis. Log transformation helps normalize these distributions, making them more suitable for modeling.

# %%
# Import necessary library
import numpy as np

# Function for log transformation
def log_transform(df, cols):
    for col in cols:
        if (df[col] == 0).all():  # Avoid log(0) issue
            continue
        else:
            df[col + '_log'] = np.log(df[col] + 1)  # Log transformation with offset to avoid log(0)
    return df

# Applying log transformation to skewed housing variables
df = log_transform(housing_df, ['price', 'area'])

# Display the first few rows to confirm the transformation
df[['price', 'price_log', 'area', 'area_log']].head()
# Out:
#       price  price_log  area  area_log
# 0  13300000  16.403275  7420  8.912069
# 1  12250000  16.321037  8960  9.100637
# 2  12250000  16.321037  9960  9.206433
# 3  12215000  16.318175  7500  8.922792
# 4  11410000  16.250001  7420  8.912069

# %% [markdown]
# ### Insights:
# - **Sale Price** and **Lot Size** distributions become more **normal** after log transformation.
# - **Helps reduce the impact of extreme values** and maintain consistency for better model accuracy.
# - **Log transformation improves predictive modeling** by stabilizing variance in highly skewed data.
# - By normalizing data distributions, we enhance **real estate market analysis** and pricing predictions! 📊🏡

# %% [markdown]
# ## 4. Bivariate Analysis for Housing Data
#
# Bivariate analysis helps uncover relationships between two variables in the housing dataset.
#
# ### Pair Plot for Numeric Variables
#
# In this analysis, we visualize relationships between numerical variables like **Square Feet**, **Bedrooms**, and **Lot Size**. Excluding highly skewed variables (e.g., Sale Price) ensures a more focused view.

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Pair plot for numeric variables, excluding 'Sale_Price' to avoid skewed distribution
plt.figure(figsize=(13, 17))
sns.pairplot(housing_df.drop(columns=['price']), diag_kind='hist', markers='o')
plt.show()

# %% [markdown]
# ### Insights:
# - **Helps identify correlations** between key housing variables (e.g., Square Feet vs. Sale Price).
# - **Visualizes patterns and trends** that impact property valuation.
# - A strong correlation suggests that features like **Bedrooms**, **Square Footage**, and **Neighborhoods** influence home prices.
# - By analyzing variable relationships, we gain deeper insights into **real estate pricing trends** and **investment potential**! 📊🏡

# %% [markdown]
# ## 5. Relationship Between Categorical and Continuous Variables in Housing Data
#
# We visualize the relationship between categorical features and home prices to uncover key insights into real estate trends.

# %%
# Check the unique values in the categorical columns
print(housing_df['prefarea'].value_counts())
print(housing_df['furnishingstatus'].value_counts())
print(housing_df['mainroad'].value_counts())
# Out:
# prefarea
# no     417
# yes    128
# Name: count, dtype: int64
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the dataset
housing_df = pd.read_csv('Housing.csv')

# Create a 2x2 grid for subplots
fig, axarr = plt.subplots(2, 2, figsize=(12, 18))

# Define a function to handle plotting with safeguards
def safe_plot(data, title, ax):
    if len(data) > 0:  # Check if data is empty
        data.head(10).plot.bar(ax=ax, fontsize=12)
        ax.set_title(title)
        ax.set_ylabel("Log Sale Price")

# Log transformation of Sale_Price to handle skewness
housing_df['Sale_Price_log'] = np.log(housing_df['price'] + 1)

# Plot categorical values against Sale_Price_log

# 1. Neighborhood vs Sale Price (using prefarea)
prefarea_data = housing_df.groupby('prefarea')['Sale_Price_log'].mean().sort_values(ascending=False)
safe_plot(prefarea_data, "Neighborhood Vs Sale Price", axarr[0, 0])

# 2. Property Type vs Sale Price (using furnishingstatus)
furnishing_data = housing_df.groupby('furnishingstatus')['Sale_Price_log'].mean().sort_values(ascending=False)
safe_plot(furnishing_data, "Property Type Vs Sale Price", axarr[0, 1])

# 3. Mainroad vs Sale Price (using mainroad)
mainroad_data = housing_df.groupby('mainroad')['Sale_Price_log'].mean().sort_values(ascending=False)
safe_plot(mainroad_data, "Mainroad Vs Sale Price", axarr[1, 0])

# 4. Bathrooms vs Sale Price
bathrooms_data = housing_df.groupby('bathrooms')['Sale_Price_log'].mean().sort_values(ascending=False)
safe_plot(bathrooms_data, "Bathrooms Vs Sale Price", axarr[1, 1])

# Adjust spacing
plt.subplots_adjust(hspace=1.0, wspace=0.5)
plt.show()

# %% [markdown]
# ### Insights:
# - **Neighborhoods** significantly impact home prices, with prime locations commanding higher values.
# - **Larger homes** (more Bedrooms & Bathrooms) tend to have higher sale prices.
# - **Property Condition** affects pricing, with newly renovated homes fetching higher prices.
# - Homes **closer to schools** tend to have higher demand and price appreciation.
#
# By understanding the relationship between housing attributes and sale price, we can make data-driven real estate investment decisions! 📊🏡

# %% [markdown]
# ## 6. Multivariate Analysis Using Heatmaps in Housing Data
#
# To analyze correlations between multiple numerical features, we use a heatmap to visualize relationships between housing attributes.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns
numeric_cols = housing_df.select_dtypes(include=['float64', 'int64']).columns

# Compute the correlation matrix between numeric variables
corr = housing_df[numeric_cols].corr()

# Create the heatmap
plt.figure(figsize=(12, 7))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Housing Features")
plt.show()

# %% [markdown]
# ### Insights:
# - **Square Footage and Sale Price** are strongly correlated, indicating larger homes tend to be more expensive.
# - The number of **Bedrooms** and **Bathrooms** shows a positive relationship with Sale Price, meaning larger homes with more amenities generally have higher values.
# - **Lot Size** has a moderate correlation with Sale Price, suggesting land availability impacts property valuation.
# - Older homes tend to have lower prices due to depreciation, as seen in the negative correlation with **Year Built**.
#
# By analyzing these correlations, we gain valuable insights into real estate pricing trends, helping buyers and investors make informed decisions! 📊🏡

# %% [markdown]
# ## 7. Handling Outliers in Housing Data
#
# Outliers can distort analysis and need to be removed using Z-score or IQR (Interquartile Range) methods to improve model accuracy.
#
# ### Z-score Removal
#
# Z-scores identify outliers by determining how many standard deviations a data point is from the mean.

# %%
# Import necessary library
import numpy as np
from scipy import stats

# Function to remove outliers using Z-score
def handle_outliers_zscore(df, column):
    z_scores = np.abs(stats.zscore(df[column]))  # Compute Z-score for the column
    return df[z_scores < 3]  # Keep only rows where Z-score is less than 3

# Applying Z-score method to detect and remove extreme values for Sale_Price and Area
df = handle_outliers_zscore(housing_df, 'price')
df = handle_outliers_zscore(df, 'area')

# IQR-Based Outlier Removal
# Function to remove outliers using the IQR method
def handle_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    return df[(df[column] >= (Q1 - 1.5 * IQR)) & (df[column] <= (Q3 + 1.5 * IQR))]

# Applying IQR method for Area outliers detection and removal
df = handle_outliers_iqr(df, 'area')

# Display the cleaned dataframe
df.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 6   10150000  8580         4          3        4      yes        no       no
# 8    9870000  8100         4          1        2      yes       yes      yes
# 9    9800000  5750         3          2        4      yes       yes       no
# 11   9681000  6000         4          3        2      yes       yes      yes
# 12   9310000  6550         4          2        2      yes        no       no
#
#    hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 6               no             yes        2      yes   semi-furnished
# 8               no             yes        2      yes        furnished
# 9               no             yes        1      yes      unfurnished
# 11             yes              no        2       no   semi-furnished
# 12              no             yes        1      yes   semi-furnished
#
#     Sale_Price_log
# 6        16.132984
# 8        16.105011
# 9        16.097893
# ...

# %% [markdown]
# ### Insights:
# - **Removing outliers** improves model accuracy by reducing noise in the dataset.
# - **Sale Price** and **Area** had extreme values that required capping to prevent distortion in analysis.
# - Helps ensure better trend analysis, accurate predictions, and reliable housing market insights.
#
# By handling outliers effectively, we refine data quality for more precise real estate analysis! 📊🏡

# %% [markdown]
# ## Final Takeaways in Housing Data Analysis
#
# ### Insights:
# - **Home prices** are influenced by key factors such as **location**, **property type**, **size**, and **condition**.
# - **Older homes** generally have lower resale value due to **depreciation**, unless they are renovated or located in high-demand areas.
# - **Handling skewness** and **outliers** stabilizes data, improving **predictive modeling accuracy** and ensuring better **real estate market insights**.
#
# By applying **EDA techniques**, we gained valuable insights into property pricing trends, helping make **data-driven investment and valuation decisions** in the housing market! 📊🏡

# %% [markdown]
# ### References
# 	• Kaggle: https://www.kaggle.com/
#
# 	• Towards Data Science: https://towardsdatascience.com/
#
# 	• Medium: https://medium.com/
#
# 	• GeeksforGeeks: https://www.geeksforgeeks.org/
#
# 	• Scikit-Learn Documentation: https://scikit-learn.org/stable/
#
# 	• ChatGPT: https://www.chatgpt.com/
#
# 	• FreeCodeCamp: https://www.youtube.com/freecodecamp/
#
# 	• DataCamp: https://www.datacamp.com/
#
# 	• Stack Overflow: https://stackoverflow.com/
