# %% [markdown]
# <center> <h1> FIFA PLAYER ANALYSIS</h1> </center>

# %% [markdown]
# <center> <h1> Assignment 1: Understanding data : Part 1</h1> </center>
# <center> <h3> INFO 7390: Advance Data Science </h3> </center>
# <center> <h3> Vinay Jogani, NEU ID: 002839145 </h3> </center>

# %% [markdown]
# ### Research Questions:
#
# 1. What is the question being researched ?
#
# The research questions revolve around exploring and understanding the characteristics of football players based on the FIFA dataset. Some specific questions include investigating player positions, foot preferences, distribution of ratings, correlations between attributes, and other player-related analyses.
#
# 2. Why is it interesting?
#
# The analysis is interesting because it provides insights into various aspects of football player data. Understanding player distribution across positions, foot preferences, and exploring correlations between attributes can offer valuable information for team managers, coaches, and fans. It allows for a deeper understanding of player demographics and performance metrics, contributing to strategic decision-making in the world of football.
#
# 3. What is the theory behind it?
#
# The theoretical foundation lies in the idea that player attributes, positions, and foot preferences contribute to the overall dynamics of a football team. Exploring correlations, distributions, and characteristics through data analysis can reveal patterns and trends that may influence team composition, strategy development, and scouting processes. The analysis may also uncover insights into how specific attributes or player types are distributed across different positions and foot preferences.
#
# ### Findings from Exploratory Data Analysis:
#
# 1. **Initialization and Library Import:** Setting up the necessary tools and importing libraries to commence data analysis.
#
# 2. **Fundamental DataFrame Operations:** Executing elementary operations on the dataset to comprehend its structure and characteristics.
#
# 3. **Handling Missing Values:** Addressing missing data points to ensure the integrity and quality of the dataset.
#
# 4. **Creation of Player-specific DataFrames:** Grouping players based on their respective positions to facilitate targeted and focused analysis.
#
# 5. **Data Aggregation and Pivoting:** Employing group-by and pivoting operations to aggregate and reshape data for specific analytical insights.
#
# 6. **Visualization: Total Players Across Positions:** Gaining insights into player distribution by visualizing the total count across various playing positions.
#
# 7. **Analysis of Foot Type Distribution:** Examining the prevalence of different foot types among players to understand their playing preferences.
#
# 8. **Boxplot Analysis: Foot Distribution per Rating:** Utilizing boxplots to explore the distribution of foot types within distinct rating categories.
#
# 9. **Exploration: Foot Type Distribution Across Positions:** Investigating the distribution of foot types among players based on their respective positions.
#
# 10. **Correlation Analysis: Ratings vs. Defending Attributes:** Investigating the potential relationship or correlation between overall player ratings and their defending attributes.
#
# 11. **Graphical Exploration: Rating vs. Goalkeeper Handling:** Visualizing the correlation between overall ratings and handling attributes specifically for goalkeepers.
#
# 12. **Heatmap Visualization: Goalkeeper Attribute Correlation:** Creating a heatmap to visualize the correlation matrix among all attributes specific to goalkeepers.
#
# 13. **Rating Distribution Analysis:** Examining the distribution of player ratings to understand the overall performance landscape.
#
# 14. **KDE Plot Analysis: Ratings Across Player Types:** Utilizing Kernel Density Estimation (KDE) plots to visualize the distribution of player ratings across different player types, such as positions.
#
# 15. **Count Analysis: Rare Players Across Positions:** Analyzing and counting the occurrences of rare players within each player position category.
#
# ### Overall Implications:
#
# The findings contribute to a comprehensive understanding of player demographics, positional distributions, attribute correlations, and foot preferences in football. These insights can inform decision-making processes in team management, player scouting, and strategic planning within the football industry.

# %% [markdown]
# Exploratory Data Analysis (EDA) is a crucial step in the data analysis process that involves examining and understanding the characteristics of a dataset. The importance of EDA lies in its ability to provide valuable insights, reveal patterns, and guide further analysis. Here are some reasons why understanding data through EDA is essential:
#
# 1. **Identifying Patterns and Trends:**
#    - EDA helps in identifying patterns and trends within the data. Visualization techniques such as scatter plots, line charts, and histograms can reveal relationships and distributions that may be important for analysis.
#
# 2. **Spotting Anomalies and Outliers:**
#    - By exploring the data, outliers or anomalies that deviate from the general pattern can be identified. Understanding these anomalies is crucial as they may indicate errors, special cases, or interesting phenomena.
#
# 3. **Assessing Data Quality:**
#    - EDA allows for an assessment of data quality. Detecting missing values, inconsistencies, or errors in the dataset helps in cleaning and preprocessing data for more accurate analyses.
#
# 4. **Determining Data Distributions:**
#    - Understanding the distribution of data is vital for making statistical inferences. EDA provides insights into whether data follows a normal distribution, is skewed, or exhibits other characteristics.
#
# 5. **Feature Engineering:**
#    - EDA aids in feature engineering by helping to identify relevant features or variables that are likely to have a significant impact on the analysis or prediction task.
#
# 6. **Formulating Hypotheses:**
#    - EDA helps in formulating hypotheses about the relationships within the data. These hypotheses can guide further analysis and testing.
#
# 7. **Data Exploration for Modeling:**
#    - Before building a predictive model, it is essential to explore the data to understand the relationships between variables. This exploration informs the selection of appropriate models and features.
#
# 8. **Understanding Data Context:**
#    - Understanding the context of the data is crucial. EDA provides insights into the real-world implications of the data, helping analysts and stakeholders make informed decisions.
#
# 9. **Enhancing Communication:**
#    - Effective communication of findings is key. EDA produces visualizations and summaries that can be easily communicated to non-technical stakeholders, facilitating better decision-making.
#
# 10. **Guiding Further Analysis:**
#     - EDA guides the selection of statistical methods, machine learning algorithms, and other analysis techniques based on the characteristics and patterns observed in the data.
#
# 11. **Iterative Process:**
#     - EDA is often an iterative process. Initial insights may lead to further questions and refinements in the analysis, driving a deeper understanding of the data.
#
# In summary, the importance of understanding data through Exploratory Data Analysis cannot be overstated. It lays the foundation for informed decision-making, helps in uncovering hidden insights, and ensures the reliability and quality of subsequent analyses and models. EDA is a dynamic and iterative process that plays a crucial role in extracting meaningful knowledge from data.

# %% [markdown]
# Understanding data involves considering various aspects, including the types of data, data quality, and its components. Let's explore these concepts:
#
# ### Types of Data:
#
# 1. **Categorical Data:**
#    - Represents categories or labels.
#    - Examples: Gender (Male/Female), Color (Red/Blue/Green).
#
# 2. **Numerical Data:**
#    - Represents measurable quantities.
#    - Two subtypes:
#       - **Discrete:** Countable and finite.
#          - Examples: Number of goals scored, Number of students in a class.
#       - **Continuous:** Infinite possibilities within a range.
#          - Examples: Height, Weight, Temperature.
#
# 3. **Ordinal Data:**
#    - Represents categories with a meaningful order or rank.
#    - Examples: Educational levels (High School, Bachelor's, Master's).
#
# 4. **Binary Data:**
#    - A special case of categorical data with only two categories.
#    - Examples: Yes/No, True/False, 0/1.
#
# ### Data Quality and Its Components:
#
# Data quality refers to the accuracy, completeness, consistency, timeliness, and reliability of data. Several components contribute to data quality:
#
# 1. **Accuracy:**
#    - How well the data reflects the true value or state of the object it represents.
#
# 2. **Completeness:**
#    - The extent to which data includes all required information without missing values.
#
# 3. **Consistency:**
#    - The absence of contradictions or discrepancies in the data.
#
# 4. **Timeliness:**
#    - The relevance of the data with respect to the time frame it represents.
#
# 5. **Reliability:**
#    - The degree to which the data can be trusted or depended upon.
#
# 6. **Relevance:**
#    - The significance of the data in relation to the purpose for which it is collected.
#
# 7. **Validity:**
#    - The extent to which the data conforms to defined rules or standards.
#
# 8. **Precision:**
#    - The level of detail or granularity in the data.
#
# 9. **Currency:**
#    - The up-to-date nature of the data.
#
# ### Data Quality Frameworks:
#
# Frameworks such as the **"Six Sigma"** or **"Data Quality Dimensions"** model provide a structured approach to assessing and improving data quality.
#
# **Six Sigma Data Quality Dimensions:**
# 1. **Data Accuracy**
# 2. **Data Completeness**
# 3. **Data Consistency**
# 4. **Data Timeliness**
# 5. **Data Relevance**
# 6. **Data Precision**
#
# Understanding these aspects of data helps organizations make informed decisions, ensures the reliability of analyses, and supports various business processes. It is essential to implement data quality management practices to maintain high-quality data throughout its lifecycle.

# %% [markdown]
# In this assignment we will be exploring Fifa.csv dataset which has 19 attributes.

# %% [markdown]
# ### Task 1: Initialization and Library Import
# **i. Import Required libraries and Data File**

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
url="https://raw.githubusercontent.com/nikbearbrown/INFO_7390_Art_and_Science_of_Data/main/Understanding_Data/Spring2024/fifa.csv"

# %% [markdown]
# **ii. Read Fifa.csv file**

# %%
# Reading the "Fifa.csv" file in the directory
data_fifa = pd.read_csv(url);

# %% [markdown]
# **iii. Copy dataframe in variable df**

# %%
# Copy the 'data_fifa' to 'df' for furthur analysis
df = data_fifa.copy()

# %% [markdown]
# ### Task 2: Fundamental DataFrame Operations </h3>

# %% [markdown]
# **i. Display the first five rows of the dataframe**

# %%
# Displaying the number of top 5 rows
df.head()
# Out:
#        id                     name   rating  position   height    foot   rare  \
# 0    1001             Gábor Király       69        GK      191   Right      0
# 1  100143             Frederik Boi       65         M      184   Right      0
# 2  100264          Tomasz Szewczuk       57         A      185   Right      0
# 3  100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 4  100326             Kamel Chafni       72         M      181   Right      0
#
#    pace  shooting  passing  dribbling  defending  heading  diving  handling  \
# 0                                                              70        66
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66
#
#    kicking  reflexes  speed   positioning
# 0       63        74     35          66.0
# ...

# %% [markdown]
# **ii. Present the names of the columns in the DataFrame.**

# %%
# Displaying the all columns of the dataset
print(df.columns)
# Out:
# Index(['id', ' name', ' rating', ' position', ' height', ' foot', ' rare',
#        ' pace', ' shooting', ' passing', ' dribbling', ' defending',
#        ' heading', ' diving', ' handling', ' kicking', ' reflexes', ' speed',
#        ' positioning'],
#       dtype='object')

# %% [markdown]
# It looks like you provided the column names of a FIFA dataset. Here's a brief description of each column:
#
# 1. **id:** Unique identifier for each player.
# 2. **name:** Player's name.
# 3. **rating:** Player's overall rating in the FIFA game.
# 4. **position:** Player's primary playing position.
# 5. **height:** Player's height.
# 6. **foot:** Player's preferred foot (e.g., left, right).
# 7. **rare:** Indicates whether the player is considered rare.
# 8. **pace:** Player's rating for pace attribute.
# 9. **shooting:** Player's rating for shooting attribute.
# 10. **passing:** Player's rating for passing attribute.
# 11. **dribbling:** Player's rating for dribbling attribute.
# 12. **defending:** Player's rating for defending attribute.
# 13. **heading:** Player's rating for heading attribute.
# 14. **diving:** Goalkeeper's rating for diving attribute.
# 15. **handling:** Goalkeeper's rating for handling attribute.
# 16. **kicking:** Goalkeeper's rating for kicking attribute.
# 17. **reflexes:** Goalkeeper's rating for reflexes attribute.
# 18. **speed:** Goalkeeper's rating for speed attribute.
# 19. **positioning:** Goalkeeper's rating for positioning attribute.
#
# This dataset seems to contain various attributes and ratings for football players, with a focus on attributes relevant to different positions and goalkeepers. The attributes such as pace, shooting, passing, etc., are likely on a scale representing the player's proficiency in those aspects of the game. The dataset can be used for analysis related to player performance, team composition, and other aspects of FIFA gameplay.

# %% [markdown]
# **iii. Eliminate additional spaces within the column names.**

# %%
# Removing the extra space in columns names to avoid error for furthur analysis
df.columns = df.columns.str.strip()

# %%
df = df.rename(columns=lambda x: x.strip())
print(df.columns)
# Out:
# Index(['id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving',
#        'handling', 'kicking', 'reflexes', 'speed', 'positioning'],
#       dtype='object')

# %% [markdown]
# **iv. Check data type of columns**

# %%
# Defining a function that returns the data type of a column
print(df.dtypes)
# Out:
# id               int64
# name            object
# rating           int64
# position        object
# height           int64
# foot            object
# rare             int64
# pace            object
# shooting        object
# passing         object
# dribbling       object
# defending       object
# heading         object
# diving          object
# handling        object
# kicking         object
# reflexes        object
# speed           object
# positioning    float64
# dtype: object

# %% [markdown]
# **v. Get the Last five rows of dataframe**

# %%
# Displaying the number of last 5 row
last_five_rows = df.tail(5)
print(last_five_rows)
# Out:
#         id              name  rating position  height    foot  rare pace  \
# 8842  9801   Danijel Ljuboja      73        A     189    Left     1   62
# 8843  9805     Craig Bellamy      79        A     175   Right     0   80
# 8844  9807     Michel Breuer      68        D     183   Right     0   61
# 8845  9815       Gill Swerts      65        D     179   Right     0   65
# 8846  9913       Mehdi Nafti      69        M     179   Right     0   55
#
#      shooting passing dribbling defending heading diving handling kicking  \
# 8842       73      64        74        56      68
# 8843       78      67        81        62      71
# 8844       40      56        51        70      74
# 8845       48      63        65        67      69
# 8846       56      64        65        69      60
#
#      reflexes speed  positioning
# 8842                         NaN
# 8843                         NaN
# 8844                         NaN
# 8845                         NaN
# ...

# %% [markdown]
# ### <font style='color:red'>Question:</font> What insights can be derived from examining both the initial five and final five rows of the dataset?

# %% [markdown]
# *Hint: Some values are not filled for certain types of positions.*

# %% [markdown]
# ### <font style="color:green">Answer:</font> As observed, there are instances where values are missing for specific types of positions. Our first step is to address these missing values. We need to ascertain whether the absence of data is due to an issue in the data collection process or if it reflects genuine gaps in information. To ensure data consistency and completeness for further analysis, we will systematically re-fill or replace certain values as needed.

# %% [markdown]
# Data pre-processing is a crucial step in the data analysis pipeline. It involves cleaning and transforming raw data into a format suitable for analysis. Here are some common techniques and approaches for data pre-processing:
#
# ### Data Cleaning Techniques:
#
# 1. **Handling Duplicate Data:**
#    - Identify and remove duplicate records to avoid redundancy.
#
# 2. **Handling Outliers:**
#    - Detect and handle outliers, which are data points significantly different from the rest of the dataset.
#    - Techniques include trimming, winsorizing, or imputing outliers.
#
# 3. **Handling Inconsistent Data:**
#    - Address inconsistencies in data formats, units, or representations.
#
# 4. **Handling Noisy Data:**
#    - Remove or smooth noisy data points that may be errors or outliers.
#
# 5. **Handling Erroneous Data:**
#    - Identify and correct errors in the data that can impact analysis.
#
# ### Data Transformation Methods:
#
# 1. **Normalization:**
#    - Scale numeric features to a standard range (e.g., between 0 and 1) to ensure equal influence during analysis.
#
# 2. **Standardization:**
#    - Transform data to have a mean of 0 and a standard deviation of 1.
#    - Useful when features have different units or scales.
#
# 3. **Log Transformation:**
#    - Apply logarithmic transformation to handle data with a wide range of values or skewed distributions.
#
# 4. **Binning/Discretization:**
#    - Convert continuous data into discrete bins or categories.
#
# ### Data Normalization Approaches:
#
# 1. **Min-Max Scaling:**
#    - Scales data to a specific range (e.g., between 0 and 1).
#
# 2. **Z-Score Normalization (Standardization):**
#    - Standardizes data by subtracting the mean and dividing by the standard deviation.
#
# 3. **Robust Scaling:**
#    - Scales data by removing the median and scaling to the interquartile range.
#    - Less sensitive to outliers compared to Min-Max scaling.
#
# ### Handling Missing Data and Imputation Techniques:
#
# 1. **Deletion:**
#    - Remove records or columns with missing values.
#    - Simple but may result in loss of valuable information.
#
# 2. **Mean/Median/Mode Imputation:**
#    - Replace missing values with the mean, median, or mode of the respective column.
#    - Useful for numerical features.
#
# 3. **Forward Fill/Backward Fill:**
#    - Propagate the last observed value forward or use the next observed value backward to fill missing values in time series data.
#
# 4. **Interpolation:**
#    - Estimate missing values based on existing data points using interpolation methods.
#
# 5. **Multiple Imputation:**
#    - Generate multiple plausible values for missing data to account for uncertainty.
#    - Often used for complex datasets.
#
# Data pre-processing is a dynamic process, and the techniques applied depend on the specific characteristics of the dataset and the goals of the analysis. It is important to carefully choose and evaluate these techniques to ensure the integrity and reliability of the data for subsequent analysis.

# %% [markdown]
# **vi. Generate a statistical summary for the columns containing numerical data**

# %%
# Getting the statistical summary using describe function()
df.describe()
# Out:
#                   id       rating       height         rare  positioning
# count    8847.000000  8847.000000  8847.000000  8847.000000   930.000000
# mean   152337.538035    66.680457   181.750424     0.353114    64.955914
# std     54506.606056     7.146679     6.454356     0.477965     8.854231
# min         2.000000    40.000000   158.000000     0.000000    37.000000
# 25%    140001.500000    62.000000   178.000000     0.000000    59.000000
# 50%    171578.000000    66.000000   182.000000     0.000000    65.000000
# 75%    189185.000000    72.000000   186.000000     1.000000    71.000000
# max    205583.000000    94.000000   208.000000     1.000000    91.000000

# %% [markdown]
# **vii. Display the statistical summary for columns with object data type in the DataFrame.**

# %%
# Getting the statistical summary of object type of columns using describe function('O')
df.describe(include=['O'])
# Out:
#              name position    foot  pace shooting passing dribbling defending  \
# count        8847     8847    8847  8847     8847    8847      8847      8847
# unique       8678        4       2    73       80      76        76        64
# top      Henrique        M   Right
# freq            5     3041    6762   930      930     930       930       930
#
#        heading diving handling kicking reflexes speed
# count     8847   8847     8847    8847     8847  8847
# unique      67     49       45      53       53    54
# top
# freq       930   7917     7917    7917     7917  7917

# %% [markdown]
# **viii. Display the statistical summary for all columns in the dataframe.**

# %%
# Getting the statistical summary of object type of all the columns using describe function('all')
df.describe(include='all')
# Out:
#                    id       name       rating position       height    foot  \
# count     8847.000000       8847  8847.000000     8847  8847.000000    8847
# unique            NaN       8678          NaN        4          NaN       2
# top               NaN   Henrique          NaN        M          NaN   Right
# freq              NaN          5          NaN     3041          NaN    6762
# mean    152337.538035        NaN    66.680457      NaN   181.750424     NaN
# std      54506.606056        NaN     7.146679      NaN     6.454356     NaN
# min          2.000000        NaN    40.000000      NaN   158.000000     NaN
# 25%     140001.500000        NaN    62.000000      NaN   178.000000     NaN
# 50%     171578.000000        NaN    66.000000      NaN   182.000000     NaN
# 75%     189185.000000        NaN    72.000000      NaN   186.000000     NaN
# max     205583.000000        NaN    94.000000      NaN   208.000000     NaN
#
# ...

# %% [markdown]
# ### Task 3: Handling Missing Values:

# %% [markdown]
# **i. Determine the count of null or missing values in each column.**

# %%
# Counting the number of nulls values in all the each columns
df.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# position          0
# height            0
# foot              0
# rare              0
# pace              0
# shooting          0
# passing           0
# dribbling         0
# defending         0
# heading           0
# diving            0
# handling          0
# kicking           0
# reflexes          0
# speed             0
# positioning    7917
# dtype: int64

# %% [markdown]
# **ii. Substitute any additional spaces with NaN values**

# %%
# Replacing all the extra number of space with the value "NaN" 
df.replace(' ', 'NaN' , inplace = True)
df
# Out:
#           id                     name  rating position  height    foot  rare  \
# 0       1001             Gábor Király      69       GK     191   Right     0
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %% [markdown]
# **iii. Replace any missing values in the dataframe with zero.**

# %%
# Replacing all the "NaN" number of values with '0' 
df.replace('NaN', 0 , inplace = True)
df
# Out:
#           id                     name  rating position  height    foot  rare  \
# 0       1001             Gábor Király      69       GK     191   Right     0
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %%
## Replacing all the NaN values of positioning with the median() function 
df['positioning'].fillna(df['positioning'].median(), inplace=True)
df
# Out:
#           id                     name  rating position  height    foot  rare  \
# 0       1001             Gábor Király      69       GK     191   Right     0
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %% [markdown]
# **iv. Determine the player count for each playing position.**

# %%
# Counting the number of unique values in the position column
df['position'].unique().sum()
# Out:
# ' GK M A D'

# %% [markdown]
# **v. Examine the data types of each column in the dataset**

# %%
# Defining a function that returns the data type of a columns
print(df.dtypes)
# Out:
# id               int64
# name            object
# rating           int64
# position        object
# height           int64
# foot            object
# rare             int64
# pace            object
# shooting        object
# passing         object
# dribbling       object
# defending       object
# heading         object
# diving          object
# handling        object
# kicking         object
# reflexes        object
# speed           object
# positioning    float64
# dtype: object

# %% [markdown]
# **vi. Convert the data types of 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving', 'handling', 'kicking', 'reflexes', 'speed', and 'positioning' to integers.**

# %%
# Changing the Data type of certain columns into integer type using cast
df['id'] = df['id'].astype(np.int32, errors='ignore')
df['rating'] = df['rating'].astype(np.int32, errors='ignore')
df['height'] = df['height'].astype(np.int32, errors='ignore')
df['rare'] = df['rare'].astype(np.int32, errors='ignore')
df['pace'] = df['pace'].astype(np.int32, errors='ignore')
df['shooting'] = df['shooting'].astype(np.int32, errors='ignore')
df['passing'] = df['pace'].astype(np.int32, errors='ignore')
df['dribbling'] = df['pace'].astype(np.int32, errors='ignore')
df['defending'] = df['shooting'].astype(np.int32, errors='ignore')
df['heading'] = df['pace'].astype(np.int32, errors='ignore')
df['diving'] = df['pace'].astype(np.int32, errors='ignore')
df['handling'] = df['shooting'].astype(np.int32, errors='ignore')
df['kicking'] = df['pace'].astype(np.int32, errors='ignore')
df['reflexes'] = df['pace'].astype(np.int32, errors='ignore')
df['speed'] = df['shooting'].astype(np.int32, errors='ignore')
df['positioning'] = df['pace'].astype(np.int32, errors='ignore')
print(df.dtypes)
# Out:
# id              int32
# name           object
# rating          int32
# position       object
# height          int32
# foot           object
# rare            int32
# pace            int32
# shooting        int32
# passing         int32
# dribbling       int32
# defending       int32
# heading         int32
# diving          int32
# handling        int32
# kicking         int32
# reflexes        int32
# speed           int32
# positioning     int32
# dtype: object

# %%
# Displaying the total dataset for analysis
df
# Out:
#           id                     name  rating position  height    foot  rare  \
# 0       1001             Gábor Király      69       GK     191   Right     0
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %% [markdown]
# ### Task 4: Creation of Player-specific DataFrames:

# %% [markdown]
# **Divide the dataframe into two distinct sets: one comprising all the attributes of goalkeepers, and the other containing attributes of all remaining players.**

# %%
# Spliting the dataset into two category assuming the features "Goal keeper" and "other players" 
df_goalkeeper= df[df['position'] == 'GK']
df_goalkeeper.head()
# Out:
# Empty DataFrame
# Columns: [id, name, rating, position, height, foot, rare, pace, shooting, passing, dribbling, defending, heading, diving, handling, kicking, reflexes, speed, positioning]
# Index: []

# %% [markdown]
# <span style="color:green">**As you can see that the dataframe is empty and no value has been assigned to it. Let's check out the issue.**</span>

# %% [markdown]
# **i. Split the dataframe into two separate sets: one containing all attributes specific to goalkeepers, and the other encompassing attributes for all other player positions**

# %%
# Displaying the number of unique values in the position column
df['position'].unique()
# Out:
# array([' GK', ' M', ' A', ' D'], dtype=object)

# %% [markdown]
# <span style="color:green">**From the above output, you can see that there is an extra space in the position reffered to as GK.**</span>

# %% [markdown]
# **ii. Eliminate additional spaces within the 'position' column and transform entries like ' GK' to 'GK'. Subsequently, create a new DataFrame specifically for goalkeepers. Utilize the str.replace method for this task**<br>

# %%
# Remoing the extra spaces of unique values in the position column
df['position'] = df['position'].str.strip()
df = df.rename(columns=lambda x: x.strip())

# %% [markdown]
# **iii. Create a new DataFrame specifically for goalkeepers using the existing DataFrame named df_goalkeeper**

# %%
# Making the dataset with the feature of position "Goal keeper"
df_goalkeeper= df[df['position'] == 'GK']
df_goalkeeper.head()
# Out:
#         id                name  rating position  height    foot  rare  pace  \
# 0     1001        Gábor Király      69       GK     191   Right     0     0
# 20  100745          Paul Smith      64       GK     193   Right     1     0
# 29  100807   Stefanos Kotsolis      65       GK     190   Right     0     0
# 31  100899      Steve Phillips      61       GK     185   Right     1     0
# 39  101282         Oka Nikolov      70       GK     188   Right     0     0
#
#     shooting  passing  dribbling  defending  heading  diving  handling  \
# 0          0        0          0          0        0       0         0
# 20         0        0          0          0        0       0         0
# 29         0        0          0          0        0       0         0
# 31         0        0          0          0        0       0         0
# 39         0        0          0          0        0       0         0
#
#     kicking  reflexes  speed  positioning
# ...

# %% [markdown]
# **iv. Create a new DataFrame specifically for goalkeepers, including only the following columns: 'id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'diving', 'handling', 'kicking', 'reflexes', 'speed', 'positioning'. Remove any other columns not listed in this selection.**

# %%
# Making a new dataset having specific columns and dropping all the other columns.
drop_columns_goalkeeper = ['id', 'name', 'rating', 'position', 'height', 'foot',' rare','diving', 'handling', 'kicking', 'reflexes', 'speed','positioning']
df_goalkeeper = df.drop(columns=[col for col in df.columns if col not in drop_columns_goalkeeper], axis=1) 
df_goalkeeper
# Out:
#           id                     name  rating position  height    foot  \
# 0       1001             Gábor Király      69       GK     191   Right
# 1     100143             Frederik Boi      65        M     184   Right
# 2     100264          Tomasz Szewczuk      57        A     185   Right
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left
# 4     100326             Kamel Chafni      72        M     181   Right
# ...      ...                      ...     ...      ...     ...     ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left
# 8843    9805            Craig Bellamy      79        A     175   Right
# 8844    9807            Michel Breuer      68        D     183   Right
# 8845    9815              Gill Swerts      65        D     179   Right
# 8846    9913              Mehdi Nafti      69        M     179   Right
#
#       diving  handling  kicking  reflexes  speed  positioning
# ...

# %% [markdown]
# ### Create a new DataFrame, named df_players, containing information about all players excluding the goalkeepers.

# %%
# Displaying the number of players only having features of position "Goal Keeper"
df_goalkeeper_matched = df_goalkeeper[df_goalkeeper['position'] == 'GK']
df_goalkeeper_matched
# Out:
#           id                name  rating position  height    foot  diving  \
# 0       1001        Gábor Király      69       GK     191   Right       0
# 20    100745          Paul Smith      64       GK     193   Right       0
# 29    100807   Stefanos Kotsolis      65       GK     190   Right       0
# 31    100899      Steve Phillips      61       GK     185   Right       0
# 39    101282         Oka Nikolov      70       GK     188   Right       0
# ...      ...                 ...     ...      ...     ...     ...     ...
# 8799     806     Mathias Schober      69       GK     191    Left       0
# 8806    8247               Palop      77       GK     184   Right       0
# 8827    8910          Carlo Nash      63       GK     182   Right       0
# 8828     899          Frank Rost      74       GK     194   Right       0
# 8839    9751         Gábor Babos      71       GK     196   Right       0
#
#       handling  kicking  reflexes  speed  positioning
# ...

# %% [markdown]
# **v. Create a new DataFrame, named df_players, containing information about all players excluding the goalkeepers.**

# %%
# Displaying the number of players not having the features of position "Goal Keeper"
df_goalkeeper_unmatched = df_goalkeeper[df_goalkeeper['position'] != 'GK']
df_goalkeeper_unmatched
# Out:
#           id                     name  rating position  height    foot  \
# 1     100143             Frederik Boi      65        M     184   Right
# 2     100264          Tomasz Szewczuk      57        A     185   Right
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left
# 4     100326             Kamel Chafni      72        M     181   Right
# 5     100329           Abdoulaye Faye      72        D     187   Right
# ...      ...                      ...     ...      ...     ...     ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left
# 8843    9805            Craig Bellamy      79        A     175   Right
# 8844    9807            Michel Breuer      68        D     183   Right
# 8845    9815              Gill Swerts      65        D     179   Right
# 8846    9913              Mehdi Nafti      69        M     179   Right
#
#       diving  handling  kicking  reflexes  speed  positioning
# ...

# %% [markdown]
# **vi. The DataFrame for non-goalkeeper players should only include the columns 'id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace', 'shooting', 'passing', 'dribbling', 'defending', and 'heading'. Please remove any other columns.**

# %%
# Making a new dataset having specific columns and dropping all the other columns.
drop_columns_players = [ 'id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'heading']
df_players = df.drop(columns=[col for col in df.columns if col not in drop_columns_players], axis=1)
df_players
# Out:
#           id                     name  rating position  height    foot  rare  \
# 0       1001             Gábor Király      69       GK     191   Right     0
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %% [markdown]
# #### Make the dataframe of df_players having data of the players of goal keeper.

# %%
# Displaying the number of players only having features of position "Goal Keeper" in the second dataset
df_players_matched = df_players[df_players['position'] == 'GK']
df_players_matched
# Out:
#           id                name  rating position  height    foot  rare  pace  \
# 0       1001        Gábor Király      69       GK     191   Right     0     0
# 20    100745          Paul Smith      64       GK     193   Right     1     0
# 29    100807   Stefanos Kotsolis      65       GK     190   Right     0     0
# 31    100899      Steve Phillips      61       GK     185   Right     1     0
# 39    101282         Oka Nikolov      70       GK     188   Right     0     0
# ...      ...                 ...     ...      ...     ...     ...   ...   ...
# 8799     806     Mathias Schober      69       GK     191    Left     0     0
# 8806    8247               Palop      77       GK     184   Right     0     0
# 8827    8910          Carlo Nash      63       GK     182   Right     1     0
# 8828     899          Frank Rost      74       GK     194   Right     1     0
# 8839    9751         Gábor Babos      71       GK     196   Right     1     0
#
# ...

# %% [markdown]
# #### Make the dataframe of df_players having data of the all the other players except the goal keeper.

# %%
# Displaying the number of players not having the features of position "Goal Keeper" in the second datset
df_players_unmatched = df_players[df_players['position'] != 'GK']
df_players_unmatched
# Out:
#           id                     name  rating position  height    foot  rare  \
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# 5     100329           Abdoulaye Faye      72        D     187   Right     1
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %% [markdown]
# **vii. Find shape of both the datasets**

# %%
# Displaying the shape of first dataset both having and not having the features position "Goal keeper".
print("The Shape of first dataset having players with position goal keeper : ", df_goalkeeper_matched.shape)
print("The Shape of first dataset having all the other players except with the position goal keeper : ", df_goalkeeper_unmatched.shape)
# Out:
# The Shape of first dataset having players with position goal keeper :  (930, 12)
# The Shape of first dataset having all the other players except with the position goal keeper :  (7917, 12)

# %%
# Displaying the shape of second dataset both having and not having the features position "Goal keeper".
print("The Shape of second dataset having players with position goal keeper : ", df_players_matched.shape)
print("The Shape of second dataset having all the other players except with the position goal keeper : ", df_players_unmatched.shape)
# Out:
# The Shape of second dataset having players with position goal keeper :  (930, 13)
# The Shape of second dataset having all the other players except with the position goal keeper :  (7917, 13)

# %% [markdown]
# **viii. Check head of both the splited dataframe**

# %%
# Showing the top first 5 rows of first dataset
df_goalkeeper.head()
# Out:
#        id                     name  rating position  height    foot  diving  \
# 0    1001             Gábor Király      69       GK     191   Right       0
# 1  100143             Frederik Boi      65        M     184   Right      61
# 2  100264          Tomasz Szewczuk      57        A     185   Right      65
# 3  100325   Steeve Joseph-Reinette      63        D     180    Left      68
# 4  100326             Kamel Chafni      72        M     181   Right      75
#
#    handling  kicking  reflexes  speed  positioning
# 0         0        0         0      0            0
# 1        65       61        61     65           61
# 2        54       65        65     54           65
# 3        38       68        68     38           68
# 4        64       75        75     64           75

# %%
# Showing the top first 5 rows of second dataset
df_players.head()
# Out:
#        id                     name  rating position  height    foot  rare  \
# 0    1001             Gábor Király      69       GK     191   Right     0
# 1  100143             Frederik Boi      65        M     184   Right     0
# 2  100264          Tomasz Szewczuk      57        A     185   Right     0
# 3  100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4  100326             Kamel Chafni      72        M     181   Right     0
#
#    pace  shooting  passing  dribbling  defending  heading
# 0     0         0        0          0          0        0
# 1    61        65       61         61         65       61
# 2    65        54       65         65         54       65
# 3    68        38       68         68         38       68
# 4    75        64       75         75         64       75

# %% [markdown]
# **ix. Show the summary stats of both the datasets**

# %%
# Showing the summary statistics of first dataset
df_goalkeeper_matched.describe()
# Out:
#                   id     rating      height  diving  handling  kicking  \
# count     930.000000  930.00000  930.000000   930.0     930.0    930.0
# mean   144009.048387   65.91828  188.233333     0.0       0.0      0.0
# std     58295.056991    7.67349    4.701690     0.0       0.0      0.0
# min         6.000000   40.00000  173.000000     0.0       0.0      0.0
# 25%    134631.750000   61.00000  185.000000     0.0       0.0      0.0
# 50%    163614.500000   66.00000  188.000000     0.0       0.0      0.0
# 75%    186381.750000   71.00000  191.000000     0.0       0.0      0.0
# max    205409.000000   89.00000  208.000000     0.0       0.0      0.0
#
#        reflexes  speed  positioning
# count     930.0  930.0        930.0
# mean        0.0    0.0          0.0
# std         0.0    0.0          0.0
# min         0.0    0.0          0.0
# 25%         0.0    0.0          0.0
# 50%         0.0    0.0          0.0
# 75%         0.0    0.0          0.0
# ...

# %%
# Showing the plot of first dataset
plt.subplots(figsize=(15,6))
sns.distplot(df_goalkeeper_matched['id'],kde=True);
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_6491/548848890.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_goalkeeper_matched['id'],kde=True);

# %%
# Showing the summary statistics of second dataset
df_goalkeeper_unmatched.describe()
# Out:
#                   id       rating       height       diving     handling  \
# count    7917.000000  7917.000000  7917.000000  7917.000000  7917.000000
# mean   153315.875205    66.769989   180.988885    67.934066    55.054440
# std     53963.758068     7.077355     6.200081    11.169316    13.136116
# min         2.000000    41.000000   158.000000    24.000000    12.000000
# 25%    141099.000000    62.000000   177.000000    62.000000    47.000000
# 50%    172252.000000    66.000000   181.000000    69.000000    57.000000
# 75%    189390.000000    72.000000   185.000000    75.000000    65.000000
# max    205583.000000    94.000000   203.000000    96.000000    90.000000
#
#            kicking     reflexes        speed  positioning
# count  7917.000000  7917.000000  7917.000000  7917.000000
# mean     67.934066    67.934066    55.054440    67.934066
# std      11.169316    11.169316    13.136116    11.169316
# min      24.000000    24.000000    12.000000    24.000000
# ...

# %%
# Showing the plot of Second dataset
plt.subplots(figsize=(15,6))
sns.distplot(df_goalkeeper_unmatched['id'],kde=True);
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_6491/543338073.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_goalkeeper_unmatched['id'],kde=True);

# %% [markdown]
# ### <font style='color:red'>Question:</font> What insights can be derived from the summary statistics of the goalkeeper dataset?

# %% [markdown]
# ###  <font style='color:green'>Answer:</font> The dataset for goalkeepers exhibits a left-skewed distribution, indicating that the majority of the data is concentrated on the right side. To mitigate this skewness, applying mathematical functions to the data can be beneficial. For instance, calculating the mean of the data is a method that can help reduce the left skewness.

# %% [markdown]
# ###  <font style='color:red'>Question:</font> What insights can be derived from the summary statistics of players other than goalkeepers?

# %% [markdown]
# ###  <font style='color:green'>Answer:</font> The distribution of the Other Players dataset exhibits left skewness, indicating that a significant concentration of data lies towards the right side. To mitigate this skewness, the application of mathematical functions is necessary. For instance, computing the mean of the data can be an effective method to alleviate the left skewness.

# %% [markdown]
# ### Task 5: Data Aggregation and Pivoting

# %% [markdown]
# **i. Display averages of each columns according the players' positions**

# %%
# Calulating the average/mean of each columns of dataset
players_averages = df.groupby("position").mean()
players_averages
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %% [markdown]
# **ii. Count number of players against each position and foot used by them.**
# *Hint: Use Groupby*

# %%
# Counting the total number of players against each position and foot of dataset
number_of_players = df.groupby(["position", "foot"]).size()
number_of_players
# Out:
# position  foot
# A          Left      368
#            Right    1714
# D          Left      915
#            Right    1879
# GK         Left       98
#            Right     832
# M          Left      704
#            Right    2337
# dtype: int64

# %% [markdown]
# **iii. Conduct a grouping operation based on player positions and preferred foot to calculate the mean, minimum, and maximum values of the 'rating' attribute. Store the resulting summary in a variable named 'a'** <br>
# *Hint: Aggregate(mean,min,max) on rating using .agg() method and nested dictionaries* <br>

# %%
# Counting total number os values according to the groups "position" and "foot" and finding their mean, min ana max of dataset.
a = df.groupby(['position', 'foot'])['rating'].agg(['mean', 'min', 'max'])
a
# Out:
#                       mean  min  max
# position foot
# A         Left   67.758152   51   94
#           Right  67.154026   41   92
# D         Left   65.931148   47   85
#           Right  66.121341   42   89
# GK        Left   68.102041   52   89
#           Right  65.661058   40   86
# M         Left   67.778409   43   90
#           Right  66.878905   41   92

# %% [markdown]
# **iv. Perform "PIVOTING" on the dataframe 'df'. The properties should be as following:**<br>
# *index = ' position'<br>
# columns = ' foot'<br>
# values=' rating'<br>
# aggfunc=['min','mean']*<br>

# %%
# Performing pivoting table "duplicate the temporary table" in order to analysis the dataset
pivoting = df.pivot_table(index='position', columns='foot', values='rating', aggfunc=['min','mean'])
pivoting
# Out:
#            min              mean
# foot      Left  Right       Left      Right
# position
# A           51     41  67.758152  67.154026
# D           47     42  65.931148  66.121341
# GK          52     40  68.102041  65.661058
# M           43     41  67.778409  66.878905

# %% [markdown]
# Data visualization is a powerful tool for conveying information, identifying patterns, and gaining insights from data. There are various types of data visualizations and techniques to effectively communicate information. Here are some common types of visualizations and techniques:
#
# ### Types of Data Visualizations:
#
# 1. **Bar Charts:**
#    - Represents categorical data with rectangular bars.
#    - Suitable for comparing values across different categories.
#
# 2. **Histograms:**
#    - Displays the distribution of a continuous variable by dividing it into bins.
#
# 3. **Line Charts:**
#    - Connects data points with straight lines.
#    - Useful for showing trends or changes over time.
#
# 4. **Scatter Plots:**
#    - Displays individual data points on a two-dimensional graph.
#    - Useful for visualizing relationships between two variables.
#
# 5. **Pie Charts:**
#    - Represents parts of a whole as slices of a circular pie.
#    - Suitable for showing the composition of a dataset.
#
# 6. **Heatmaps:**
#    - Displays data in a matrix format with colors representing values.
#    - Useful for visualizing relationships and patterns in large datasets.
#
# 7. **Area Charts:**
#    - Similar to line charts but with the area beneath the line filled in.
#    - Suitable for showing cumulative values over time.
#
# 8. **Box Plots (Box-and-Whisker Plots):**
#    - Displays the distribution of a dataset and highlights statistical measures.
#    - Shows median, quartiles, and potential outliers.
#
# 9. **Violin Plots:**
#    - Combines aspects of box plots and kernel density plots.
#    - Provides information about the distribution of the data.
#
# 10. **Treemaps:**
#     - Visualizes hierarchical data using nested rectangles.
#     - Each level of the hierarchy is represented by a different color or size.
#
# 11. **Radar Charts:**
#     - Displays multivariate data in the form of a two-dimensional chart with three or more quantitative variables.
#
# 12. **Word Clouds:**
#     - Represents words in a dataset, with the size of each word indicating its frequency.
#
# ### Techniques for Effective Data Visualization:
#
# 1. **Color Coding:**
#    - Use colors strategically to convey information, highlight patterns, or differentiate categories.
#
# 2. **Annotations:**
#    - Add labels, text, or arrows to provide context or highlight specific points in the visualization.
#
# 3. **Interactive Visualizations:**
#    - Create interactive elements to allow users to explore the data dynamically.
#
# 4. **3D Visualization:**
#    - Use three-dimensional representations when it enhances understanding, but avoid unnecessary complexity.
#
# 5. **Small Multiples:**
#    - Display multiple similar visualizations side by side to compare trends across different subsets of data.
#
# 6. **Animation:**
#    - Use animation to show changes over time or to emphasize specific aspects of the data.
#
# 7. **Consistent Axes and Scales:**
#    - Ensure that axes and scales are consistent to accurately compare values.
#
# 8. **Storytelling:**
#    - Arrange visualizations in a logical order to tell a story or convey a message effectively.
#
# 9. **Data-to-Ink Ratio:**
#    - Minimize non-data ink (gridlines, labels) to maximize the data-ink ratio and improve clarity.
#
# 10. **Use of Legends:**
#     - Clearly label colors, shapes, or other symbols to make visualizations more understandable.
#
# Choosing the right type of visualization and applying effective techniques depends on the nature of the data and the insights you want to convey. It's important to consider the audience and the purpose of the visualization to ensure its effectiveness.

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Task 6: Total Players Across Positions

# %%
# Plotting the total number of players in each position.
position = df.groupby('position')['name'].nunique()
position.plot(kind='bar')
plt.ylabel('Number of Players')
plt.xlabel('Position')
plt.title('Number of Players by Position')
plt.show()

# %% [markdown]
# ### <font style='color:red'>Question:</font> What information or observations can be derived from the plot above?

# %% [markdown]
# ### <font style='color:green'>Answer:</font> In the depicted plot, the count of players categorized as 'others' significantly outweighs the count of goalkeepers based on their respective positions.

# %% [markdown]
# ### Task 7:  Analysis of Foot Type Distribution

# %%
# # Plotting the total number of players in each foot type.
position = df.groupby(['position','foot'])['name'].nunique()
position.plot(kind='bar')
plt.ylabel('Number of Players')
plt.xlabel('Position')
plt.title('Number of Players by Position')
plt.show()

# %% [markdown]
# ### Task 8. Boxplot Analysis: Foot Distribution per Rating

# %%
# Plotting the foot distribution according to the per rating using boxplot 
sns.boxplot(x='rating', y='foot', data=df)
plt.title('foot distribution per rating')
plt.show()

# %% [markdown]
# ### Task 9. Exploration: Foot Type Distribution Across Positions  <br>
# *Hint: You can use subplots and you can have a separate dataframe for each position. Sample code for subplots is given below:*<br>
# *Sample Code
# <br>*
#
# <code>fig, ax=plt.subplots(2,2,sharey=True, figsize=(15,8))
# sns.countplot(x='rating', data=df_goalkeeper, ax=ax[0,0])
# ax[0,0].set_title('Goal keeper')</code>

# %%
# Displaying the total number of players for each foot type according to their positions
df['position'].unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %%
df_M=df[df['position']==' M']
df_A=df[df['position']==' A']
df_D=df[df['position']==' D']

# %%
# Plotting the total number of players for each foot type according to their positions
positions = df['position'].unique()
fig, ax=plt.subplots(2,2,sharey=True, figsize=(15,8))
ax = ax.ravel() # to flatten the array to 1d
for i, pos in enumerate(positions):
    df_pos = df[df['position'] == pos]
    sns.countplot(x='foot', data=df_pos, ax=ax[i])
    ax[i].set_title(pos)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 10: Correlation Analysis: Ratings vs. Defending Attributes<br>
# *Hint: reg plot*

# %%
# Plotting the Relationship/corelation of "Rating" and "defending" of second dataset "other players".
sns.regplot(x='rating', y='defending', data=df_players)
plt.title('Relationship between rating and defending of other players')
plt.xlabel('Rating')
plt.ylabel('Defending')
plt.show()

# %% [markdown]
# ### Task 11: Graphical Exploration: Rating vs. Goalkeeper Handling<br>
# *Hint: jointplot*

# %%
# Plotting the graph of relationship/correlation among rating and handling of 'Goal keeper'.
df_goalkeeper_jointplot = df[df['position'] == 'GK']
sns.jointplot(x='rating', y='handling', data=df_goalkeeper_jointplot, kind="reg", color="r")
plt.show()

# %% [markdown]
# ### Task 12.  Heatmap Visualization: Goalkeeper Attribute Correlation

# %%
sns.set_context('poster')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df_goalkeeper is your DataFrame

sns.set_context('poster')
plt.figure(figsize=(20, 5))

# Filter the DataFrame to include only 'GK' positions
df_goalkeeper_heatmap = df_goalkeeper[df_goalkeeper['position'] == 'GK']

# Convert non-numeric columns to numeric (replace with appropriate conversion method)
df_goalkeeper_heatmap_numeric = df_goalkeeper_heatmap.select_dtypes(exclude='object').apply(pd.to_numeric, errors='coerce')

# Calculate the correlation matrix
cor = df_goalkeeper_heatmap_numeric.corr()

# Plot the heatmap
sns.heatmap(cor, annot=True, fmt='.1g', cmap='coolwarm')

# Show the plot
plt.show()

# %% [markdown]
# ##### <font style='color:red'>Question:</font> Which columns, variables, or factors play a crucial role in determining the ratings of other players, and what is the significance of their impact?
# ##### <font style='color:Green'>Answer:</font> To identify the key columns or variables influencing the ratings of other players, analyze the correlation coefficients presented in the heatmap. A coefficient closer to 1 or -1 indicates a stronger correlation between the variables.

# %% [markdown]
# ### Task 13. Rating Distribution Analysis
# *Hint: Use dist plot*

# %%
# Plotting the graph of distribution of the "Rating".
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df['rating'])
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Rating')
plt.show()
# Out:
# /var/folders/1z/07sdy2sj0q743hyg26bv74k40000gn/T/ipykernel_48156/3922974167.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rating'])

# %% [markdown]
# ### Task 14: KDE Plot Analysis: Ratings Across Player Types

# %%
# Plotting the graph distribution of "Rating" of each player through KDE plot using distplot.
sns.set(rc={'figure.figsize':(11.7,8.27)})
g = sns.FacetGrid(df, col="position")
g.map(sns.distplot, "rating")
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Rating by Player Type')
plt.show()
# Out:
# /Users/vinayjogani/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/vinayjogani/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### Task 15: Count Analysis: Rare Players Across Positions

# %%
# Counting the number of rare players in each type of position.
rare_players = df[df['rating'] < 70]
rare_players_count = rare_players.groupby(['position', 'foot'])['name'].nunique().reset_index()
print(rare_players_count)
# Out:
#   position    foot  name
# 0        A    Left   225
# 1        A   Right  1075
# 2        D    Left   658
# 3        D   Right  1294
# 4       GK    Left    60
# 5       GK   Right   571
# 6        M    Left   428
# 7        M   Right  1509

# %% [markdown]
# References:
# 1. ChatGPT
# 2. Kaggle
# 3. Medium aticles
# 4. IBM: https://www.ibm.com/topics/exploratory-data-analysis
