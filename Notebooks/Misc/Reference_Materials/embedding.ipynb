# %%
pip install openai==0.28.0
# Out:
# Requirement already satisfied: openai==0.28.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (0.28.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests>=2.20 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from openai==0.28.0) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from openai==0.28.0) (4.67.1)
# Requirement already satisfied: aiohttp in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from openai==0.28.0) (3.11.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from requests>=2.20->openai==0.28.0) (2024.8.30)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from aiohttp->openai==0.28.0) (1.18.3)
# Requirement already satisfied: colorama in c:\users\chiranjit usa\onedrive - northeastern university\desktop\vector_database_project\venv\lib\site-packages (from tqdm->openai==0.28.0) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import openai

# Set your OpenAI API key
openai.api_key = "ENTER_YOUR_API_KEY"

# %%
import os

# %%
def fetch_json_directories(base_dir):
    """
    Recursively fetch directories containing .json files in the given directory.

    Args:
        base_dir (str): The base directory to search within.

    Returns:
        list: A list of unique directories containing .json files.
    """
    json_directories = set()  # Use a set to ensure uniqueness
    
    # Walk through all directories and subdirectories
    for root, _, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".json"):  # Check for .json extension
                json_directories.add(root)  # Add the directory to the set
                break  # No need to check other files in this directory
    
    return list(json_directories)

# %%
legal_case_paths = fetch_json_directories("C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/")

# %%
len(legal_case_paths)
# Out:
# 4

# %%
legal_case_paths
# Out:
# ['C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\1.zip_extracted\\metadata',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\1.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz-app\\1.zip_extracted\\json',
#  'C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/ariz\\1.zip_extracted\\metadata']

# %%
import faiss
import numpy as np
import openai
import json
import pickle
from pathlib import Path
from tqdm import tqdm
from sklearn.metrics.pairwise import cosine_similarity

openai.api_key = "ENTER_YOUR_API_KEY"

def split_into_chunks(text, chunk_size=1000, chunk_overlap=200):
    """
    Splits the text into chunks of specified size with overlap.

    Parameters:
    - text: The input text to be split.
    - chunk_size: The maximum size of each chunk (default: 1000).
    - chunk_overlap: The overlap size between consecutive chunks (default: 200).

    Returns:
    - List of text chunks.
    """
    chunks = []
    for i in range(0, len(text), chunk_size - chunk_overlap):
        chunks.append(text[i:i + chunk_size])
    return chunks

def load_json_files(directory):
    """
    Loads and extracts content from JSON files in the specified directory.

    Parameters:
    - directory: Path to the directory containing JSON files.

    Returns:
    - List of dictionaries with 'id' and 'content' for each JSON.
    """
    data = []
    directory = Path(directory)
    for file in tqdm(directory.rglob("*.json"), desc="Loading JSON files"):
        try:
            with open(file, "r", encoding="utf-8") as f:
                json_data = json.load(f)
                if isinstance(json_data, dict):
                    content = json.dumps(json_data)  # Convert dict to string
                elif isinstance(json_data, list):
                    content = "\n".join([json.dumps(item) for item in json_data])
                else:
                    content = str(json_data)
            data.append({
                "id": f"{os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(file))))}_{os.path.basename(os.path.dirname(os.path.dirname(file)))}_{os.path.basename(os.path.dirname(file))}_{file.name}",
                "content": content
            })
        except Exception as e:
            print(f"Error loading file {file.name}: {e}")
            continue
    return data

def process_json_files(json_files):
    """
    Processes JSON files to extract content and split it into chunks.

    Parameters:
    - json_files: List of dictionaries with 'id' and 'content' for each JSON.

    Returns:
    - List of dictionaries containing 'id' and 'text_chunk'.
    """
    all_chunks = []
    for json_file in tqdm(json_files, desc="Processing JSON files"):
        # Split JSON content into chunks
        text_chunks = split_into_chunks(json_file["content"])
        # Append text chunks with their corresponding IDs
        for i, chunk in enumerate(text_chunks):
            all_chunks.append({
                "id": f"{json_file['id']}_chunk_{i}",
                "text_chunk": chunk
            })
    return all_chunks

def generate_embeddings_from_chunks(chunks, batch_size=2):
    """
    Generates embeddings for the given text chunks using OpenAI's Embedding API.

    Parameters:
    - chunks: List of dictionaries with 'id' and 'text_chunk'.
    - batch_size: Number of chunks to process in a single API call (default: 2).

    Returns:
    - List of embeddings with their corresponding 'id'.
    """
    embeddings = []
    for i in tqdm(range(0, len(chunks), batch_size), desc="Generating embeddings"):
        batch = chunks[i:i + batch_size]
        try:
            # Extract text content for embedding generation
            batch_texts = [item["text_chunk"] for item in batch]
            response = openai.Embedding.create(
                model="text-embedding-ada-002",
                input=batch_texts
            )
            # Add embeddings with corresponding IDs
            for j, embedding in enumerate(response["data"]):
                embeddings.append({
                    "id": batch[j]["id"],
                    "embedding": embedding["embedding"]
                })
        except Exception as e:
            print(f"Error generating embedding for batch {i}: {e}")
            continue
    return embeddings

def save_embeddings(embeddings, file_name="embeddings.pkl"):
    """
    Saves embeddings to a pickle file.

    Parameters:
    - embeddings: List of embeddings to save.
    - file_name: Name of the file to save the embeddings (default: 'embeddings.pkl').
    """
    try:
        with open(file_name, "wb") as f:
            pickle.dump(embeddings, f)
        print(f"Embeddings saved to {file_name}")
    except Exception as e:
        print(f"Error saving embeddings: {e}")

def store_embeddings_in_faiss(embeddings, faiss_index_file="faiss_index.index", d=1536):
    """
    Stores embeddings in a FAISS vector database.

    Parameters:
    - embeddings: List of dictionaries containing 'id' and 'embedding'.
    - faiss_index_file: File name to save the FAISS index (default: 'faiss_index.index').
    - d: Dimension of the embeddings (default: 1536 for OpenAI embeddings).
    """
    # Initialize a FAISS index (L2 distance for default)
    index = faiss.IndexFlatL2(d)

    # Metadata mapping for IDs
    id_mapping = []

    # Convert embeddings into a NumPy array
    vectors = []
    for item in embeddings:
        id_mapping.append(item["id"])
        vectors.append(np.array(item["embedding"], dtype=np.float32))

    vectors = np.vstack(vectors)  # Stack vectors into a single NumPy array

    # Add vectors to the FAISS index
    index.add(vectors)

    # Save the FAISS index
    faiss.write_index(index, faiss_index_file)

    # Save the ID mapping
    with open("id_mapping.pkl", "wb") as f:
        pickle.dump(id_mapping, f)

    print(f"Stored {len(embeddings)} embeddings into the FAISS index.")

if __name__ == "__main__":
    # Directory containing JSON files
    json_dir = "C:/Users/chiranjit usa/OneDrive - Northeastern University/Desktop/vector_database_project/static.case.law/"  # Replace with your directory path

    # Load JSON files
    json_files=[]
    for folder in legal_case_paths:
        folder_files = load_json_files(folder)
        json_files.extend(folder_files)
    print(len(json_files))
    # Process JSON files to generate text chunks (content_dict)
    try:
        content_dict = process_json_files(json_files)
        print(f"Processed {len(content_dict)} text chunks.")
    except Exception as e:
        print(f"Error during processing: {e}")

    # Save content_dict to a file for later use
    try:
        with open("content_dict.pkl", "wb") as f:
            pickle.dump(content_dict, f)
        print("Saved content_dict with text chunks.")
    except Exception as e:
        print(f"Error saving content_dict: {e}")

    # Generate embeddings from text chunks
    try:
        embeddings = generate_embeddings_from_chunks(content_dict, batch_size=2)
        print(f"Generated embeddings for {len(embeddings)} chunks.")
    except Exception as e:
        print(f"Error generating embeddings: {e}")

    # Save embeddings to a file
    save_embeddings(embeddings, file_name="output_embeddings.pkl")

    # Store embeddings in FAISS
    try:
        store_embeddings_in_faiss(embeddings, faiss_index_file="faiss_index.index", d=1536)
        print("Embeddings successfully stored in FAISS.")
    except Exception as e:
        print(f"Error storing embeddings in FAISS: {e}")
# Out:
# Loading JSON files: 2it [00:00, 77.72it/s]
# Loading JSON files: 40it [00:00, 607.55it/s]
# Loading JSON files: 50it [00:00, 1839.16it/s]
# Loading JSON files: 2it [00:00, 305.91it/s]
# 94
# Processing JSON files: 100%|██████████| 94/94 [00:00<00:00, 19487.18it/s]
# Processed 2875 text chunks.
# Saved content_dict with text chunks.
# Generating embeddings: 100%|██████████| 1438/1438 [07:01<00:00,  3.41it/s]
# Generated embeddings for 2875 chunks.
# Embeddings saved to output_embeddings.pkl
# Stored 2875 embeddings into the FAISS index.
# Embeddings successfully stored in FAISS.

# %%
content_dict
# Out:
# [{'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_0',
#   'text_chunk': '{"id": 1234473, "name": "Iva L. ROREBECK, Sebe L. Broyles and Clarice L. Broyles, his wife, Appellants, v. Helen CRISTE, the wife of John Criste, Appellee", "name_abbreviation": "Rorebeck v. Criste", "decision_date": "1965-02-02", "docket_number": "No. 1 CA-CIV 3", "first_page": "1", "last_page": "6", "citations": [{"type": "official", "cite": "1 Ariz. App. 1"}, {"type": "parallel", "cite": "398 P.2d 678"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "80 A.L.R.2d 1161", "category": "reporters:specialty", "reporter": "A.L.R. 2d", "year": 1960, "opinion_index": 0}, {"cite": "220 Or. 297", "category": "reporters:state", "reporter": "Or.", "case_ids": [5778884], "weight": 2, "year": 1960, "opinion_index": 0, "case_paths": ["/or/220/0297-01"]}, {"cite": "9 P.2d 402", "category": "reporters:state_regional", "reporter": "P.2d", "case_ids": [5034679]'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_1',
#   'text_chunk': ': [5778884], "weight": 2, "year": 1960, "opinion_index": 0, "case_paths": ["/or/220/0297-01"]}, {"cite": "9 P.2d 402", "category": "reporters:state_regional", "reporter": "P.2d", "case_ids": [5034679], "year": 1932, "pin_cites": [{"page": "403"}], "opinion_index": 0, "case_paths": ["/ariz/40/0042-02"]}, {"cite": "40 Ariz. 42", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5034560, 5034679], "year": 1932, "pin_cites": [{"page": "45"}], "opinion_index": 0, "case_paths": ["/ariz/40/0042-01", "/ariz/40/0042-02"]}, {"cite": "80 A.L.R. 155", "category": "reporters:specialty", "reporter": "A.L.R.", "opinion_index": 0}, {"cite": "43 S.W.2d 380", "category": "reporters:state_regional", "reporter": "S.W.2d", "year": 1931, "opinion_index": 0}, {"cite": "163 Tenn. 364", "category": "reporters:state", "reporter": "Tenn.", "case_ids": [8532366], "year": 1931, "opinion_index": 0, "case_paths": ["/tenn/163/0364-01"]}, {"cite": "35 P.2d 93", "category": "reporters:state_regional", "r'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_2',
#   'text_chunk': '"reporters:state", "reporter": "Tenn.", "case_ids": [8532366], "year": 1931, "opinion_index": 0, "case_paths": ["/tenn/163/0364-01"]}, {"cite": "35 P.2d 93", "category": "reporters:state_regional", "reporter": "P.2d", "year": 1934, "opinion_index": 0}, {"cite": "178 Wash. 541", "category": "reporters:state", "reporter": "Wash.", "case_ids": [869862], "year": 1934, "opinion_index": 0, "case_paths": ["/wash/178/0541-01"]}, {"cite": "64 Ariz. 192", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [8503787], "weight": 2, "year": 1946, "opinion_index": 0, "case_paths": ["/ariz/64/0192-01"]}, {"cite": "85 Ariz. 56", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [646658], "weight": 2, "year": 1958, "opinion_index": 0, "case_paths": ["/ariz/85/0056-01"]}, {"cite": "66 Ariz. 139", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [2441607], "weight": 2, "year": 1947, "opinion_index": 0, "case_paths": ["/ariz/66/0139-01"]}], "analysis": {"cardinalit'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_3',
#   'text_chunk': '"66 Ariz. 139", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [2441607], "weight": 2, "year": 1947, "opinion_index": 0, "case_paths": ["/ariz/66/0139-01"]}], "analysis": {"cardinality": 637, "char_count": 12942, "ocr_confidence": 0.704, "pagerank": {"raw": 3.3462384788630615e-07, "percentile": 0.8744637235607172}, "sha256": "cbf86367d6a9e25bd70a9d4e93deed6e4fa5c3d14e19b8d7a424a75fd55bc309", "simhash": "1:fee5bd9e42e7e30b", "word_count": 2261}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0001-01", "first_page_order": 27, "last_page_order": 32}\n{"id": 1234419, "name": "Farrell HOOSAVA, Petitioner, v. The INDUSTRIAL COMMISSION of Arizona and Kaibab Manufacturing Co., Respondents", "name_abbreviation": "Hoosava v. Industrial Commission", "decision_date": "1965-02-03", "docket_number": "No. 1 CA-IC 7", "first_page": "6", "last_page": "7", "citations": [{"type": "official'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_4',
#   'text_chunk': 'ndents", "name_abbreviation": "Hoosava v. Industrial Commission", "decision_date": "1965-02-03", "docket_number": "No. 1 CA-IC 7", "first_page": "6", "last_page": "7", "citations": [{"type": "official", "cite": "1 Ariz. App. 6"}, {"type": "parallel", "cite": "398 P.2d 683"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [], "analysis": {"cardinality": 218, "char_count": 2801, "ocr_confidence": 0.678, "pagerank": {"raw": 6.848989183728895e-08, "percentile": 0.41742993510432463}, "sha256": "a00a350b9fe65ec31d7509dbdc405c6c62dc2b0c308e6625a942e148919f43cb", "simhash": "1:4cc6ed1f809cedb5", "word_count": 469}, "last_updated": "2023-07-14T15:14:03.502380+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0006-01", "first_page_order": 32, "last_page_order": 33}\n{"id": 1234429, "name": "Ernest W. SPARKS and R'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_5',
#   'text_chunk': '"provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0006-01", "first_page_order": 32, "last_page_order": 33}\n{"id": 1234429, "name": "Ernest W. SPARKS and Ruth G. Sparks, his wife, Appellants, v. SCOTTSDALE MORTGAGE CORPORATION, an Arizona Corporation, Appellee", "name_abbreviation": "Sparks v. Scottsdale Mortgage Corp.", "decision_date": "1965-02-09", "docket_number": "No. 1 CA-CIV 15", "first_page": "8", "last_page": "11", "citations": [{"type": "official", "cite": "1 Ariz. App. 8"}, {"type": "parallel", "cite": "398 P.2d 916"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "28 Ariz. 263", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [4974109], "weight": 2, "year": 1925, "opinion_index": 0, "case_paths": ["/ariz/28/0263-01"]}, {"cite": "1 Ariz.App. 1", "category": "reporters:state'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_6',
#   'text_chunk': 'reporters:state", "reporter": "Ariz.", "case_ids": [4974109], "weight": 2, "year": 1925, "opinion_index": 0, "case_paths": ["/ariz/28/0263-01"]}, {"cite": "1 Ariz.App. 1", "category": "reporters:state", "reporter": "Ariz. App.", "case_ids": [1234473], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz-app/1/0001-01"]}, {"cite": "66 Ariz. 299", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [2441085], "weight": 2, "year": 1947, "opinion_index": 0, "case_paths": ["/ariz/66/0299-01"]}, {"cite": "64 Ariz. 192", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [8503787], "weight": 2, "year": 1946, "opinion_index": 0, "case_paths": ["/ariz/64/0192-01"]}], "analysis": {"cardinality": 445, "char_count": 8453, "ocr_confidence": 0.699, "pagerank": {"raw": 1.27879270835649e-07, "percentile": 0.616621277920064}, "sha256": "977decb14d65de40a917e6ef61bfc98412092911ac7c710e2a9c26f9855a8229", "simhash": "1:f8bfb1fe4ee83d54", "word_count": 1426}, "last_updated": "202'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_7',
#   'text_chunk': '70835649e-07, "percentile": 0.616621277920064}, "sha256": "977decb14d65de40a917e6ef61bfc98412092911ac7c710e2a9c26f9855a8229", "simhash": "1:f8bfb1fe4ee83d54", "word_count": 1426}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0008-01", "first_page_order": 34, "last_page_order": 37}\n{"id": 1234492, "name": "Sol BLACKMAN and Carol E. Blackman, husband and wife, Appellants, v. ASSOCIATES LOAN COMPANY, an Indiana corporation, Appellee", "name_abbreviation": "Blackman v. Associates Loan Co.", "decision_date": "1965-02-09", "docket_number": "No. 2 CA-CIV 52", "first_page": "11", "last_page": "12", "citations": [{"type": "official", "cite": "1 Ariz. App. 11"}, {"type": "parallel", "cite": "398 P.2d 919"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": '},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_8',
#   'text_chunk': '2d 919"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "96 Ariz. 109", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [637205], "weight": 2, "pin_cites": [{"page": "777"}], "opinion_index": 0, "case_paths": ["/ariz/96/0109-01"]}], "analysis": {"cardinality": 299, "char_count": 4265, "ocr_confidence": 0.719, "pagerank": {"raw": 1.0547801384503952e-07, "percentile": 0.5550578431406619}, "sha256": "4e969a4006f10ce44269f716a0139d191d83e24df92d5adbff54b168f93fd6a4", "simhash": "1:2b52be8bb0401c0c", "word_count": 733}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0011-01", "first_page_order": 37, "last_page_order": 38}\n{"id": 1234435, "name": "Frances Evelyn REILLY, Petitioner, v. The INDUSTRIAL COMMISSION of Arizona and E. L. Grub'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_9',
#   'text_chunk': 'tch": "2018"}, "file_name": "0011-01", "first_page_order": 37, "last_page_order": 38}\n{"id": 1234435, "name": "Frances Evelyn REILLY, Petitioner, v. The INDUSTRIAL COMMISSION of Arizona and E. L. Gruber Underwear Company, Respondents", "name_abbreviation": "Reilly v. Industrial Commission", "decision_date": "1965-02-11", "docket_number": "No. 1 CA-IC 5", "first_page": "12", "last_page": "15", "citations": [{"type": "official", "cite": "1 Ariz. App. 12"}, {"type": "parallel", "cite": "398 P.2d 920"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "377 S.W.2d 947", "category": "reporters:state_regional", "reporter": "S.W.2d", "case_ids": [8528173], "year": 1964, "pin_cites": [{"page": "950"}], "opinion_index": 0, "case_paths": ["/tenn/214/0118-01"]}, {"cite": "209 Tenn. 106", "category": "reporters:state", "reporter": "Tenn.", "case_ids": [8528392'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_10',
#   'text_chunk': 'ear": 1964, "pin_cites": [{"page": "950"}], "opinion_index": 0, "case_paths": ["/tenn/214/0118-01"]}, {"cite": "209 Tenn. 106", "category": "reporters:state", "reporter": "Tenn.", "case_ids": [8528392], "weight": 2, "year": 1964, "pin_cites": [{"page": "115"}], "opinion_index": 0, "case_paths": ["/tenn/209/0106-01"]}, {"cite": "73 Ariz. 86", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5190552], "weight": 2, "year": 1951, "opinion_index": 0, "case_paths": ["/ariz/73/0086-01"]}, {"cite": "61 Ariz. 436", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5183513], "weight": 2, "year": 1944, "pin_cites": [{"page": "437"}], "opinion_index": 0, "case_paths": ["/ariz/61/0436-01"]}, {"cite": "91 Ariz. 266", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [616463], "weight": 2, "year": 1962, "opinion_index": 0, "case_paths": ["/ariz/91/0266-01"]}, {"cite": "69 Ariz. 301", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5160122]'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_11',
#   'text_chunk': 'e_ids": [616463], "weight": 2, "year": 1962, "opinion_index": 0, "case_paths": ["/ariz/91/0266-01"]}, {"cite": "69 Ariz. 301", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5160122], "weight": 2, "year": 1950, "opinion_index": 0, "case_paths": ["/ariz/69/0301-01"]}, {"cite": "42 Ariz. 436", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5055166], "weight": 2, "year": 1933, "opinion_index": 0, "case_paths": ["/ariz/42/0436-01"]}, {"cite": "368 S.W.2d 955", "category": "reporters:state_regional", "reporter": "S.W.2d", "case_ids": [10178823], "year": 1963, "opinion_index": 0, "case_paths": ["/sw2d/368/0955-01"]}, {"cite": "82 Ariz. 129", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [651678], "weight": 2, "year": 1957, "opinion_index": 0, "case_paths": ["/ariz/82/0129-01"]}, {"cite": "76 Ariz. 105", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [653288], "weight": 2, "year": 1953, "opinion_index": 0, "case_paths": ["'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_12',
#   'text_chunk': ' "case_paths": ["/ariz/82/0129-01"]}, {"cite": "76 Ariz. 105", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [653288], "weight": 2, "year": 1953, "opinion_index": 0, "case_paths": ["/ariz/76/0105-01"]}, {"cite": "90 Ariz. 3", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639060], "weight": 4, "year": 1961, "opinion_index": 0, "case_paths": ["/ariz/90/0003-01"]}], "analysis": {"cardinality": 546, "char_count": 8846, "ocr_confidence": 0.703, "pagerank": {"raw": 5.100823421482013e-07, "percentile": 0.9382936997485182}, "sha256": "6c9ef090efe7760ec65e7f4d212b05f84887cba0132dc47b080b251a4575321c", "simhash": "1:405f46cff2d8ba5c", "word_count": 1456}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0012-01", "first_page_order": 38, "last_page_order": 41}\n{"id": 1234402, "name": "The STATE of Arizona, Appellee, v. Rupert BACA, Appellant", "name_abbreviation"'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_13',
#   'text_chunk': 'vard", "batch": "2018"}, "file_name": "0012-01", "first_page_order": 38, "last_page_order": 41}\n{"id": 1234402, "name": "The STATE of Arizona, Appellee, v. Rupert BACA, Appellant", "name_abbreviation": "State v. Baca", "decision_date": "1965-02-09", "docket_number": "No. 1 CA-CR 1", "first_page": "16", "last_page": "18", "citations": [{"type": "official", "cite": "1 Ariz. App. 16"}, {"type": "parallel", "cite": "398 P.2d 924"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "296 F.2d 328", "category": "reporters:federal", "reporter": "F.2d", "case_ids": [218684], "year": 1961, "opinion_index": 0, "case_paths": ["/f2d/296/0328-01"]}, {"cite": "93 L.Ed. 153", "category": "reporters:federal", "reporter": "L. Ed.", "year": 1948, "opinion_index": 0}, {"cite": "335 U.S. 451", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [6159793], '},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk
"category": "reporters:federal", "reporter": "U.S.", "case_ids": [6157337], "weight": 3, "year": 1946, "opinion_index": 0, "case_paths": ["/us/331/0145-01"]}, {"cite": "94 L.Ed. 653", "category": "reporters:federal", "reporter": "L. Ed.", "year": 1950, "opinion_index": 0}, {"cite": "339 U.S. 56", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [362582], "weight": 2, "year": 1950, "opinion_index": 0, "case_paths": ["/us/339/0056-01"]}, {"cite": "367 U.S. 643", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [1785580], "weight": 3, "year": 1961, "opinion_index": 0, "case_paths": ["/us/367/0643-01"]}, {"cite": "94 Ariz. 243", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [612681], "weight": 2, "year": 1963, "opinion_index": 0, "case_paths": ["/ariz'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_18',
#   'text_chunk': 'se_paths": ["/us/367/0643-01"]}, {"cite": "94 Ariz. 243", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [612681], "weight": 2, "year": 1963, "opinion_index": 0, "case_paths": ["/ariz/94/0243-01"]}], "analysis": {"cardinality": 538, "char_count": 8942, "ocr_confidence": 0.713, "pagerank": {"raw": 2.5228971904779376e-07, "percentile": 0.8116770514419953}, "sha256": "8cf2b3e5e107aa407e4fbe714565ec734b6c16c9bcd44a2b681c842b3f59ded4", "simhash": "1:0fa8b1ce1b36d481", "word_count": 1552}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0016-01", "first_page_order": 42, "last_page_order": 44}\n{"id": 1234423, "name": "In the Matter of the ESTATE of George S. THOMPSON, Deceased. Warren BASS, Appellant, v. Robert H. RENAUD, Appellee", "name_abbreviation": "Bass v. Renaud", "decision_date": "1965-02-11", "docket_number": "No. 2 CA-CIV 24", "first_page": "18", "last_page": "24", "c'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_19',
#   'text_chunk': 'ren BASS, Appellant, v. Robert H. RENAUD, Appellee", "name_abbreviation": "Bass v. Renaud", "decision_date": "1965-02-11", "docket_number": "No. 2 CA-CIV 24", "first_page": "18", "last_page": "24", "citations": [{"type": "official", "cite": "1 Ariz. App. 18"}, {"type": "parallel", "cite": "398 P.2d 926"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "88 Ariz. 312", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [643192], "weight": 2, "year": 1960, "opinion_index": 0, "case_paths": ["/ariz/88/0312-01"]}, {"cite": "84 Ariz. 169", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [647971], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/84/0169-01"]}, {"cite": "230 P.2d 512", "category": "reporters:state_regional", "reporter": "P.2d", "case_ids": [5188796, 5187927], "opinion_index": 0, "case_paths": ["/ariz/7'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_20',
#   'text_chunk': '0, "case_paths": ["/ariz/84/0169-01"]}, {"cite": "230 P.2d 512", "category": "reporters:state_regional", "reporter": "P.2d", "case_ids": [5188796, 5187927], "opinion_index": 0, "case_paths": ["/ariz/72/0037-01", "/ariz/72/0038-01"]}, {"cite": "72 Ariz. 38", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5187927], "opinion_index": 0, "case_paths": ["/ariz/72/0038-01"]}, {"cite": "36 Ariz. 106", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5013857], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/36/0106-01"]}, {"cite": "94 Ariz. 230", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [612686], "weight": 2, "year": 1963, "opinion_index": 0, "case_paths": ["/ariz/94/0230-01"]}, {"cite": "63 Ariz. 544", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [2442895], "weight": 2, "year": 1945, "pin_cites": [{"page": "555"}], "opinion_index": 0, "case_paths": ["/ariz/63/0544-01"]}, {"cite": "119 P.2d 788", "category": "rep'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_21',
#   'text_chunk': 'reporter": "Ariz.", "case_ids": [2442895], "weight": 2, "year": 1945, "pin_cites": [{"page": "555"}], "opinion_index": 0, "case_paths": ["/ariz/63/0544-01"]}, {"cite": "119 P.2d 788", "category": "reporters:state_regional", "reporter": "P.2d", "opinion_index": 0}, {"cite": "48 Cal. App.2d 263", "category": "reporters:state", "reporter": "Cal. App. 2d", "case_ids": [4632083], "opinion_index": 0, "case_paths": ["/cal-app-2d/48/0263-01"]}, {"cite": "77 Ariz. 235", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639497], "weight": 2, "pin_cites": [{"page": "244"}], "opinion_index": 0, "case_paths": ["/ariz/77/0235-01"]}, {"cite": "24 Cal.Rptr. 263", "category": "reporters:state", "reporter": "Cal. Rptr.", "opinion_index": 0}, {"cite": "207 Cal.App.2d 133", "category": "reporters:state", "reporter": "Cal. App. 2d", "case_ids": [2127092], "opinion_index": 0, "case_paths": ["/cal-app-2d/207/0133-01"]}, {"cite": "93 Ariz. 152", "category": "reporters:state", "reporter": "Ariz.'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_22',
#   'text_chunk': 'rs:state", "reporter": "Cal. App. 2d", "case_ids": [2127092], "opinion_index": 0, "case_paths": ["/cal-app-2d/207/0133-01"]}, {"cite": "93 Ariz. 152", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614069], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/93/0152-01"]}], "analysis": {"cardinality": 742, "char_count": 16560, "ocr_confidence": 0.698, "pagerank": {"raw": 2.3234770416907907e-07, "percentile": 0.7902734869870792}, "sha256": "6706553e16d0c2f0bc23620ae143bb2a4db745cdb857a462e29ad1f522ea894f", "simhash": "1:8e5bc6887a489d3c", "word_count": 2819}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0018-01", "first_page_order": 44, "last_page_order": 50}\n{"id": 1234495, "name": "James AVENENTE, dba Oak Tavern, Petitioner, v. Addie Pat SMOUSE and the Industrial Commission of Arizona, Respondents", "name_abbreviation": "Avenente v. Smouse", "decision_date": "196'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_23',
#   'text_chunk': '34495, "name": "James AVENENTE, dba Oak Tavern, Petitioner, v. Addie Pat SMOUSE and the Industrial Commission of Arizona, Respondents", "name_abbreviation": "Avenente v. Smouse", "decision_date": "1965-02-11", "docket_number": "No. 1 CA-IC 6", "first_page": "24", "last_page": "27", "citations": [{"type": "official", "cite": "1 Ariz. App. 24"}, {"type": "parallel", "cite": "398 P.2d 932"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "226 U.S. 14", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [8285152], "weight": 3, "opinion_index": 0, "case_paths": ["/us/226/0014-01"]}, {"cite": "194 U.S. 25", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [3631214], "weight": 3, "opinion_index": 0, "case_paths": ["/us/194/0025-01"]}, {"cite": "87 Ariz. 329", "category": "reporters:state", "reporter": "Ariz.", "case_ids": '},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_24',
#   'text_chunk': 'reporter": "U.S.", "case_ids": [3631214], "weight": 3, "opinion_index": 0, "case_paths": ["/us/194/0025-01"]}, {"cite": "87 Ariz. 329", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [645846], "weight": 2, "year": 1960, "opinion_index": 0, "case_paths": ["/ariz/87/0329-01"]}, {"cite": "72 Ariz. 265", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5187276], "weight": 2, "year": 1951, "pin_cites": [{"page": "267"}, {"page": "828"}], "opinion_index": 0, "case_paths": ["/ariz/72/0265-01"]}, {"cite": "79 Ariz. 191", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [648623], "year": 1955, "opinion_index": 0, "case_paths": ["/ariz/79/0191-01"]}, {"cite": "45 Ariz. 186", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5077211], "weight": 2, "year": 1935, "opinion_index": 0, "case_paths": ["/ariz/45/0186-01"]}, {"cite": "78 Ariz. 112", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [626700], "weight": 2, "year":'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_25',
#   'text_chunk': 'ight": 2, "year": 1935, "opinion_index": 0, "case_paths": ["/ariz/45/0186-01"]}, {"cite": "78 Ariz. 112", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [626700], "weight": 2, "year": 1945, "opinion_index": 0, "case_paths": ["/ariz/78/0112-01"]}, {"cite": "47 Ariz. 294", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [2429720], "weight": 2, "year": 1936, "opinion_index": 0, "case_paths": ["/ariz/47/0294-01"]}, {"cite": "51 Ariz. 291", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5105860], "weight": 2, "year": 1938, "opinion_index": 0, "case_paths": ["/ariz/51/0291-01"]}], "analysis": {"cardinality": 541, "char_count": 8953, "ocr_confidence": 0.693, "pagerank": {"raw": 4.6625958716062554e-07, "percentile": 0.9276546624919059}, "sha256": "675e1e93c8aeddbc54414b342e9c16f80d9ea89358a9e0bde3d249e878f21fb6", "simhash": "1:a63a5e8fb15adc89", "word_count": 1476}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_26',
#   'text_chunk': '"675e1e93c8aeddbc54414b342e9c16f80d9ea89358a9e0bde3d249e878f21fb6", "simhash": "1:a63a5e8fb15adc89", "word_count": 1476}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0024-01", "first_page_order": 50, "last_page_order": 53}\n{"id": 1234475, "name": "Robert W. FINN, Special Administrator of the Estates of Francis M. Williams and Sally Williams, husband and wife, decedents, Appellant, v. J. H. ROSE TRUCK LINES, a Texas corporation, Appellee", "name_abbreviation": "Finn v. J. H. Rose Truck Lines", "decision_date": "1965-02-09", "docket_number": "No. 2 CA-CIV 8", "first_page": "27", "last_page": "33", "citations": [{"type": "official", "cite": "1 Ariz. App. 27"}, {"type": "parallel", "cite": "398 P.2d 935"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"c'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_27',
#   'text_chunk': '398 P.2d 935"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "93 Ariz. 97", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614123], "weight": 2, "pin_cites": [{"page": "108"}], "opinion_index": 0, "case_paths": ["/ariz/93/0097-01"]}, {"cite": "90 Ariz. 55", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639054], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/90/0055-01"]}, {"cite": "79 Ariz. 199", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [648632], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/79/0199-01"]}, {"cite": "85 Ariz. 345", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [646680], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/85/0345-01"]}, {"cite": "187 Or. 191", "category": "reporters:state", "reporter": "Or.", "case_ids": [2068773], '},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_28',
#   'text_chunk': ': "Ariz.", "case_ids": [646680], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/85/0345-01"]}, {"cite": "187 Or. 191", "category": "reporters:state", "reporter": "Or.", "case_ids": [2068773], "weight": 2, "year": 1949, "opinion_index": 0, "case_paths": ["/or/187/0191-01"]}, {"cite": "172 P.2d 78", "category": "reporters:state_regional", "reporter": "P.2d", "year": 1946, "opinion_index": 0}, {"cite": "75 Cal. App.2d 909", "category": "reporters:state", "reporter": "Cal. App. 2d", "case_ids": [4471649], "year": 1946, "opinion_index": 0, "case_paths": ["/cal-app-2d/75/0909-01"]}, {"cite": "87 Ariz. 206", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [645857], "weight": 2, "pin_cites": [{"page": "209"}], "opinion_index": 0, "case_paths": ["/ariz/87/0206-01"]}, {"cite": "93 Ariz. 368", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614101], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/93/0368-01"]}], "analysis": {"cardinality": 830, "cha'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_29',
#   'text_chunk': ': "93 Ariz. 368", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614101], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/93/0368-01"]}], "analysis": {"cardinality": 830, "char_count": 18443, "ocr_confidence": 0.704, "pagerank": {"raw": 2.264488466786788e-07, "percentile": 0.7830315589827824}, "sha256": "caa295a7226f0637c925ad9f65b828bea9377aaa3b665593f8ea5a2beef79ab6", "simhash": "1:9cc2e246449c80e7", "word_count": 3206}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0027-01", "first_page_order": 53, "last_page_order": 59}\n{"id": 1234450, "name": "PACIFIC GUANO COMPANY, a corporation, Appellant, v. PINAL COUNTY LAND COMPANY, a corporation, Appellee", "name_abbreviation": "Pacific Guano Co. v. Pinal County Land Co.", "decision_date": "1965-02-16", "docket_number": "No. 2 CA-CIV 14", "first_page": "34", "last_page": "36", "citations": [{"type": "official", "cite'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_30',
#   'text_chunk': 'ation": "Pacific Guano Co. v. Pinal County Land Co.", "decision_date": "1965-02-16", "docket_number": "No. 2 CA-CIV 14", "first_page": "34", "last_page": "36", "citations": [{"type": "official", "cite": "1 Ariz. App. 34"}, {"type": "parallel", "cite": "399 P.2d 122"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "95 Ariz. 392", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [570048], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/95/0392-01"]}, {"cite": "73 Ariz. 281", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5190257], "weight": 2, "year": 1964, "opinion_index": 0, "case_paths": ["/ariz/73/0281-01"]}, {"cite": "90 Ariz. 241", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639089], "weight": 2, "year": 1952, "opinion_index": 0, "case_paths": ["/ariz/90/0241-01"]}, {"cite": "58 A'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_31',
#   'text_chunk': '}, {"cite": "90 Ariz. 241", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639089], "weight": 2, "year": 1952, "opinion_index": 0, "case_paths": ["/ariz/90/0241-01"]}, {"cite": "58 Ariz. 486", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5139448], "weight": 2, "year": 1961, "opinion_index": 0, "case_paths": ["/ariz/58/0486-01"]}, {"cite": "39 Ariz. 385", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5025708], "weight": 2, "year": 1942, "opinion_index": 0, "case_paths": ["/ariz/39/0385-01"]}, {"cite": "37 Ariz. 521", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [2423754], "weight": 2, "year": 1932, "opinion_index": 0, "case_paths": ["/ariz/37/0521-01"]}, {"cite": "29 Ariz. 574", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [571032], "weight": 2, "year": 1931, "opinion_index": 0, "case_paths": ["/ariz/29/0574-01"]}], "analysis": {"cardinality": 454, "char_count": 6605, "ocr_confidence": 0.712, '},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_32',
#   'text_chunk': 'ter": "Ariz.", "case_ids": [571032], "weight": 2, "year": 1931, "opinion_index": 0, "case_paths": ["/ariz/29/0574-01"]}], "analysis": {"cardinality": 454, "char_count": 6605, "ocr_confidence": 0.712, "pagerank": {"raw": 1.2168013377875825e-07, "percentile": 0.5972740109558511}, "sha256": "bde68f18840d5acfc44b9788cb1bc732e5304f793c9b3d3e3bfb8cb4b08e05a2", "simhash": "1:b691c0275f520d70", "word_count": 1097}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0034-01", "first_page_order": 60, "last_page_order": 62}\n{"id": 1234367, "name": "Alexander B. AGUILAR and Dolores Aguilar, husband and wife, Appellants, v. D. C. CARPENTER and Josephine Carpenter, husband and wife, Appellees", "name_abbreviation": "Aguilar v. Carpenter", "decision_date": "1965-02-16", "docket_number": "No. 2 CA-CIV 30", "first_page": "36", "last_page": "40", "citations": [{"type": "official", "cite": "1 Ariz. App. 36"},'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_33',
#   'text_chunk': 'ation": "Aguilar v. Carpenter", "decision_date": "1965-02-16", "docket_number": "No. 2 CA-CIV 30", "first_page": "36", "last_page": "40", "citations": [{"type": "official", "cite": "1 Ariz. App. 36"}, {"type": "parallel", "cite": "399 P.2d 124"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "90 Ariz. 241", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639089], "weight": 2, "pin_cites": [{"page": "245"}], "opinion_index": 0, "case_paths": ["/ariz/90/0241-01"]}, {"cite": "93 Ariz. 152", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614069], "weight": 2, "pin_cites": [{"page": "160"}], "opinion_index": 0, "case_paths": ["/ariz/93/0152-01"]}, {"cite": "94 Ariz. 21", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [612660], "weight": 2, "pin_cites": [{"page": "24"}], "opinion_index": 0, "case_pa'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_34',
#   'text_chunk': 'aths": ["/ariz/93/0152-01"]}, {"cite": "94 Ariz. 21", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [612660], "weight": 2, "pin_cites": [{"page": "24"}], "opinion_index": 0, "case_paths": ["/ariz/94/0021-01"]}, {"cite": "95 Ariz. 392", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [570048], "weight": 3, "pin_cites": [{"page": "394"}], "opinion_index": 0, "case_paths": ["/ariz/95/0392-01"]}, {"cite": "93 Ariz. 266", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614090], "weight": 2, "pin_cites": [{"page": "978"}], "opinion_index": 0, "case_paths": ["/ariz/93/0266-01"]}, {"cite": "81 Ariz. 302", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [649572], "weight": 2, "pin_cites": [{"page": "306"}], "opinion_index": 0, "case_paths": ["/ariz/81/0302-01"]}, {"cite": "95 Ariz. 145", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [569661], "weight": 2, "pin_cites": [{"page": "150"}], "opinion_index": 0, "cas'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_35',
#   'text_chunk': '_paths": ["/ariz/81/0302-01"]}, {"cite": "95 Ariz. 145", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [569661], "weight": 2, "pin_cites": [{"page": "150"}], "opinion_index": 0, "case_paths": ["/ariz/95/0145-01"]}, {"cite": "376 P.2d 857", "category": "reporters:state_regional", "reporter": "P.2d", "case_ids": [628621, 628589], "opinion_index": 0, "case_paths": ["/ariz/92/0329-01", "/ariz/92/0328-01"]}, {"cite": "92 Ariz. 329", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [628621], "pin_cites": [{"page": "331"}], "opinion_index": 0, "case_paths": ["/ariz/92/0329-01"]}, {"cite": "93 Ariz. 116", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [614065], "weight": 2, "pin_cites": [{"page": "119"}], "opinion_index": 0, "case_paths": ["/ariz/93/0116-01"]}, {"cite": "90 Ariz. 97", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639103], "weight": 2, "pin_cites": [{"page": "102"}], "opinion_index": 0, "case_paths": ["/ariz/9'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_36',
#   'text_chunk': '3/0116-01"]}, {"cite": "90 Ariz. 97", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639103], "weight": 2, "pin_cites": [{"page": "102"}], "opinion_index": 0, "case_paths": ["/ariz/90/0097-01"]}, {"cite": "375 P.2d 364", "category": "reporters:state_regional", "reporter": "P.2d", "case_ids": [628596], "opinion_index": 0, "case_paths": ["/ariz/92/0159-02"]}, {"cite": "92 Ariz. 159", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [628563, 628596], "pin_cites": [{"page": "167"}], "opinion_index": 0, "case_paths": ["/ariz/92/0159-01", "/ariz/92/0159-02"]}, {"cite": "77 Ariz. 235", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639497], "weight": 3, "pin_cites": [{"page": "732"}], "opinion_index": 0, "case_paths": ["/ariz/77/0235-01"]}], "analysis": {"cardinality": 544, "char_count": 9374, "ocr_confidence": 0.689, "pagerank": {"raw": 2.3541482191926022e-07, "percentile": 0.793572907146324}, "sha256": "b281615b57911d044b39dff75ec52431a649a'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_37',
#   'text_chunk': 'lysis": {"cardinality": 544, "char_count": 9374, "ocr_confidence": 0.689, "pagerank": {"raw": 2.3541482191926022e-07, "percentile": 0.793572907146324}, "sha256": "b281615b57911d044b39dff75ec52431a649a5b388c593bfb0bf4c4356565fad", "simhash": "1:542b1024635c9d74", "word_count": 1549}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0036-01", "first_page_order": 62, "last_page_order": 66}\n{"id": 1234426, "name": "In the Matter of the ESTATE of Arthur Marshal FOREMAN, aka Arthur Marshal Forman, aka Arthur M. Foreman, aka Arthur M. Forman, aka A. M. Foreman, aka A. M. Forman, Deceased. FIRST NATIONAL BANK OF ARIZONA, PHOENIX, Executor of the Estate of Arthur Marshal Foreman, deceased, and Richard Forman and Mary Joan Koenigs, Beneficiaries under the Last Will and Testament of Arthur Marshal Foreman, deceased, Appellants, v. Laura THOMASON, Individually and as Administratrix, with Will annexed'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_38',
#   'text_chunk': ' Forman and Mary Joan Koenigs, Beneficiaries under the Last Will and Testament of Arthur Marshal Foreman, deceased, Appellants, v. Laura THOMASON, Individually and as Administratrix, with Will annexed, of the Last Will and Testament of Mary R. Foreman, deceased, Appellee", "name_abbreviation": "First National Bank v. Thomason", "decision_date": "1965-02-19", "docket_number": "No. 2 CA-CIV 37", "first_page": "41", "last_page": "42", "citations": [{"type": "official", "cite": "1 Ariz. App. 41"}, {"type": "parallel", "cite": "398 P.2d 175"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "71 Ariz. 334", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5153104], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/71/0334-01"]}, {"cite": "70 Ariz. 349", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5781723], "wei'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_39',
#   'text_chunk': '", "case_ids": [5153104], "weight": 2, "opinion_index": 0, "case_paths": ["/ariz/71/0334-01"]}, {"cite": "70 Ariz. 349", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5781723], "weight": 2, "year": 1951, "opinion_index": 0, "case_paths": ["/ariz/70/0349-01"]}, {"cite": "65 Ariz. 9", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5174394], "weight": 2, "year": 1950, "opinion_index": 0, "case_paths": ["/ariz/65/0009-01"]}, {"cite": "43 Ariz. 27", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [5058530], "weight": 4, "opinion_index": 0, "case_paths": ["/ariz/43/0027-01"]}, {"cite": "19 Ariz. 205", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [4915783], "weight": 2, "year": 1934, "opinion_index": 0, "case_paths": ["/ariz/19/0205-01"]}], "analysis": {"cardinality": 305, "char_count": 4688, "ocr_confidence": 0.699, "pagerank": {"raw": 5.663806401086183e-08, "percentile": 0.35299065698424886}, "sha256": "cb88a5de5070e0be'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_40',
#   'text_chunk': '19/0205-01"]}], "analysis": {"cardinality": 305, "char_count": 4688, "ocr_confidence": 0.699, "pagerank": {"raw": 5.663806401086183e-08, "percentile": 0.35299065698424886}, "sha256": "cb88a5de5070e0be3a0a4dd405946a4044fd4444d4a94ff4ab163583de415346", "simhash": "1:25794877754fc94f", "word_count": 773}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0041-01", "first_page_order": 67, "last_page_order": 68}\n{"id": 1234455, "name": "The STATE of Arizona, Appellee, v. Phillip Ray EDWARDS, Appellant", "name_abbreviation": "State v. Edwards", "decision_date": "1965-02-24", "docket_number": "No. 1 CA-CR. 7", "first_page": "42", "last_page": "44", "citations": [{"type": "official", "cite": "1 Ariz. App. 42"}, {"type": "parallel", "cite": "399 P.2d 176"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Ari'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_41',
#   'text_chunk': 'App. 42"}, {"type": "parallel", "cite": "399 P.2d 176"}], "court": {"name_abbreviation": "Ariz. Ct. App.", "id": 8807, "name": "Arizona Court of Appeals"}, "jurisdiction": {"id": 21, "name_long": "Arizona", "name": "Ariz."}, "cites_to": [{"cite": "96 Ariz. 113", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [637213], "weight": 2, "year": 1964, "opinion_index": 0, "case_paths": ["/ariz/96/0113-01"]}, {"cite": "90 Ariz. 376", "category": "reporters:state", "reporter": "Ariz.", "case_ids": [639081], "weight": 3, "year": 1962, "opinion_index": 0, "case_paths": ["/ariz/90/0376-01"]}, {"cite": "372 U.S. 335", "category": "reporters:federal", "reporter": "U.S.", "case_ids": [1765333], "weight": 7, "year": 1963, "opinion_index": 0, "case_paths": ["/us/372/0335-01"]}], "analysis": {"cardinality": 403, "char_count": 6471, "ocr_confidence": 0.685, "pagerank": {"raw": 1.9822250805646743e-07, "percentile": 0.7407248453481264}, "sha256": "7e8bf0494b7683338547c22d30bbd0523d2072b4874'},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_42',
#   'text_chunk': ' {"cardinality": 403, "char_count": 6471, "ocr_confidence": 0.685, "pagerank": {"raw": 1.9822250805646743e-07, "percentile": 0.7407248453481264}, "sha256": "7e8bf0494b7683338547c22d30bbd0523d2072b48748132e39930573311a165b", "simhash": "1:cac6dcaa16a01720", "word_count": 1121}, "last_updated": "2024-02-27T17:18:29.251436+00:00", "provenance": {"date_added": "2019-08-29", "source": "Harvard", "batch": "2018"}, "file_name": "0042-01", "first_page_order": 68, "last_page_order": 70}\n{"id": 1234396, "name": "SANITARY DISTRICT NO. 1 OF PIMA COUNTY, Arizona, and City of Tucson, a municipal corporation, Appellants, v. STATE of Arizona ex rel. William E. WILLEY, State Highway Engineer, Appellee", "name_abbreviation": "Sanitary District No. 1 v. State", "decision_date": "1965-02-24", "docket_number": "No. 2 CA-CIV 17", "first_page": "45", "last_page": "51", "citations": [{"type": "official", "cite": "1 Ariz. App. 45"}, {"type": "parallel", "cite": "399 P.2d 179"}], "court": {"name_abbreviation": '},
#  {'id': 'ariz-app_1.zip_extracted_metadata_CasesMetadata.json_chunk_43',
# ...
#  {'id': 'ariz_1.zip_extracted_json_0099-01.json_chunk_185',
#   'text_chunk': 's offered to prove the contents. 1 Greenl. 595, 596, sec. 558.\\nThe court erred in rejecting the following question: \\u201cFor what purpose did you request Linn to send you a deed of the premises in controversy, or a power of attorney ?\\u201d Not offered to impeach deed or power of attorney, but for the purpose of explaining the reason of their execution.\\nThe court erred in rejecting the following evidence: The defendants offered to purge the whole transaction of any suspicion of fraud in the location of the mine and their conduct subsequent thereto, but the evidence was objected to by plaintiffs and excluded by the court, yet the court submits the question to the jury whether the claim was located for the benefit of French and Moreland.\\nThe court erred in rejecting the evidence offered by defendants to prove the declarations and admissions of the grantor of plaintiffs, Mary E. Sawyer, at the time of the pretended location of the mine by her, that she located because Linn was a non-r'},
#  {'id': 'ariz_1.zip_extracted_json_0099-01.json_chunk