# %% [markdown]
# #### Worked Example 2

# %% [markdown]
# #### Understanding Dataset
#
# This dataset contains insightful information related to insurance claims, giving us an in-depth look into the demographic patterns of those receiving them. The dataset contains information on patient age, gender, BMI (Body Mass Index), blood pressure levels, diabetic status, number of children, smoking status and region. By analyzing these key factors across geographical areas and across different demographics such as age or gender we can gain a greater understanding of who is most likely to receive an insurance claim.
#
# This understanding gives us valuable insight that can be used to inform our decision making when considering potential customers for our services. On a broader scale it can inform public policy by allowing for more targeted support for those who are most in need and vulnerable. These kinds of insights are extremely valuable and this dataset provides us with the tools we need to uncover them!
#
#  <div style="text-align:center">
#     <img src="https://www.internationalstudentinsurance.com/blog/wp-content/uploads/2017/08/Insurance-Claims_EN.png" alt="Image Alt Text" width="500"/>
# </div>
#
# The insurance_data.csv file contains detailed information about insurance claims, including age, gender, BMI, blood pressure, diabetic status, number of children, smoking status and region of the insured person
#
# Diabetic: Whether the insured person is diabetic or not. (Boolean)
# Children: Number of children of the insured person. (Integer)
# Smoker: Whether the insured person is a smoker or not. (Boolean)
# Claim: Amount of the insurance claim. (Float)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /var/folders/yq/ssn56htj0_jdf574hksbbxw00000gn/T/ipykernel_54809/265554930.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('insurance_data.csv')

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.tail()
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# 1335    Yes  northwest  55135.40
# 1336    Yes  northeast  58571.07
# 1337    Yes  northwest  60021.40
# 1338    Yes  southeast  62592.87
# 1339    Yes  southeast  63770.43

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1340 non-null   int64
#  1   PatientID      1340 non-null   int64
#  2   age            1335 non-null   float64
#  3   gender         1340 non-null   object
#  4   bmi            1340 non-null   float64
#  5   bloodpressure  1340 non-null   int64
#  6   diabetic       1340 non-null   object
#  7   children       1340 non-null   int64
#  8   smoker         1340 non-null   object
#  9   region         1337 non-null   object
#  10  claim          1340 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 115.3+ KB

# %%
df.describe()
# Out:
#              index    PatientID          age          bmi  bloodpressure  \
# count  1340.000000  1340.000000  1335.000000  1340.000000    1340.000000
# mean    669.500000   670.500000    38.078652    30.668955      94.157463
# std     386.968991   386.968991    11.102924     6.106735      11.434712
# min       0.000000     1.000000    18.000000    16.000000      80.000000
# 25%     334.750000   335.750000    29.000000    26.275000      86.000000
# 50%     669.500000   670.500000    38.000000    30.400000      92.000000
# 75%    1004.250000  1005.250000    47.000000    34.700000      99.000000
# max    1339.000000  1340.000000    60.000000    53.100000     140.000000
#
#           children         claim
# count  1340.000000   1340.000000
# mean      1.093284  13252.745642
# std       1.205334  12109.609288
# min       0.000000   1121.870000
# 25%       0.000000   4719.685000
# 50%       1.000000   9369.615000
# 75%       2.000000  16604.305000
# max       5.000000  63770.430000

# %% [markdown]
# #### Column Types
# Numerical - Index, PatientID, age, bmi, bloodpressure, children, claim
#
# Categorical - gender, diabetic, smoker, region

# %% [markdown]
# #### Univariate Analysis

# %%
#Age
df['age'].describe()
# Out:
# count    1335.000000
# mean       38.078652
# std        11.102924
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
sns.set(style='ticks', palette='Set2')
sns.displot(data=df, x='age', kind='hist', bins=22).set(title='Age distribution')

# %%
sns.displot(data=df,x='age',kind='kde', fill=True,color=sns.color_palette()[3]).set(title='Age distribution - KDE plot')

# %%
# calculating the skew

df['age'].skew()
# Out:
# 0.11361133741072633

# %%
# calculating the skew

df['age'].skew()
# Out:
# 0.11361133741072633

# %% [markdown]
# #### Conclusions
#
# Age is normally (almost) distributed
#
# Maximum number of people are aged between 25 - 50
#
# There are less number of people aged between 38 - 40

# %% [markdown]
# #### BMI

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %%
df['bmi'].isnull().sum()
# Out:
# 0

# %%
sns.displot(data=df, x='bmi', kind='hist', color=sns.color_palette()[2]).set(title='BMI distribution')

# %%
sns.displot(data=df, x='bmi', kind='kde', color=sns.color_palette()[4], fill=True).set(title='BME distribution - KDE Plot')

# %%
df['bmi'].skew()
# Out:
# 0.28597245020808587

# %%
df['bmi'].describe()
# Out:
# count    1340.000000
# mean       30.668955
# std         6.106735
# min        16.000000
# 25%        26.275000
# 50%        30.400000
# 75%        34.700000
# max        53.100000
# Name: bmi, dtype: float64

# %% [markdown]
# ##### If your BMI is less than 18.5, it falls within the underweight range. If your BMI is 18.5 to 24.9, it falls within the Healthy Weight range. If your BMI is 25.0 to 29.9, it falls within the overweight range. If your BMI is 30.0 or higher, it falls within the obese range (Source)
#
# 1. We can see from the study that general BMI range is from 18.5 to 24.9, but in our dataset, more than 50% of people have a BMI higher than 30 and the maximum is 53 which is extremely high
#
# 2. Let's take a closer look at these points

# %%
df[df['bmi'] > 26]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1         1          2  24.0    male  30.1             87       No         0
# 2         2          3   NaN    male  33.3             82      Yes         0
# 3         3          4   NaN    male  33.7             80       No         0
# 4         4          5   NaN    male  34.1            100       No         0
# 5         5          6   NaN    male  34.4             96      Yes         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %%
sns.kdeplot(data=df, x='bmi', fill=True)
sns.rugplot(data=df, x='bmi', color=sns.color_palette()[5]).set(title='BMI distribution -KDE + Rug Plot')
# Out:
# [Text(0.5, 1.0, 'BMI distribution -KDE + Rug Plot')]

# %%
sns.boxplot(data=df, y='bmi').set(title='BMI distribution - Box Plot')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# [Text(0.5, 1.0, 'BMI distribution - Box Plot')]

# %% [markdown]
# #### The boxplot says the median value is at 30 and the data has outliers over the value of 47 (around). This still seems really high and we will not this in our obervations
#
# #### Conclusion :
#
# The BMI is normally distributed
# The BMI has very high values, values reaching over 45
# Median iss at 30, which is considered as obese
# no missing values

# %% [markdown]
# #### BP

# %%
df['bloodpressure'].describe()
# Out:
# count    1340.000000
# mean       94.157463
# std        11.434712
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
sns.displot(data=df, x='bloodpressure', kind='hist', color=sns.color_palette()[6]).set(title='Bloodpressure distribution')

# %%
df['bloodpressure'].skew()
# Out:
# 1.4835342102293079

# %%
sns.catplot(data=df, y='bloodpressure', kind='box', color=sns.color_palette()[5]).set(title='Bloodpressure distribution - Box Plot')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
df[df['bloodpressure'] > 120]
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 1147   1147       1148  29.0  female  32.7            128      Yes         2
# 1150   1150       1151  55.0  female  27.1            135       No         1
# 1152   1152       1153  38.0  female  35.9            128       No         1
# 1153   1153       1154  43.0    male  36.8            126       No         2
# 1154   1154       1155  31.0    male  23.8            126      Yes         0
# 1156   1156       1157  46.0  female  23.0            137      Yes         0
# 1161   1161       1162  22.0    male  22.4            137      Yes         2
# 1166   1166       1167  23.0    male  26.7            123      Yes         0
# 1169   1169       1170  27.0    male  36.7            130       No         1
# 1174   1174       1175  44.0  female  29.1            139       No         0
# 1181   1181       1182  32.0    male  28.6            132       No         0
# ...

# %%
df['bloodpressure'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Claim

# %%
df['claim'].describe()
# Out:
# count     1340.000000
# mean     13252.745642
# std      12109.609288
# min       1121.870000
# 25%       4719.685000
# 50%       9369.615000
# 75%      16604.305000
# max      63770.430000
# Name: claim, dtype: float64

# %%
sns.displot(data=df, x='claim', kind='hist', color=sns.color_palette()[3]).set(title='Claim distribution')

# %%
sns.catplot(data=df, y='claim', kind='box').set(title='Claim distribution - Box Plot')
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
df['claim'].skew()
# Out:
# 1.5167468509489237

# %%
df['claim'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Conclusion :
# Claim amout is generally between 0 - 20,000

# %% [markdown]
# #### Bivariate Analysis
#
# ##### Gender and Claim

# %%
sns.barplot(data=df, x='gender', y='claim').set(title='Gender vs Claim')
# Out:
# [Text(0.5, 1.0, 'Gender vs Claim')]

# %% [markdown]
# ##### Men have more claims than women

# %% [markdown]
# #### Claim and Diabetic

# %%
sns.barplot(data=df, x='diabetic', y='claim').set(title='Diabetic vs Claim')
# Out:
# [Text(0.5, 1.0, 'Diabetic vs Claim')]

# %%
sns.violinplot(data=df, x='diabetic', y='claim')
plt.title('Diabetic vs Claim Amount Distribution - Violin Plot')
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.stripplot(data=df, x='diabetic', y='claim', jitter=True, dodge=True)
plt.title('Diabetic vs Claim - Strip Plot')
plt.show()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# #### Diabetic people have more claims than non diabetic people

# %% [markdown]
# #### Claim and Smoker

# %%
sns.barplot(data=df, x='smoker', y='claim').set(title='Smoker vs Claim')
# Out:
# [Text(0.5, 1.0, 'Smoker vs Claim')]

# %% [markdown]
# #### Smokers have more claim than non smokers

# %% [markdown]
# #### Claim and Region

# %%
sns.barplot(data=df, x='region', y='claim').set(title='Region vs Claim')
# Out:
# [Text(0.5, 1.0, 'Region vs Claim')]

# %% [markdown]
# #### NorthEast has the most number of claims.
#
# This might indicate the more number of smokers are living in the NE region
# NE might have more men than women

# %%
pd.crosstab(df['smoker'], df['region'], normalize='columns')
# Out:
# region  northeast  northwest  southeast  southwest
# smoker
# No       0.709957   0.833811   0.794582   0.815287
# Yes      0.290043   0.166189   0.205418   0.184713

# %% [markdown]
# #### As you can see that most non smokers are living in the NE region, which confirms our assumption

# %% [markdown]
# #### Multivariate Analysis
#
# #### BloodPressure and Gender on Claim

# %%
sns.jointplot(data=df,x='bloodpressure',y='claim',kind='scatter',hue='gender', palette='bright')
plt.suptitle('BP & Gender on Claim')
plt.subplots_adjust(top=0.90)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# #### The plot reveals that there is some correlation between claim value and bloodpressure, in both male & female groups

# %% [markdown]
# #### Age, gender on claim

# %%
sns.jointplot(data=df,x='age',y='claim',kind='scatter',hue='gender', palette='bright')
plt.suptitle('Age & Gender on Claim')
plt.subplots_adjust(top=0.90)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# #### Nothing significant can be observed from this

# %% [markdown]
# #### Age and Diabetes on claim

# %%
sns.jointplot(data=df,x='age',y='claim',kind='scatter',hue='diabetic', palette='bright')
plt.suptitle('Age & Diabetic on Claim')
plt.subplots_adjust(top=0.90)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# #### Nothing significant can be observed

# %% [markdown]
# #### Age and smoker on claim

# %%
sns.jointplot(data=df,x='age',y='claim',kind='scatter',hue='smoker', palette='bright')
plt.suptitle('Age & Smoker on Claim')
plt.subplots_adjust(top=0.90)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/homebrew/Caskroom/miniforge/base/envs/ev/lib/python3.9/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# #### This plot shows that smoker have a high claim value

# %% [markdown]
# #### Bonus Example OF EDA
#
# ##### Time Series Analysis

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %%
# reading the data
df = pd.read_csv('btc.csv')

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-01-29  3468.870117  3476.065430  3400.819824  3448.116943
# 1  2019-01-30  3443.896973  3495.174805  3429.387939  3486.181641
# 2  2019-01-31  3485.409180  3504.804932  3447.915771  3457.792725
# 3  2019-02-01  3460.547119  3501.954102  3431.591553  3487.945313
# 4  2019-02-02  3484.625977  3523.287354  3467.574707  3521.060791
#
#      Adj Close        Volume
# 0  3448.116943  5.897159e+09
# 1  3486.181641  5.955113e+09
# 2  3457.792725  5.831198e+09
# 3  3487.945313  5.422927e+09
# 4  3521.060791  5.071624e+09

# %%
df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1823  2024-01-26  39936.816406  42209.386719  39825.691406  41816.871094
# 1824  2024-01-27  41815.625000  42195.632813  41431.281250  42120.054688
# 1825  2024-01-28  42126.125000  42797.175781  41696.910156  42035.593750
# 1826  2024-01-29           NaN           NaN           NaN           NaN
# 1827  2024-01-30  43300.226563  43725.660156  43176.347656  43557.242188
#
#          Adj Close        Volume
# 1823  41816.871094  2.559812e+10
# 1824  42120.054688  1.142294e+10
# 1825  42035.593750  1.685897e+10
# 1826           NaN           NaN
# 1827  43557.242188  2.217897e+10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1828 entries, 0 to 1827
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1828 non-null   object
#  1   Open       1827 non-null   float64
#  2   High       1827 non-null   float64
#  3   Low        1827 non-null   float64
#  4   Close      1827 non-null   float64
#  5   Adj Close  1827 non-null   float64
#  6   Volume     1827 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 100.1+ KB

# %%
#summary statistics
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   1827.000000   1827.000000   1827.000000   1827.000000   1827.000000
# mean   25185.782225  25756.180247  24575.095349  25204.764079  25204.764079
# std    16016.278178  16419.466240  15548.503143  16009.046938  16009.046938
# min     3401.376465   3427.945557   3391.023682   3399.471680   3399.471680
# 25%     9917.354981  10166.542969   9724.194825   9929.474610   9929.474610
# 50%    22954.021484  23388.322266  22603.416016  22961.279297  22961.279297
# 75%    37503.277344  38628.927735  36465.330079  37555.906250  37555.906250
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  1.827000e+03
# mean   2.936545e+10
# std    1.795642e+10
# min    5.004963e+09
# 25%    1.748666e+10
# 50%    2.592029e+10
# 75%    3.654403e+10
# max    3.509679e+11

# %%
#summary statistics for the closing price
df['Close'].describe()
# Out:
# count     1827.000000
# mean     25204.764079
# std      16009.046938
# min       3399.471680
# 25%       9929.474610
# 50%      22961.279297
# 75%      37555.906250
# max      67566.828125
# Name: Close, dtype: float64

# %%
#creating return series
#return = percentage change in adjusted closing price
df['Return'] = df['Adj Close'].pct_change()
# Out:
# /var/folders/yq/ssn56htj0_jdf574hksbbxw00000gn/T/ipykernel_54809/1626808977.py:3: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Return'] = df['Adj Close'].pct_change()

# %%
df.head()
#for the 1st row you will always get nan in return because there is no previous value to calculate the return day.
# since return can be negative or positive, there are both positive and negative values in the return series
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-01-29  3468.870117  3476.065430  3400.819824  3448.116943
# 1  2019-01-30  3443.896973  3495.174805  3429.387939  3486.181641
# 2  2019-01-31  3485.409180  3504.804932  3447.915771  3457.792725
# 3  2019-02-01  3460.547119  3501.954102  3431.591553  3487.945313
# 4  2019-02-02  3484.625977  3523.287354  3467.574707  3521.060791
#
#      Adj Close        Volume    Return
# 0  3448.116943  5.897159e+09       NaN
# 1  3486.181641  5.955113e+09  0.011039
# 2  3457.792725  5.831198e+09 -0.008143
# 3  3487.945313  5.422927e+09  0.008720
# 4  3521.060791  5.071624e+09  0.009494

# %%
np.mean(df['Return'])
# Out:
# 0.0020105435990812742

# %%
#plotting closing price
#simple time series plot
ax1 = df['Adj Close'].plot(style = ['-'])

# %%
ax2 = df['Return'].plot(style = ['-'])
#there are huge spikes in the return series
#we can see that the return series is not stationary

# %%
#dotted plot 
df['Return'].plot(style = ['.k'])
# Out:
# <Axes: >

# %%
df['Return'].hist()
#historgram of the return series
# Out:
# <Axes: >

# %%
df['Adj Close'].hist()
#histogram of the closing price series
# Out:
# <Axes: >

# %%
#kernel density plot
df['Adj Close'].plot(kind = 'kde')
#better way compared to histogram
# Out:
# <Axes: ylabel='Density'>

# %%
df['Return'].plot(kind = 'kde')
#Kernel density plot of the return series
# Out:
# <Axes: ylabel='Density'>

# %%
#exponential smoothing
#very basic model
# exponential smoothing model is about it will take some historical points from time series provide more wieghts to recent periods and less weights to farther periods.
#default threshold is used

from statsmodels.tsa.holtwinters import SimpleExpSmoothing

model = SimpleExpSmoothing(df['Adj Close']).fit(smoothing_level = 0.1, optimized = False)

df['Adj Close'].plot(marker = 'o', color = 'red')
model.fittedvalues.plot(marker = 'o', color = 'blue')


## Here Red line is the actual data and blue line is the predicted values
#It is fitting well but it is not capturing the spikes in the data
# Out:
# <Axes: >

# %%
# lag plot to check if the series is random

from pandas.plotting import lag_plot
lag_plot(df['Adj Close'])

#it's is not random because it is following a pattern
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
#Autocorrelation plot

from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Adj Close'])
#it is showing strong autocorrelation
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# #### References
#
# 	•	https://www.kaggle.com/
# 	•	https://towardsdatascience.com/
# 	•	https://medium.com/
# 	•	https://www.geeksforgeeks.org/?newui
# 	•	https://scikit-learn.org/stable/
# 	•	https://www.chatgpt.com/
# 	•	https://www.youtube.com/freecodecamp/
# 	•	https://www.datacamp.com/
# 	•	https://stackoverflow.com/
#     •	Yahoo Finance
# 	•	INFO7390 Repo
