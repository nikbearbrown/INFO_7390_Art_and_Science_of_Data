# %% [markdown]
# ***Introduction to Causality***:
#
#
# ---
#
#
# Causality is all about figuring out how one thing leads to another. It's like connecting the dots between actions and outcomes. For example, we might wonder if eating healthy food leads to feeling better. Understanding causality helps us make sense of these connections. It's important because it helps scientists and decision-makers make better choices based on real evidence. But it's not always easy. Sometimes, things that seem connected might not really be, so we have to be careful. Scientists use different methods, like experiments and studies, to untangle these connections and find out what's really causing what. By understanding causality, we can make smarter decisions and learn more about how the world works.

# %% [markdown]
# <img src="https://i.pinimg.com/564x/fd/1c/9e/fd1c9e4187e11438f3bcd1623e42bf04.jpg" style="float:centre;width:50px;height:50px;">

# %% [markdown]
# **Understanding Cause and Effect:**
#
#
# ---
#
#
# 1. **The Essence of Causality:**
#    Causality, the cornerstone of scientific inquiry, delves into the relationships between events, aiming to uncover the mechanisms that drive outcomes. At its core, causality seeks to answer the fundamental question: what causes what?
#
# 2. **The Philosophical Underpinnings:**
#    Causal inquiry finds its roots in ancient philosophical discourse, where thinkers pondered the nature of causation and its implications for human understanding. From Aristotle's notion of the four causes to Hume's skepticism, philosophers have grappled with the complexities of causality.
#
# 3. **The Modern Framework:**
#    Contemporary approaches to causality draw from philosophical insights while integrating rigorous methodologies from statistics, epidemiology, and other disciplines. Key figures like Judea Pearl have revolutionized causal inference, providing a structured framework for understanding cause-and-effect relationships.
#
# 4. **Counterfactuals:**
#    Central to causal inference is the concept of counterfactuals – hypothetical scenarios that depict what would have happened under different conditions. Pearl's work highlights the role of counterfactuals in quantifying causal effects and disentangling complex causal relationships.
#
# 5. **Challenges in Causal Inference:**
#    Despite its significance, unraveling causality poses numerous challenges. Confounding, the presence of extraneous factors that obscure true causal relationships, remains a pervasive issue. Madelyn Glymour and Nicholas P. Jewell explore strategies for addressing confounding and enhancing causal inference methodologies.
#
# 6. **Applications Across Disciplines:**
#    Causal inference finds application in diverse fields, from medicine and public health to economics and social sciences. Understanding causal relationships is essential for designing effective interventions, evaluating policies, and making informed decisions.
#
# 7. **The Promise of Causal Inference:**
#    By elucidating cause-and-effect relationships, causal inference holds the promise of advancing knowledge, fostering evidence-based decision-making, and driving innovation across disciplines. As researchers continue to refine methodologies and grapple with complex causal phenomena, the quest to understand causality remains an enduring intellectual pursuit.
#
# In this introduction, we embark on a journey through the intricate landscape of causality, exploring its philosophical foundations, methodological frameworks, and practical implications. By synthesizing insights from seminal works and contemporary scholarship, we aim to provide a comprehensive understanding of causality's significance in shaping our understanding of the world.

# %% [markdown]
# **Main topics in causality include:**
#
# ---
#
#
# 1. Cause and Effect: Understanding how changes in one variable lead to changes in another.
# 2. Correlation vs. Causation: Differentiating between variables moving together and one causing the other.
# 3. Controlled Experiments: Using experiments to isolate the effect of a single variable on an outcome.
# 4. Observational Studies: Analyzing data to infer causality when experiments are not feasible.
# 5. Confounding Variables: Identifying and controlling variables that influence both the cause and effect.
# 6. Causal Inference: Using statistical methods to deduce causal relationships from data.
# 7. Counterfactual Thinking: Considering what would happen if a specific event did not occur.
# 8. Potential Outcomes Framework: Defining causality based on potential outcomes under different scenarios.
# 9. Directed Acyclic Graphs (DAGs): Visual representations of causal relationships.
# 10. Granger Causality: Testing whether one time series can predict another.
# 11. Structural Causal Models (SCMs): Frameworks for causal inference using observational data.
# 12. Randomized Controlled Trials (RCTs): Gold standard experiments for establishing causality.
# 13. Instrumental Variables (IV): Using variables that affect the treatment but not the outcome for causal inference.

# %% [markdown]
# **Correlation vs Causation:**
#
# ---
#
#
# Correlation and causation are two concepts often encountered in statistics and data analysis, each addressing different aspects of the relationship between variables.
#
# **Correlation** refers to the statistical relationship between two variables, where changes in one variable are associated with changes in another. It measures the strength and direction of the linear relationship between variables, typically quantified by correlation coefficients such as Pearson's r or Spearman's rank correlation coefficient. For example, if we observe a high positive correlation between ice cream sales and temperature, it means that as temperatures rise, ice cream sales tend to increase as well.
#
# However, **correlation** does not imply **causation**. Just because two variables are correlated does not mean that changes in one variable cause changes in the other. This is a common fallacy known as the "correlation does not imply causation" principle.
#
# **Causation**, on the other hand, refers to the relationship where one variable directly influences the other, leading to a cause-and-effect relationship. Establishing **causation** requires more than just observing a correlation. It involves demonstrating that changes in one variable actually lead to changes in another, typically through controlled experiments or rigorous observational studies. For instance, to establish that smoking causes lung cancer, researchers have conducted extensive studies, including randomized controlled trials and cohort studies, to demonstrate the **causal** link between smoking and the development of lung cancer.
#
# In summary, while **correlation** measures the degree of association between variables, **causation** goes further to establish a direct cause-and-effect relationship. It's essential to be cautious when interpreting correlations and to use additional evidence and research methods to establish **causation** reliably.

# %% [markdown]
# ![image.png](https://statisticseasily.com/wp-content/uploads/2023/05/correlation-vs-causality-2.jpg)

# %% [markdown]
# **Correlation vs Causation Examples**
#
# ---
#
#
# 1. **Ice cream sales and drowning incidents:**
#    Ice cream sales and the number of drowning incidents are positively correlated. However, this does not mean that ice cream sales cause drownings. The underlying factor is the hot weather, leading to increased ice cream consumption and more people swimming, thus increasing the risk of drowning. In this case, the hot weather acts as a confounding variable.
#
# 2. **Number of firefighters and the damage caused by fires:**
#    In some instances, data may show a positive correlation between the number of firefighters at a fire scene and the damage caused by the fire. This correlation does not mean firefighters cause more damage; larger fires require more firefighters and tend to cause more damage. Here, the size of the fire is the confounding variable.
#
# 3. **Education level and income:**
#    Data often reveals a positive correlation between a person’s education level and income. While this correlation might suggest that higher education causes higher income, it is essential to consider other factors that could influence this relationship, such as individual abilities, work experience, and social networks. The correlation between education and income does not guarantee a causal relationship.
#
# 4. **Pirate population and global temperature:**
#    A humorous example often cited to demonstrate the distinction between correlation and causality is the decrease in the number of pirates over the past centuries and the increase in global temperature. Though the data might show an inverse correlation between the pirate population and global temperature, it is absurd to suggest that the decline in pirates causes global warming.

# %% [markdown]
# *An often-cited example, famously used as a parody by the author of the Flying Spaghetti Monster to debunk misleading graphs, involves Pirates versus Global Warming. In this example, Somalia is humorously noted to have "the highest number of pirates and the lowest carbon emissions of any country."*

# %%
file = '/content/pirates-vs-global-warming.csv'
import pandas as pd
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import ColumnDataSource
from bokeh.models.annotations import Title
df = pd.read_csv(file)
source = ColumnDataSource(df)
plot = figure()
t = Title()
t.text = 'Global Average Temperature (celsius) vs Number of Pirates (approximate)'
plot.title=t
legend_label = 'Years (1820-2000)'
x='global-average-temperature'
y='number-of-pirates'
color='green'
plot.line(x=x, y=y, line_width=1, source=source, color=color, legend_label=legend_label)
output_notebook()
show(plot)
# Out:
#   <div id="f9c26ca9-b52e-4565-9388-1455961df750" data-root-id="p1055" style="display: contents;"></div>

# %% [markdown]
# **Strategies for Identifying Causation in Data Analysis**
#
#
# ---
#
#
# **Establishing causality** is critical to data analysis, allowing researchers to infer cause-and-effect relationships between variables. Identifying causality can be challenging, but several strategies can help analysts determine if a causal relationship exists. This section outlines some key strategies for identifying causality in data analysis.
#
# **Controlled experiments:** These experiments involve manipulating an independent variable and measuring its impact on a dependent variable to establish causality. Random assignment and controlling confounding factors help isolate the causal effect.
#
# **Natural experiments:** When controlled experiments are not possible or ethical, natural experiments can estimate causal effects by comparing groups exposed to naturally occurring conditions that resemble a controlled experiment.
#
# **Longitudinal studies:** These studies collect data on subjects over time, examining how changes in variables relate to one another. Temporal precedence is crucial for establishing causality.
#
# **Granger causality:** A time series analysis approach determining if one-time series can predict another, providing evidence of causality through lagged relationships between variables but not guaranteeing cause-and-effect.
#
# **Instrumental variables:** This technique estimates causal relationships in the presence of confounding factors by identifying an instrument related to the independent variable but not affected by confounding factors.
#
# **Regression discontinuity design:** A quasi-experimental method estimating causal effects by comparing observations near a threshold, assessing treatment impact while accounting for confounding factors.
#
# **Meta-analysis:** Combines multiple studies’ results to estimate overall effect size, examining causal relationship consistency and strength across studies and identifying potential moderators.
#
# **Propensity score matching:** Controls selection bias in observational studies by matching treatment and control groups based on covariates predicting treatment assignment likelihood and estimating causal effects while controlling confounding factors.
#
# **Difference-in-differences:** A quasi-experimental method comparing variable outcome changes between treatment and control groups over time, estimating causal effects while controlling confounding factors.
#
# **Mediation analysis:** Examines how an independent variable affects a dependent variable via mediator variables, establishing a causal pathway.
#
# **Moderation analysis:** Investigates conditions under which relationships between variables change, identifying when causal relationships are stronger or weaker.
#
# **Counterfactual analysis:** Estimates causal effects by determining what would have happened if a treatment had not been applied or a different treatment had been applied, controlling confounding factors.
#
# **Fixed Effects Models:** Controls unobserved time-invariant factors in panel data analysis, estimating the causal effect of the independent variable on the dependent variable.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
suicide_data = pd.read_csv("/content/master.csv")

# Check the first few rows of the dataset
print(suicide_data.head())
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year gdp_for_year ($)  \
# 0               6.71  Albania1987           NaN    2,156,624,900
# 1               5.19  Albania1987           NaN    2,156,624,900
# 2               4.83  Albania1987           NaN    2,156,624,900
# 3               4.59  Albania1987           NaN    2,156,624,900
# 4               3.28  Albania1987           NaN    2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %% [markdown]
# **An Exploration Data Analysis**
#
# ---

# %%
suicide_data.describe()
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
suicide_data.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
# gdp_for_year ($)          0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %% [markdown]
# #The HDI for year variable has 19456 empty values. So we will drop it

# %%
suicide_data = suicide_data.rename({suicide_data.columns[9] : 'GDP for year', suicide_data.columns[10] : 'GDP per Capita'}, axis=1).drop(['country-year','HDI for year'], axis=1)
suicide_data['GDP for year'] = suicide_data['GDP for year'].apply(lambda x:x.replace(',', '')).astype(np.int64)
suicide_data = suicide_data.query('year != 2016')

# %%
ages = ['5-14 years', '15-24 years', '25-34 years', '35-54 years', '55-74 years', '75+ years']
genders = ['male', 'female']

# %%
from bokeh.io import output_notebook, output_file, show
from bokeh.plotting import figure
from bokeh.layouts import row, column
from bokeh.models import ColumnDataSource, NumeralTickFormatter, FactorRange, Div
from bokeh.models import Title
from bokeh.transform import factor_cmap
from bokeh.palettes import Plasma256, linear_palette, Inferno256
output_notebook()

# %%
def line_plot(x, y, p_width=400, p_height=400, color='blue', title='', legend='', x_label='', y_label=''):
    p = figure(plot_width=p_width, plot_height=p_height, title=title, toolbar_location=None)

    # Set line and circle glyphs
    p.line(x, y, line_width=2, color=color, legend=legend)
    p.circle(x, y, size=4, color=color, legend=legend)

    # Axis Attributes
    p.yaxis.axis_label = y_label
    p.xaxis.axis_label = x_label

    # Figure outline attributes
    p.outline_line_alpha = 0.4
    p.outline_line_width = 1.3
    p.outline_line_color = "gray"

    return p

# %%
population_year = suicide_data.groupby('year').sum().population.values
suicides_year = suicide_data.groupby('year').sum().suicides_no.values
suicides_per_100k_year = (suicides_year / population_year) * 100000
years = np.unique(suicide_data['year'].values)
# Out:
# <ipython-input-88-485400766693>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   population_year = suicide_data.groupby('year').sum().population.values
# <ipython-input-88-485400766693>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   suicides_year = suicide_data.groupby('year').sum().suicides_no.values

# %%
pip install --upgrade bokeh==2.4.3

# %%
p1 = line_plot(x=years,
               y=suicides_year,
               p_height=300,
               p_width=350,
               color = "#718dbf",
               title='Suicides Globally, per Year')

p2 = line_plot(x=years,
               y=suicides_per_100k_year,
               p_height=300,
               p_width=350,
               title='Suicides Globally, per 100k per Year',
               color="#e84d60")

# Set y-axis tick format
p1.yaxis.formatter=NumeralTickFormatter(format="0")
p2.yaxis.formatter=NumeralTickFormatter(format="0")

# Set title font size
p1.title.text_font_size = '11pt'
p2.title.text_font_size = '11pt'

# Set axes labels
p1.yaxis.axis_label = 'Suicides'
p1.xaxis.axis_label = 'Year'
p1.yaxis.axis_label_text_font_size='10.5pt'
p1.xaxis.axis_label_text_font_size='10.5pt'
p1.yaxis.axis_label_text_font_style='bold'
p1.xaxis.axis_label_text_font_style='bold'

p2.yaxis.axis_label = 'Suicides per 100k'
p2.xaxis.axis_label = 'Year'
p2.yaxis.axis_label_text_font_size='10.5pt'
p2.xaxis.axis_label_text_font_size='10.5pt'
p2.yaxis.axis_label_text_font_style='bold'
p2.xaxis.axis_label_text_font_style='bold'

### PLOTS FOR PERCENTAGE CHANGE

data = suicide_data.groupby('year').sum()
data.loc[:, 'suicides/100k pop'] = suicides_per_100k_year


p_pct1 = line_plot(x=data.reset_index().year.values,
              y=data.suicides_no.pct_change().values,
              title='Pct. Change of Suicides, per Year',
              p_height=300,
              p_width=350,
              color='black')

p_pct2 = line_plot(x=data.reset_index().year.values,
              y=data['suicides/100k pop'].pct_change().values,
              title='Pct. Change of Suicides per 100k, per Year',
              p_height=300,
              p_width=350,
              color='black')

# Title attributes
p_pct1.title.text_font_size = '10pt'
p_pct2.title.text_font_size = '10pt'
p_pct1.title.text_font_style = 'bold italic'
p_pct2.title.text_font_style = 'bold italic'


# Axes attributes
p_pct1.yaxis.axis_label='Pct. of Suicides'
p_pct1.xaxis.axis_label='Year'
p_pct1.yaxis.axis_label_text_font_size='10.5pt'
p_pct1.xaxis.axis_label_text_font_size='10.5pt'
p_pct1.yaxis.axis_label_text_font_style='bold'
p_pct1.xaxis.axis_label_text_font_style='bold'
p_pct1.yaxis.formatter=NumeralTickFormatter(format='0%')

p_pct2.yaxis.axis_label='Pct. of Suicides per 100k'
p_pct2.xaxis.axis_label='Year'
p_pct2.yaxis.axis_label_text_font_size='10.5pt'
p_pct2.xaxis.axis_label_text_font_size='10.5pt'
p_pct2.yaxis.axis_label_text_font_style='bold'
p_pct2.xaxis.axis_label_text_font_style='bold'
p_pct2.yaxis.formatter=NumeralTickFormatter(format='0%')


show(column(row(p1, p_pct1), row(p2, p_pct2)))
# Out:
# ...
# <ipython-input-90-dd15273a8cb8>:40: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = suicide_data.groupby('year').sum()
# ...
#   <div class="bk-root" id="dba7be7f-006d-4fe4-81ba-e47e52dbefed" data-root-id="8907"></div>

# %%
data = suicide_data.groupby(['country']).sum().suicides_no.nlargest(40).reset_index()

dt = suicide_data.groupby(['country']).sum()
suicides = dt.suicides_no.values
population = dt.population.values
suicides_per_100k = (suicides / population) * 1e5

dt['suicides/100k pop'] = suicides_per_100k
dt = dt['suicides/100k pop'].nlargest(40).reset_index()

countries = np.flip(data['country'].values)
suicides_country = np.flip(data['suicides_no'].values)
countries_100k = np.flip(dt['country'].values)
suicides_country_100k = np.flip(dt['suicides/100k pop'].values)
# Out:
# <ipython-input-91-ccfb1e57395e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = suicide_data.groupby(['country']).sum().suicides_no.nlargest(40).reset_index()
# <ipython-input-91-ccfb1e57395e>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dt = suicide_data.groupby(['country']).sum()

# %%
source = ColumnDataSource(data=dict(suicides_country_100k=suicides_country_100k, countries_100k=countries_100k,
                                     color=linear_palette(Plasma256[50:100], 40)[::-1]))

p = figure(y_range=countries_100k,
           plot_height=700,
           plot_width=550,
           toolbar_location=None)

p.hbar(y='countries_100k',
       right='suicides_country_100k',
       height=0.8,
       source=source,
       color='color')

p.add_layout(Title(text="(Showing rates per 100000 individuals)", text_font_style="italic", text_font_size='11pt'), 'above')
p.add_layout(Title(text="Suicide Rates, by Country", text_font_size="16pt"), 'above')

# Axes attributes
p.x_range.start = 0
p.ygrid.grid_line_color = None
p.xaxis.formatter=NumeralTickFormatter(format="0")

# Set and adjust axes labels
p.xaxis.axis_label = 'Suicides per 100k'
p.yaxis.axis_label='Country'
p.xaxis.axis_label_text_font_size='10.5pt'
p.yaxis.axis_label_text_font_size='11pt'
p.xaxis.axis_label_text_font_style='bold'
p.yaxis.axis_label_text_font_style='bold'

# Adjust y-axis major label font size
p.yaxis.major_label_text_font_size='10.6pt'

# Title attributes
p.title.text_font_size = '12pt'

# Figure outline attributes
p.outline_line_alpha = 0.4
p.outline_line_width = 1.3
p.outline_line_color = "gray"

show(p)
# Out:
#   <div class="bk-root" id="e2009f99-7b2a-49da-b099-230259e0f2dc" data-root-id="4891"></div>

# %%
data = suicide_data.suicides_no.groupby(suicide_data.age).sum().reindex(index=ages)
dt = suicide_data.groupby(['age', 'year']).sum().suicides_no.reindex(level='age', index=ages)
# Out:
# <ipython-input-63-3da4a990a730>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dt = suicide_data.groupby(['age', 'year']).sum().suicides_no.reindex(level='age', index=ages)

# %%
from bokeh.palettes import Set1
from bokeh.models import Legend

# %%
# BAR PLOT
b = figure(x_range=ages, plot_height=400, plot_width=300, title='Suicides, by Age Range', toolbar_location=None)

# Set a vertical bar glyph
b.vbar(x=ages, top=data.values,  width=0.8)

# Set axes attributes
b.y_range.start = 0
b.xgrid.grid_line_color = None
b.yaxis.formatter=NumeralTickFormatter(format="0")

# Adjust x-axis major label
b.xaxis.major_label_orientation = 1
b.xaxis.major_label_text_font_size='9.3pt'

# Set y-axis label
b.yaxis.axis_label = 'Suicides'
b.yaxis.axis_label_text_font_style='bold'
b.yaxis.axis_label_text_font_size='10.5pt'

# Set outline attributes
b.outline_line_alpha = 0.4
b.outline_line_width = 1.3
b.outline_line_color = "gray"

# Set title font size
b.title.text_font_size = '12pt'


# LINE PLOT
l = figure(plot_width=560, plot_height=400, title='Suicides per Year, by Age Range', toolbar_location=None)

legendList = []

for age, color in zip(ages, Set1[6]):
    s = [l.line(x=dt[age].reset_index().year, y=dt[age].reset_index().suicides_no, color=color, line_width=2),
         l.circle(x=dt[age].reset_index().year, y=dt[age].reset_index().suicides_no, color=color, size=4)]

    legendList.append((age, s))

# Adjust axis tick format and labels
l.yaxis.formatter=NumeralTickFormatter(format="0")
l.xaxis.axis_label = 'Year'
l.xaxis.axis_label_text_font_style='bold'

# Add Legend to layout and sets its attributes
l.add_layout(Legend(items=legendList, location='top_right'), 'right')
l.legend.title_text_font_style = "bold"
l.legend.border_line_color = "gray"
l.legend.border_line_width = 1.3
l.legend.border_line_alpha = 0.2
l.legend.title = "Age Range"

# Set outline attributes
l.outline_line_color = "gray"
l.outline_line_alpha = 0.4
l.outline_line_width = 1.3

# Set title font size
l.title.text_font_size = '12pt'

show(row(b, l))
# Out:
#   <div class="bk-root" id="81a1a597-5f91-4439-85d2-62e60aeed844" data-root-id="5401"></div>

# %%
dt = suicide_data.groupby(['age']).sum()
dt['suicides/100k pop'] = (dt.suicides_no.values / dt.population.values) * 1e5

dt = dt.reindex(ages)
# Out:
# <ipython-input-66-c30ddf8250b0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dt = suicide_data.groupby(['age']).sum()

# %%
data = suicide_data.groupby(['age', 'year']).sum().reindex(level='age', index=ages)

data['suicides/100k pop'] = (data.suicides_no / data.population) * 1e5
# Out:
# <ipython-input-67-b37821235967>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = suicide_data.groupby(['age', 'year']).sum().reindex(level='age', index=ages)

# %%
# BAR PLOT
b = figure(x_range=ages,plot_height=400, plot_width=300, title='Suicides by Age Range, per 100k', toolbar_location=None)

# Set a vertical bar glyph
b.vbar(x=ages, top=dt['suicides/100k pop'].values , width=0.8)

# Set axes attributes
b.y_range.start = 0
b.xgrid.grid_line_color = None
b.yaxis.formatter=NumeralTickFormatter(format="0")

# Adjust x-axis major label
b.xaxis.major_label_orientation = 1
b.xaxis.major_label_text_font_size='9.3pt'

# Set y-axis label
b.yaxis.axis_label = 'Suicides per 100k'
b.yaxis.axis_label_text_font_style='bold'
b.yaxis.axis_label_text_font_size='10.5pt'

# Set outline attributes
b.outline_line_alpha = 0.4
b.outline_line_width = 1.3
b.outline_line_color = "gray"

# Set title font size
b.title.text_font_size = '12pt'


# LINE PLOT
l = figure(plot_width=560, plot_height=400, title='Suicides by Age Range, per 100k per Year', toolbar_location=None)

legendList=[]

for age, color in zip(ages, Set1[6][::-1]):
    s =  [l.line(x=data.loc[age].reset_index().year.values, y=data.loc[age, 'suicides/100k pop'].values, color=color, line_width=2),
          l.circle(x=data.loc[age].reset_index().year.values, y=data.loc[age, 'suicides/100k pop'].values, color=color, size=4)]

    legendList.append((age, s))

# Adjust y-axis tick format and x-axis label
l.yaxis.formatter=NumeralTickFormatter(format="0")
l.xaxis.axis_label = 'Year'
l.xaxis.axis_label_text_font_style='bold'

# Add Legend to layout and sets its attributes
l.add_layout(Legend(items=legendList, location='top_right'), 'right')
l.legend.title_text_font_style = "bold"
l.legend.border_line_color = "gray"
l.legend.border_line_width = 1.3
l.legend.border_line_alpha = 0.2
l.legend.title = "Age Range"

# Set outline attributes
l.outline_line_color = "gray"
l.outline_line_alpha = 0.4
l.outline_line_width = 1.3

# Set title font size
l.title.text_font_size = '12pt'

show(row(b, l))
# Out:
#   <div class="bk-root" id="f82d1046-e972-4706-9d38-794752866ced" data-root-id="6061"></div>

# %%
data_sex_year = suicide_data.groupby(['sex', 'year']).sum()
data_sex_year['suicides/100k pop'] = (data_sex_year.suicides_no / data_sex_year.population) * 1e5

data_sex_age = suicide_data.groupby(['sex', 'age']).sum().reindex(level='age', index=ages).iloc[:, :-2]
data_sex_age['suicides/100k pop'] = (data_sex_age.suicides_no / data_sex_age.population) * 1e5

suicides_100k_women_year = data_sex_year.loc['female', 'suicides/100k pop'].values
suicides_100k_men_year = data_sex_year.loc['male', 'suicides/100k pop'].values
# Out:
# <ipython-input-69-2611505f7b23>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_sex_year = suicide_data.groupby(['sex', 'year']).sum()
# <ipython-input-69-2611505f7b23>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data_sex_age = suicide_data.groupby(['sex', 'age']).sum().reindex(level='age', index=ages).iloc[:, :-2]

# %%
year = data_sex_year.reset_index().year.unique()

# %%
# LINE PLOTS

p1 = line_plot(year,
              data_sex_year.suicides_no.male.values,
              p_width=300,
              p_height=190,
              title='Suicides per Year, for Men',
              x_label='Year',
              y_label='Suicides')

p1.yaxis.formatter=NumeralTickFormatter(format="0a")
p1.title.text_font_size = '10pt'
p1.title.text_font_style="bold italic"

p2 = line_plot(year,
               data_sex_year.suicides_no.female.values,
               p_width=300,
               p_height=190,
               color='orange',
               title='Suicides per Year, for Women',
               x_label='Year',
               y_label='Suicides')

p2.yaxis.formatter=NumeralTickFormatter(format="0a")
p2.title.text_font_style="bold italic"
p2.title.text_font_size = '10pt'


# Plots for suicides per 100k
p3 = line_plot(year,
               suicides_100k_men_year,
               p_width=300,
               p_height=190,
               color='blue',
               title='Suicide Rates per 100k, for Men',
               x_label='Year',
               y_label='Suicides per 100k')

p3.title.text_font_style="bold italic"
p3.title.text_font_size = '10pt'

p4 = line_plot(year,
               suicides_100k_women_year,
               p_width=300,
               p_height=190,
               x_label='Year',
               title='Suicide Rates per 100k, for Women',
               y_label='Suicides per 100k',
               color='orange'
              )

p4.title.text_font_style="bold italic"
p4.title.text_font_size = '10pt'

# %%
# BAR PLOTS

age_gender = [(age, gender) for age in ages for gender in genders]

suicides = sum(zip(data_sex_age.loc['male', 'suicides_no'].tolist(), data_sex_age.loc['female', 'suicides_no'].tolist()), ())
suicides_per_100k_age = sum(zip(data_sex_age.loc['male', 'suicides/100k pop'].tolist(), data_sex_age.loc['female', 'suicides/100k pop'].tolist()), ())


source = ColumnDataSource(data=dict(age_gender=age_gender,
                                    suicides=suicides,
                                    suicides_per_100k_age=suicides_per_100k_age))


p5 = figure(x_range=FactorRange(*age_gender),
            plot_height=400,
            plot_width=450,
            title='Suicides, by Age Range and Gender',
            toolbar_location=None)

p6 = figure(x_range=FactorRange(*age_gender),
            plot_height=400,
            plot_width=450,
            title='Suicides per 100k, by Age Range and Gender',
            toolbar_location=None)

p5.vbar(x='age_gender',
        top='suicides',
        width=0.9,
        source=source,
        line_color='white',
        fill_color=factor_cmap('age_gender', palette=['blue', 'orange'], factors=genders, start=1, end=2))

p6.vbar(x='age_gender',
        top='suicides_per_100k_age',
        width=0.9,
        source=source,
        line_color='white',
        fill_color=factor_cmap('age_gender', palette=['blue', 'orange'], factors=genders, start=1, end=2))

# Set axes attributes
p5.y_range.start = 0
p5.x_range.range_padding = 0.01
p5.xgrid.grid_line_color = None

p6.y_range.start = 0
p6.x_range.range_padding = 0.01
p6.xgrid.grid_line_color = None

# Add y-axis label
p5.yaxis.axis_label = 'Suicides'
p5.yaxis.axis_label_text_font_style='bold'
p5.yaxis.axis_label_text_font_size='10.5pt'

p6.yaxis.axis_label = 'Suicides per 100k'
p6.yaxis.axis_label_text_font_style='bold'
p6.yaxis.axis_label_text_font_size='10.5pt'

# Set Title font size
p5.title.text_font_size = '12pt'
p6.title.text_font_size = '12pt'

# Set Outline attributes
p5.outline_line_color = "gray"
p5.outline_line_alpha = 0.4
p5.outline_line_width = 1.3

p6.outline_line_color = "gray"
p6.outline_line_alpha = 0.4
p6.outline_line_width = 1.3

# Set y-axis tick format and x-axis label orientation
p5.xaxis.major_label_orientation = 1
p5.xaxis.major_label_text_font_size='8.7pt'
p5.yaxis.formatter=NumeralTickFormatter(format="0.0a")

p6.xaxis.major_label_orientation = 1
p6.xaxis.major_label_text_font_size='8.7pt'
p6.yaxis.formatter=NumeralTickFormatter(format='0')

# %%
show(row(p5, column(p1, p2)))
show(row(p6, column(p3, p4)))
# Out:
#   <div class="bk-root" id="96046066-1f6e-4ba0-8cf7-e5443096ffa9" data-root-id="6971"></div>
#   <div class="bk-root" id="76b26bf7-a8b5-421a-83c8-7032e7aca07f" data-root-id="7504"></div>

# %% [markdown]
# - **Gender Disparity in Suicide Rates:**
#   - **Men vs. Women:** From 1985 to 2015, suicide rates were consistently higher among men compared to women.
#   - **Male Dominance:** For every suicide committed by women during this period, there were approximately three suicides committed by men, highlighting a significant gender disparity in suicide rates.
#
# - **Temporal Trends:**
#   - **Peak Year:** The rate of suicides per 100,000 people per year reached its highest point in 1995 for both genders, indicating a notable peak in suicide incidence during that period.
#
# - **Age-Specific Patterns:**
#   - **Middle-aged Men:** Middle-aged men accounted for the highest number of suicides across the years studied, suggesting a vulnerable demographic group.
#   - **Elderly Men:** Men aged 75 years or older exhibited the highest suicide rate, surpassing 40 suicides per 100,000 people, emphasizing the elevated risk among older males.

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(15, 10),
                       sharex=True)

generations = suicide_data.suicides_no.groupby(suicide_data.generation).sum().nlargest(3).index.tolist()
countries_a = ['Russian Federation', 'United States', 'Japan']

axes = np.copy(ax.flatten())
columns = ['sex', 'age', 'country', 'generation']
categories = [genders, ages, countries_a, generations]

for col, cat, axis in zip(columns, categories, axes):
    if col in ['age']:
        data = suicide_data.groupby([col, 'year']).sum().suicides_no.reindex(level=col, index=ages)
    else:
        data = suicide_data.groupby([col, 'year']).sum().suicides_no
    data = data[cat].reset_index()
    cond = col in ['generation', 'country']
    sns.lineplot(x='year', y='suicides_no', hue=col, style=col, data=data, sort=False, dashes=cond, ax=axis, palette='deep')
    axis.set_ylabel("Number of Suicides")

sns.despine()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-74-feff92edad9f>:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = suicide_data.groupby([col, 'year']).sum().suicides_no
# <ipython-input-74-feff92edad9f>:16: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = suicide_data.groupby([col, 'year']).sum().suicides_no.reindex(level=col, index=ages)
# <ipython-input-74-feff92edad9f>:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# ...

# %% [markdown]
# - **Gender Disparity in Suicide Rates:**
#   - **Male Dominance:** Consistently, the rate of suicides among men surpasses that of women, indicating a clear gender discrepancy in suicide incidence.
#
# - **Age-Specific Trends:**
#   - **Middle-Aged Men:** Suicide rates are notably higher among middle-aged men, highlighting a vulnerable demographic group susceptible to suicide.
#
# - **Regional Variations:**
#   - **Russia:** Suicide rates in Russia peak during the early 1990s but have been declining since then, suggesting a shift in suicide trends over time.
#   - **United States:** In the United States, suicide rates exhibit a nearly linear trend from 1985 to 2000. However, beyond 2000, there is a noticeable upward trajectory, indicating a concerning rise in suicide rates over recent years.
#
# - **Generational Differences:**
#   - **Boomers:** Among different generations, Boomers demonstrate the highest rates of suicide, peaking around 1994. However, it's important to note that the Generation variable may lack clarity and consensus regarding its definition and boundaries, limiting its interpretative value in this analysis.

# %% [markdown]
# ---

# %% [markdown]
# ***Analysing correlation between variables¶***
#
# ---

# %%
data = suicide_data.copy()
data = data.select_dtypes(include=['number'])

# %%
# Correlation Matrix

plt.figure(figsize=(6, 6))
xyticklabels = ['Year', 'Suicides', 'Population', 'Suicides/100k', 'GDP for Year', 'GDP per Capita']
cm = np.corrcoef(data[data.columns].values.T)
sns.set(font_scale=1.5)
sns.heatmap(cm,
            cbar=True,
            annot=True,
            square=True,
            fmt='.2f',
            annot_kws={'size': 15},
            yticklabels=xyticklabels,
            xticklabels=xyticklabels,
           )

plt.show()

# %% [markdown]
# In the presented correlation matrix, there is a **notable positive correlation** between **suicides** and **population**, indicating a **strong relationship**. Additionally, there appears to be **some level of correlation** between **suicides** and **GDP for the year**. It's essential to remember that **correlation assesses linear associations** between variables, and we'll delve deeper into these connections in the subsequent analyses.

# %%
# Load the dataset
# suicide_data = pd.read_csv("/content/master.csv")
# Correlation analysis
correlation_matrix = suicide_data.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                        year  suicides_no  population  suicides/100k pop  \
# year               1.000000    -0.002953    0.011583          -0.039800
# suicides_no       -0.002953     1.000000    0.616105           0.307103
# population         0.011583     0.616105    1.000000           0.008461
# suicides/100k pop -0.039800     0.307103    0.008461           1.000000
# GDP for year       0.097220     0.430011    0.710834           0.025334
# GDP per Capita     0.338854     0.062168    0.083006           0.002015
#
#                    GDP for year  GDP per Capita
# year                   0.097220        0.338854
# suicides_no            0.430011        0.062168
# population             0.710834        0.083006
# suicides/100k pop      0.025334        0.002015
# GDP for year           1.000000        0.304813
# GDP per Capita         0.304813        1.000000
# ...

# %%
# Correlation analysis
correlation_matrix = suicide_data.corr()

# Plotting the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-81-0ec1e7aa7ea8>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = suicide_data.corr()

# %% [markdown]
# From the correlation matrix, we observe the following correlations involving the "suicides_no" variable:
#
# Suicides Number and Population: There is a moderate positive correlation (0.62) between the number of suicides and the population. This suggests that countries with larger populations tend to have a higher number of suicides. This correlation is intuitive since a larger population provides a larger pool of individuals who may potentially be affected by mental health issues or other factors contributing to suicide.
#
# Suicides Number and Suicides/100k Population: The correlation coefficient between the number of suicides and the suicide rate per 100k population is 0.31, indicating a moderate positive correlation. This suggests that countries with a higher number of suicides also tend to have a higher suicide rate per 100k population. While this correlation is expected, it's important to note that the suicide rate provides a standardized measure, allowing for comparisons across populations of different sizes.
#
# These correlations imply that while the total number of suicides is positively correlated with both the population size and the suicide rate per 100k population, the correlation with the population size is stronger. This suggests that the absolute size of the population may have a greater influence on the total number of suicides compared to the standardized suicide rate. However, further analysis, such as regression modeling, would be necessary to understand the specific relationships and potential causal factors contributing to suicide numbers. Additionally, other variables not included in the correlation matrix, such as socio-economic factors, cultural aspects, and mental health policies, could also play significant roles in determining suicide rates and would need to be considered in a comprehensive analysis.

# %% [markdown]
# In the correlation matrix provided above, several correlations stand out in the context of suicides:
#
# - There is a **positive correlation** between **suicides number** and **GDP for the year** with a correlation coefficient of **0.43**, suggesting that countries with higher GDP tend to have higher suicide numbers.
# - **Population** also shows a **positive correlation** with **suicides number**, indicating that countries with larger populations tend to have higher suicide rates.
# - The **GDP per capita** has a **positive correlation** with **suicides number**, indicating that countries with higher GDP per capita may experience higher suicide numbers.
# - Interestingly, there's a **negative correlation** between **year** and **suicides/100k pop**, suggesting that over the years, there might be a slight decrease in the suicide rate per 100,000 people. This could imply potential improvements in societal or mental health factors over time.

# %%
plt.style.use('seaborn')
sns.pairplot(data=suicide_data, kind='reg')
plt.show()
# Out:
# <ipython-input-77-78efeb7a3a54>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# **Suicides and GDP per Capita¶**
#
# ---

# %%
from bokeh.models import LinearAxis, Range1d, Label
data = suicide_data.groupby(['country', 'year', 'GDP per Capita']).sum().suicides_no
data_gdp = data.reset_index()
gdpPercap, suicides = data_gdp['GDP per Capita'].values, data_gdp.suicides_no.values
# Out:
# <ipython-input-78-07f341f2a105>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data = suicide_data.groupby(['country', 'year', 'GDP per Capita']).sum().suicides_no

# %%
# SCATTER PLOT
p_scatter = figure(toolbar_location = None, plot_height = 560, plot_width = 560, title = 'Suicides vs. GDP per Capita')

# Set scatter glyph
p_scatter.scatter(x = gdpPercap, y = suicides, fill_color = 'blue', size = 3)

# Set outline attributes
p_scatter.outline_line_alpha = 0.3
p_scatter.outline_line_width = 1.3
p_scatter.outline_line_color = "gray"

# Set title font size
p_scatter.title.text_font_size = '13.5pt'

# Set axes labels
p_scatter.xaxis.axis_label = 'GDP per Capita'
p_scatter.yaxis.axis_label = 'Suicides'
p_scatter.yaxis.axis_label_text_font_style='bold'
p_scatter.xaxis.axis_label_text_font_style='bold'

# Set x-axis tick format
p_scatter.xaxis.formatter=NumeralTickFormatter(format="($0,0)")


### POP-OUT TWO OUTLIERS

# Select one outlier from data
first_outlier = data_gdp.loc[data_gdp['suicides_no'] > 60000]

x_first_outlier = first_outlier['GDP per Capita'].values[0]
y_first_outlier = first_outlier.suicides_no.values[0]

# Select another outlier from data
condition = (data_gdp['GDP per Capita'] > 60000) & (data_gdp['GDP per Capita'] < 65000)

second_outlier = data_gdp.loc[condition & (data_gdp.suicides_no > 40000)]

x_second_outlier = np.ndarray.item(second_outlier['GDP per Capita'].values)
y_second_outlier = np.ndarray.item(second_outlier.suicides_no.values)

# Set label for the first outlier
firstLabel = Label(x = x_first_outlier,
                   y = y_first_outlier,
                   x_offset=1,
                   y_offset=1,
                   text='Russian Federation, 1994',
                   render_mode='css',
                   text_font_size = '9pt',
                   text_font_style = 'italic')

# Set label for the second outlier
secondLabel = Label(x = x_second_outlier,
                    y = y_second_outlier,
                    x_offset=1,
                    y_offset=1,
                    text='United States, 2015',
                    render_mode='css',
                    text_font_size = '9pt',
                    text_font_style = 'italic')

# Add outliers labels to layout
p_scatter.add_layout(firstLabel)
p_scatter.add_layout(secondLabel)

# Pop-out both outliers
p_scatter.circle(x = x_first_outlier, y = y_first_outlier, color = 'red', size = 4)
p_scatter.circle(x = x_second_outlier, y = y_second_outlier, color = 'green', size = 4)

show(p_scatter)
# Out:
#   <div class="bk-root" id="7a67a3c4-3e67-4458-bfd2-1d12856f33b3" data-root-id="8079"></div>

# %% [markdown]
# From the correlation matrix, we observe the following correlations involving the "suicides_no" variable:
#
# 1. **Suicides Number and Population**: There is a moderate positive correlation (0.62) between the number of suicides and the population. This suggests that countries with larger populations tend to have a higher number of suicides. This correlation is intuitive since a larger population provides a larger pool of individuals who may potentially be affected by mental health issues or other factors contributing to suicide.
#
# 2. **Suicides Number and Suicides/100k Population**: The correlation coefficient between the number of suicides and the suicide rate per 100k population is 0.31, indicating a moderate positive correlation. This suggests that countries with a higher number of suicides also tend to have a higher suicide rate per 100k population. While this correlation is expected, it's important to note that the suicide rate provides a standardized measure, allowing for comparisons across populations of different sizes.
#
# These correlations imply that while the total number of suicides is positively correlated with both the population size and the suicide rate per 100k population, the correlation with the population size is stronger. This suggests that the absolute size of the population may have a greater influence on the total number of suicides compared to the standardized suicide rate. However, further analysis, such as regression modeling, would be necessary to understand the specific relationships and potential causal factors contributing to suicide numbers. Additionally, other variables not included in the correlation matrix, such as socio-economic factors, cultural aspects, and mental health policies, could also play significant roles in determining suicide rates and would need to be considered in a comprehensive analysis.

# %% [markdown]
# Some of the above graphs sugests that there is a correlation between increasing rates of suicide and GDP per capita for a particular country and year. For Russia, rates of suicide starts to decrease as GDP per Capita increases. As for the East/Southeast Asian countries, such as Korea, Japan and Thailand, there is a substantial increase in rates of suicide between 1997 and 1998 (with a drastic drop in GDP per capita) probably due to a financial crisis that affected some Asian countries in this period. However, it is worth to recall that correlation does not imply causation, and there are certainly multiple factors underlying increasing rates of suicide.
